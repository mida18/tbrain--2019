# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.model_selection import train_test_split, StratifiedKFold
from scipy import stats
from sklearn import metrics
from bayes_opt import BayesianOptimization
import lightgbm as lgb
import warnings
import time
import gc

# %%
train_df = pd.read_csv('train_reprocess_knn.csv',encoding='big5')
test_df = pd.read_csv('test_reprocess_knn.csv',encoding='big5')

# %% [raw]
# #drop_columns = ['CUS_ID', 'B_IND', 'C_IND', 'DIEBENEFIT_AMT', 'DISEASES_HOSPITAL_REC_AMT', 'IF_ISSUE_INSD_B_IND', 'IF_ISSUE_INSD_C_IND', 'IF_ISSUE_INSD_D_IND','IF_ISSUE_INSD_E_IND', 'IF_ISSUE_INSD_F_IND', 'IF_ISSUE_INSD_G_IND', 'IF_ISSUE_INSD_H_IND', 'IF_ISSUE_INSD_I_IND', 'IF_ISSUE_INSD_J_IND', 'IF_ISSUE_INSD_K_IND','IF_ISSUE_INSD_L_IND', 'IF_ISSUE_INSD_M_IND','IF_ISSUE_INSD_N_IND','IF_ISSUE_INSD_O_IND', 'IF_ADD_INSD_L_IND', 'IF_ADD_INSD_Q_IND', 'IF_ADD_INSD_G_IND', 'IF_ADD_INSD_R_IND', 'FINANCETOOLS_B','FINANCETOOLS_C', 'FINANCETOOLS_D', 'FINANCETOOLS_E', 'FINANCETOOLS_F', 'FINANCETOOLS_G', 'IF_ADD_INSD_IND']
# drop_columns = ['IF_ISSUE_INSD_B_IND', 'IF_ISSUE_INSD_C_IND', 'IF_ISSUE_INSD_D_IND','IF_ISSUE_INSD_E_IND', 'IF_ISSUE_INSD_F_IND', 'IF_ISSUE_INSD_G_IND']
# train_df  = train_df.drop(drop_columns, axis = 1)
# test_df  = test_df.drop(drop_columns, axis = 1)

# %% [raw]
# df = pd.read_csv('train.csv',encoding='big5')

# %% [raw]
# # Categorical columns
# col = df.select_dtypes(include='object').columns
# col = col.drop(['Y1']).tolist()
# indexes_of_categories = [train_df.columns.get_loc(i) for i in col]

# %% [raw]
# train_df = pd.read_csv('train_preprocess_features.csv',encoding='big5')
# test_df = pd.read_csv('test_preprocess_features.csv',encoding='big5')

# %% [raw]
# train_y1 = pd.read_csv('train_frequency.csv',encoding='big5')
# y1 = train_y1['Y1']

# %% [raw]
# train_df = pd.concat([train_df, y1], axis = 1)
# train_df.shape

# %%
train_df.shape
# Out:
# (100000, 132)

# %%
#目標變量的分布
predictors = train_df.drop(['Y1'],axis=1).columns.values.tolist()
train_df['Y1'].value_counts()
# Out:
# 0.0    98000
# 1.0     2000
# Name: Y1, dtype: int64

# %% [markdown]
# ### RandomForest 篩選特徵

# %% [raw]
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.feature_selection import SelectFromModel
#
# drop_col = ['Y1','CUS_ID']
# feat_labels = train_df.drop(drop_col,axis=1).columns
# forest = RandomForestClassifier(n_estimators=500, random_state=1)
#
# X,y =train_df.drop(drop_col,axis=1), train_df['Y1']
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)
# forest.fit(X_train, y_train)
# importances = forest.feature_importances_
# indices = np.argsort(importances)[::-1]
#
# sfm = SelectFromModel(forest, threshold=0.001, prefit=True)
# X_selected = sfm.transform(X_train)
#
# for f in range(X_selected.shape[1]):
#     print("%2d) %-*s %f" % (f + 1, 30,
#                             feat_labels[indices[f]],
#                             importances[indices[f]]))

# %% [raw]
# new_col = feat_labels[indices[range(X_selected.shape[1])]]
# X,y = train_df[new_col], train_df['Y1']
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)
#
# #stdc = StandardScaler()
# #X_train_std = stdc.fit_transform(X_train)
# #X_test_std = stdc.fit_transform(X_test)

# %% [raw]
# X_train

# %% [markdown]
# ### 尋找最佳參數

# %%
X_train, X_test, y_train, y_test = train_test_split(train_df.drop(['Y1','CUS_ID'],axis=1), train_df['Y1'], test_size=0.2, random_state=1)

# %% [raw]
# train_df = train_df.drop(['CUS_ID'],axis=1)
# test_df = test_df.drop(['CUS_ID'],axis=1)
#
# train_y0 = train_df[train_df["Y1"] == 0]
# train_y1 = train_df[train_df["Y1"] == 1]

# %% [raw]
# train, test = train_test_split(train_y0, train_size = 0.1, random_state=1)

# %% [raw]
# train_df_select = pd.concat([train, train_y1], axis = 0).reset_index(drop=True)

# %% [raw]
# # 新的目標變量的分布
# predictors = train_df_select.drop(['Y1'],axis=1).columns.values.tolist()
# train_df_select['Y1'].value_counts()

# %%
#分層採樣，確保訓練集與測試集中各類樣本的比例與原始數據集中相同

# split all data
'''
X,y = train_df.drop(['Y1','CUS_ID'],axis=1), train_df['Y1']
bayesian_train_index, bayesian_val_index = list(StratifiedKFold(n_splits=2, random_state=1).split(X, y))[0]
print('number of 1 in train: %s | number of 1 in val: %s' % (train_df.iloc[bayesian_train_index,:]["Y1"].sum(), 
                                                             train_df.iloc[bayesian_val_index,:]["Y1"].sum()))
'''

# split X_train

bayesian_train_index, bayesian_val_index = list(StratifiedKFold(n_splits=2, random_state=1).split(X_train, y_train))[0]
print('number of 1 in train: %s | number of 1 in val: %s' % (y_train[bayesian_train_index].sum(), 
                                                             y_train[bayesian_val_index].sum()))


# train_df_select
'''
X, y = train_df_select.drop(['Y1'],axis=1), train_df_select['Y1']
bayesian_train_index, bayesian_val_index = list(StratifiedKFold(n_splits=2, random_state=1).split(X, y))[0]
print('number of 1 in train: %s | number of 1 in val: %s' % (y[bayesian_train_index].sum(), 
                                                             y[bayesian_val_index].sum()))
'''
print('train_size: %s | val_size: %s' % (bayesian_train_index.shape, bayesian_val_index.shape))
# Out:
# C:\Users\doggy\Anaconda3\lib\site-packages\pandas\core\series.py:1143: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self.loc[key]
# number of 1 in train: 687.0 | number of 1 in val: 636.0
# train_size: (40000,) | val_size: (40000,)

# %%
def LGB_bayesian(max_depth, num_leaves, learning_rate,
                 reg_alpha, reg_lambda, bagging_fraction, bagging_freq, feature_fraction):

    
    parameters = {'boosting_type': 'gbdt',          #設置提升類型
                 'objective': 'binary',             #目標函數
                 'importance_type': 'split', 
                 'learning_rate':learning_rate,
                 'max_depth': int(max_depth),       #if -1 means no limit
                 'n_estimators': 200, 
                 'n_jobs': -1,
                 'num_leaves': int(num_leaves),     #葉子節點數 (we should let it be smaller than 2^(max_depth))
                 'objective': 'binary', 
                 'random_state': 1, 
                 'reg_alpha': reg_alpha, 
                 'reg_lambda': reg_lambda, 
                 'silent': True, 
                 'is_unbalance': True,
                 'metric': ('auc','binary_logloss'),
                 'verbose': 0,
                 'feature_fraction': feature_fraction, #特徵採樣
                 'bagging_fraction': bagging_fraction, #數據採樣
                 'bagging_freq': int(bagging_freq),    #每K輪迭代執行一次bagging
                 'cat_smooth': 1}
    
    
    lgb_train = lgb.Dataset(X_train.iloc[bayesian_train_index], y_train.iloc[bayesian_train_index])
    lgb_valid = lgb.Dataset(X_train.iloc[bayesian_val_index], y_train.iloc[bayesian_val_index])

    
    '''    
    lgb_train = lgb.Dataset(X.iloc[bayesian_train_index], y.iloc[bayesian_train_index])
    lgb_valid = lgb.Dataset(X.iloc[bayesian_val_index], y.iloc[bayesian_val_index])
    
    '''
    clf = gb.cv(param, train_data, num_round, nfold=5)
    clf = lgb.train(parameters, lgb_train, valid_sets = lgb_valid, early_stopping_rounds = 50)
                    ##categorical_feature = indexes_of_categories)
    predictions = clf.predict(X_train.iloc[bayesian_val_index], num_iteration =clf.best_iteration) 
    score = metrics.roc_auc_score(y_train.iloc[bayesian_val_index], predictions) 
    
    '''
    clf = lgb.train(parameters, lgb_train, valid_sets = lgb_valid, early_stopping_rounds = 10)
    predictions = clf.predict(X.iloc[bayesian_val_index], num_iteration =clf.best_iteration) 
    score = metrics.roc_auc_score(y.iloc[bayesian_val_index], predictions) 
    '''
    return score

# %%
#設定參數邊界，使貝葉斯優化在邊界內搜索最佳值
bounds_LGB = {
    'num_leaves': (20, 100), 
    'learning_rate': (0.001, 0.2),
    'feature_fraction': (0.6, 1.0),
    'bagging_fraction': (0.6, 1.0),
    'bagging_freq': (5, 20),
    'reg_alpha': (0, 1),
    'reg_lambda': (0, 50),
    'max_depth':(10, 30)
}

# %%
print('数据...')
x_train = np.random.random((1000,10))
y_train = np.random.rand(1000)>0.5
x_test = np.random.random((100,10))
y_test = np.random.randn(100)>0.5

# 导入到lightgbm矩阵
lgb_train = lgb.Dataset(x_train, y_train)
lgb_test = lgb.Dataset(x_test, y_test, reference=lgb_train)

# 设置参数
params = {
    'num_leaves': 5,
    'metric': ('auc', 'logloss'),#可以设置多个评价指标
    'verbose': 0
}
# if (evals_result and gbm) not in locbals():
	# global evals_result,gbm 
#如果是局部变量的话，推荐把他们变成全局变量，这样plot的代码位置不受限制

# %%
LGB_BO = BayesianOptimization(LGB_bayesian, bounds_LGB, random_state=1)
#print(LGB_BO.space.keys)

# %%
#創建BayesianOptimization对象(LGB_BO)後，在調用maxime前不會運作。
#init_points：How many steps of random exploration you want to perform.(help by diversifying the exploration space.)
#n_iter：How many steps of bayesian optimization you want to perform.(The more steps the more likely to find a good maximum)
init_points = 10
n_iter = 50

with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    LGB_BO.maximize(init_points =init_points, n_iter =n_iter)
# Out:
# |   iter    |  target   | baggin... | baggin... | featur... | learni... | max_depth | num_le... | reg_alpha | reg_la... |
# -------------------------------------------------------------------------------------------------------------------------
# [1]	valid_0's auc: 0.718876
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's auc: 0.735676
# [3]	valid_0's auc: 0.74847
# [4]	valid_0's auc: 0.751631
# [5]	valid_0's auc: 0.754928
# [6]	valid_0's auc: 0.760006
# [7]	valid_0's auc: 0.764613
# [8]	valid_0's auc: 0.767149
# [9]	valid_0's auc: 0.769583
# [10]	valid_0's auc: 0.771606
# [11]	valid_0's auc: 0.774624
# [12]	valid_0's auc: 0.776079
# [13]	valid_0's auc: 0.776434
# [14]	valid_0's auc: 0.777929
# [15]	valid_0's auc: 0.778626
# [16]	valid_0's auc: 0.780529
# [17]	valid_0's auc: 0.781388
# [18]	valid_0's auc: 0.782765
# [19]	valid_0's auc: 0.783642
# [20]	valid_0's auc: 0.783937
# [21]	valid_0's auc: 0.7849
# [22]	valid_0's auc: 0.78593
# [23]	valid_0's auc: 0.787318
# [24]	valid_0's auc: 0.788052
# [25]	valid_0's auc: 0.788786
# [26]	valid_0's auc: 0.789555
# [27]	valid_0's auc: 0.789963
# [28]	valid_0's auc: 0.790778
# [29]	valid_0's auc: 0.791588
# [30]	valid_0's auc: 0.792499
# [31]	valid_0's auc: 0.793328
# [32]	valid_0's auc: 0.79451
# [33]	valid_0's auc: 0.795125
# [34]	valid_0's auc: 0.796343
# [35]	valid_0's auc: 0.797273
# [36]	valid_0's auc: 0.798062
# [37]	valid_0's auc: 0.798543
# [38]	valid_0's auc: 0.798992
# [39]	valid_0's auc: 0.799204
# [40]	valid_0's auc: 0.799837
# [41]	valid_0's auc: 0.800586
# [42]	valid_0's auc: 0.800639
# [43]	valid_0's auc: 0.80065
# [44]	valid_0's auc: 0.801033
# [45]	valid_0's auc: 0.801821
# [46]	valid_0's auc: 0.802459
# [47]	valid_0's auc: 0.803022
# [48]	valid_0's auc: 0.803713
# [49]	valid_0's auc: 0.803993
# [50]	valid_0's auc: 0.804401
# [51]	valid_0's auc: 0.804359
# [52]	valid_0's auc: 0.805267
# [53]	valid_0's auc: 0.805284
# [54]	valid_0's auc: 0.805481
# [55]	valid_0's auc: 0.8054
# [56]	valid_0's auc: 0.805716
# [57]	valid_0's auc: 0.80573
# [58]	valid_0's auc: 0.805885
# [59]	valid_0's auc: 0.805921
# [60]	valid_0's auc: 0.805838
# [61]	valid_0's auc: 0.806054
# [62]	valid_0's auc: 0.806608
# [63]	valid_0's auc: 0.806594
# [64]	valid_0's auc: 0.806771
# [65]	valid_0's auc: 0.807083
# [66]	valid_0's auc: 0.80729
# [67]	valid_0's auc: 0.807497
# [68]	valid_0's auc: 0.807698
# [69]	valid_0's auc: 0.807614
# [70]	valid_0's auc: 0.807839
# [71]	valid_0's auc: 0.807823
# [72]	valid_0's auc: 0.808193
# [73]	valid_0's auc: 0.808349
# [74]	valid_0's auc: 0.808441
# [75]	valid_0's auc: 0.808998
# [76]	valid_0's auc: 0.809432
# [77]	valid_0's auc: 0.809787
# [78]	valid_0's auc: 0.80979
# [79]	valid_0's auc: 0.809886
# [80]	valid_0's auc: 0.810156
# [81]	valid_0's auc: 0.810241
# [82]	valid_0's auc: 0.810635
# [83]	valid_0's auc: 0.810872
# [84]	valid_0's auc: 0.811049
# [85]	valid_0's auc: 0.810999
# [86]	valid_0's auc: 0.811181
# [87]	valid_0's auc: 0.811439
# [88]	valid_0's auc: 0.811264
# [89]	valid_0's auc: 0.811212
# [90]	valid_0's auc: 0.811109
# [91]	valid_0's auc: 0.811189
# [92]	valid_0's auc: 0.811564
# [93]	valid_0's auc: 0.811623
# [94]	valid_0's auc: 0.811742
# [95]	valid_0's auc: 0.811738
# [96]	valid_0's auc: 0.811889
# [97]	valid_0's auc: 0.812197
# [98]	valid_0's auc: 0.812339
# [99]	valid_0's auc: 0.812491
# [100]	valid_0's auc: 0.812959
# [101]	valid_0's auc: 0.812807
# [102]	valid_0's auc: 0.813102
# [103]	valid_0's auc: 0.813035
# [104]	valid_0's auc: 0.813052
# [105]	valid_0's auc: 0.813051
# [106]	valid_0's auc: 0.813275
# [107]	valid_0's auc: 0.813058
# [108]	valid_0's auc: 0.812899
# [109]	valid_0's auc: 0.813264
# [110]	valid_0's auc: 0.813097
# [111]	valid_0's auc: 0.813363
# [112]	valid_0's auc: 0.813493
# [113]	valid_0's auc: 0.813558
# [114]	valid_0's auc: 0.813547
# [115]	valid_0's auc: 0.813575
# [116]	valid_0's auc: 0.81361
# [117]	valid_0's auc: 0.813438
# [118]	valid_0's auc: 0.81329
# [119]	valid_0's auc: 0.81303
# [120]	valid_0's auc: 0.813026
# [121]	valid_0's auc: 0.81311
# [122]	valid_0's auc: 0.813207
# [123]	valid_0's auc: 0.813347
# [124]	valid_0's auc: 0.813518
# [125]	valid_0's auc: 0.813741
# [126]	valid_0's auc: 0.813787
# [127]	valid_0's auc: 0.813725
# [128]	valid_0's auc: 0.813573
# [129]	valid_0's auc: 0.81337
# [130]	valid_0's auc: 0.81355
# [131]	valid_0's auc: 0.813662
# [132]	valid_0's auc: 0.813751
# [133]	valid_0's auc: 0.813836
# [134]	valid_0's auc: 0.813751
# [135]	valid_0's auc: 0.813548
# [136]	valid_0's auc: 0.813536
# [137]	valid_0's auc: 0.813486
# [138]	valid_0's auc: 0.813499
# [139]	valid_0's auc: 0.813635
# [140]	valid_0's auc: 0.813627
# [141]	valid_0's auc: 0.813718
# [142]	valid_0's auc: 0.813524
# [143]	valid_0's auc: 0.813266
# [144]	valid_0's auc: 0.813233
# [145]	valid_0's auc: 0.813065
# [146]	valid_0's auc: 0.812856
# [147]	valid_0's auc: 0.812732
# [148]	valid_0's auc: 0.812684
# [149]	valid_0's auc: 0.812688
# [150]	valid_0's auc: 0.812689
# [151]	valid_0's auc: 0.812914
# [152]	valid_0's auc: 0.812902
# [153]	valid_0's auc: 0.813267
# [154]	valid_0's auc: 0.813436
# [155]	valid_0's auc: 0.813432
# [156]	valid_0's auc: 0.813847
# [157]	valid_0's auc: 0.814002
# [158]	valid_0's auc: 0.814191
# [159]	valid_0's auc: 0.814368
# [160]	valid_0's auc: 0.814459
# [161]	valid_0's auc: 0.814417
# [162]	valid_0's auc: 0.814443
# [163]	valid_0's auc: 0.814299
# [164]	valid_0's auc: 0.81427
# [165]	valid_0's auc: 0.814491
# [166]	valid_0's auc: 0.814645
# [167]	valid_0's auc: 0.814734
# [168]	valid_0's auc: 0.814843
# [169]	valid_0's auc: 0.815274
# [170]	valid_0's auc: 0.815209
# [171]	valid_0's auc: 0.815165
# [172]	valid_0's auc: 0.815069
# [173]	valid_0's auc: 0.815227
# [174]	valid_0's auc: 0.815234
# [175]	valid_0's auc: 0.81531
# [176]	valid_0's auc: 0.815283
# [177]	valid_0's auc: 0.815198
# [178]	valid_0's auc: 0.815193
# [179]	valid_0's auc: 0.815188
# [180]	valid_0's auc: 0.815127
# [181]	valid_0's auc: 0.815099
# [182]	valid_0's auc: 0.815052
# [183]	valid_0's auc: 0.8151
# [184]	valid_0's auc: 0.815073
# [185]	valid_0's auc: 0.815015
# [186]	valid_0's auc: 0.815187
# [187]	valid_0's auc: 0.815434
# [188]	valid_0's auc: 0.815464
# [189]	valid_0's auc: 0.81541
# [190]	valid_0's auc: 0.815403
# [191]	valid_0's auc: 0.81551
# [192]	valid_0's auc: 0.815343
# [193]	valid_0's auc: 0.815237
# [194]	valid_0's auc: 0.815216
# [195]	valid_0's auc: 0.815189
# [196]	valid_0's auc: 0.814992
# [197]	valid_0's auc: 0.814848
# [198]	valid_0's auc: 0.814582
# [199]	valid_0's auc: 0.814561
# [200]	valid_0's auc: 0.81463
# Did not meet early stopping. Best iteration is:
# [191]	valid_0's auc: 0.81551
# |  1        |  0.8155   |  0.7668   |  15.8     |  0.6      |  0.06116  |  8.669    |  27.39    |  9.313    |  17.28    |
# [1]	valid_0's auc: 0.736963
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's auc: 0.750591
# [3]	valid_0's auc: 0.762889
# [4]	valid_0's auc: 0.763363
# [5]	valid_0's auc: 0.767304
# [6]	valid_0's auc: 0.770838
# [7]	valid_0's auc: 0.775102
# [8]	valid_0's auc: 0.777897
# [9]	valid_0's auc: 0.780543
# [10]	valid_0's auc: 0.783035
# [11]	valid_0's auc: 0.784808
# [12]	valid_0's auc: 0.786175
# [13]	valid_0's auc: 0.787497
# [14]	valid_0's auc: 0.789054
# [15]	valid_0's auc: 0.790676
# [16]	valid_0's auc: 0.792445
# [17]	valid_0's auc: 0.793174
# [18]	valid_0's auc: 0.7938
# [19]	valid_0's auc: 0.794755
# [20]	valid_0's auc: 0.795639
# [21]	valid_0's auc: 0.797
# [22]	valid_0's auc: 0.7967
# [23]	valid_0's auc: 0.796581
# [24]	valid_0's auc: 0.796611
# [25]	valid_0's auc: 0.796666
# [26]	valid_0's auc: 0.796821
# [27]	valid_0's auc: 0.797354
# [28]	valid_0's auc: 0.797715
# [29]	valid_0's auc: 0.79748
# [30]	valid_0's auc: 0.79768
# [31]	valid_0's auc: 0.797828
# [32]	valid_0's auc: 0.797354
# [33]	valid_0's auc: 0.797367
# [34]	valid_0's auc: 0.797264
# [35]	valid_0's auc: 0.798116
# [36]	valid_0's auc: 0.79837
# [37]	valid_0's auc: 0.79821
# [38]	valid_0's auc: 0.797761
# [39]	valid_0's auc: 0.797693
# [40]	valid_0's auc: 0.797883
# [41]	valid_0's auc: 0.798214
# [42]	valid_0's auc: 0.798212
# [43]	valid_0's auc: 0.798768
# [44]	valid_0's auc: 0.797795
# [45]	valid_0's auc: 0.798296
# [46]	valid_0's auc: 0.798408
# [47]	valid_0's auc: 0.798194
# [48]	valid_0's auc: 0.798838
# [49]	valid_0's auc: 0.799042
# [50]	valid_0's auc: 0.798999
# [51]	valid_0's auc: 0.798705
# [52]	valid_0's auc: 0.798873
# [53]	valid_0's auc: 0.798524
# [54]	valid_0's auc: 0.798729
# [55]	valid_0's auc: 0.799285
# [56]	valid_0's auc: 0.799255
# [57]	valid_0's auc: 0.79965
# [58]	valid_0's auc: 0.799807
# [59]	valid_0's auc: 0.800173
# [60]	valid_0's auc: 0.800205
# [61]	valid_0's auc: 0.800014
# [62]	valid_0's auc: 0.800153
# [63]	valid_0's auc: 0.799832
# [64]	valid_0's auc: 0.799655
# [65]	valid_0's auc: 0.799593
# [66]	valid_0's auc: 0.79995
# [67]	valid_0's auc: 0.799714
# [68]	valid_0's auc: 0.799558
# [69]	valid_0's auc: 0.799135
# [70]	valid_0's auc: 0.798871
# [71]	valid_0's auc: 0.798772
# [72]	valid_0's auc: 0.79848
# [73]	valid_0's auc: 0.798323
# [74]	valid_0's auc: 0.798242
# [75]	valid_0's auc: 0.798218
# [76]	valid_0's auc: 0.797942
# [77]	valid_0's auc: 0.79783
# [78]	valid_0's auc: 0.797859
# [79]	valid_0's auc: 0.797706
# [80]	valid_0's auc: 0.798033
# [81]	valid_0's auc: 0.797836
# [82]	valid_0's auc: 0.79763
# [83]	valid_0's auc: 0.797838
# [84]	valid_0's auc: 0.797838
# [85]	valid_0's auc: 0.797712
# [86]	valid_0's auc: 0.797769
# [87]	valid_0's auc: 0.797871
# [88]	valid_0's auc: 0.797776
# [89]	valid_0's auc: 0.798062
# [90]	valid_0's auc: 0.797953
# [91]	valid_0's auc: 0.798343
# [92]	valid_0's auc: 0.798421
# [93]	valid_0's auc: 0.798758
# [94]	valid_0's auc: 0.798617
# [95]	valid_0's auc: 0.798487
# [96]	valid_0's auc: 0.798456
# [97]	valid_0's auc: 0.798403
# [98]	valid_0's auc: 0.79779
# [99]	valid_0's auc: 0.79744
# [100]	valid_0's auc: 0.797685
# [101]	valid_0's auc: 0.797508
# [102]	valid_0's auc: 0.797463
# [103]	valid_0's auc: 0.797251
# [104]	valid_0's auc: 0.797305
# [105]	valid_0's auc: 0.797109
# [106]	valid_0's auc: 0.796917
# [107]	valid_0's auc: 0.796616
# [108]	valid_0's auc: 0.796606
# [109]	valid_0's auc: 0.796385
# [110]	valid_0's auc: 0.795845
# Early stopping, best iteration is:
# [60]	valid_0's auc: 0.800205
# |  2        |  0.8002   |  0.7587   |  13.08    |  0.7677   |  0.1374   |  10.11    |  90.25    |  1.369    |  33.52    |
# [1]	valid_0's auc: 0.728491
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's auc: 0.750907
# [3]	valid_0's auc: 0.754931
# [4]	valid_0's auc: 0.7603
# [5]	valid_0's auc: 0.764793
# [6]	valid_0's auc: 0.769809
# [7]	valid_0's auc: 0.774957
# [8]	valid_0's auc: 0.777063
# [9]	valid_0's auc: 0.77896
# [10]	valid_0's auc: 0.780275
# [11]	valid_0's auc: 0.78228
# [12]	valid_0's auc: 0.782745
# [13]	valid_0's auc: 0.784478
# [14]	valid_0's auc: 0.785396
# [15]	valid_0's auc: 0.78564
# [16]	valid_0's auc: 0.786643
# [17]	valid_0's auc: 0.7871
# [18]	valid_0's auc: 0.787404
# [19]	valid_0's auc: 0.788342
# [20]	valid_0's auc: 0.789625
# [21]	valid_0's auc: 0.790465
# [22]	valid_0's auc: 0.790783
# [23]	valid_0's auc: 0.792181
# [24]	valid_0's auc: 0.79352
# [25]	valid_0's auc: 0.793806
# [26]	valid_0's auc: 0.794735
# [27]	valid_0's auc: 0.794819
# [28]	valid_0's auc: 0.795422
# [29]	valid_0's auc: 0.795647
# [30]	valid_0's auc: 0.796872
# [31]	valid_0's auc: 0.797422
# [32]	valid_0's auc: 0.798254
# [33]	valid_0's auc: 0.798501
# [34]	valid_0's auc: 0.799243
# [35]	valid_0's auc: 0.799757
# [36]	valid_0's auc: 0.800723
# [37]	valid_0's auc: 0.801134
# [38]	valid_0's auc: 0.801387
# [39]	valid_0's auc: 0.801704
# [40]	valid_0's auc: 0.802244
# [41]	valid_0's auc: 0.802471
# [42]	valid_0's auc: 0.802663
# [43]	valid_0's auc: 0.803155
# [44]	valid_0's auc: 0.803486
# [45]	valid_0's auc: 0.804155
# [46]	valid_0's auc: 0.804674
# [47]	valid_0's auc: 0.8051
# [48]	valid_0's auc: 0.805915
# [49]	valid_0's auc: 0.806384
# [50]	valid_0's auc: 0.806741
# [51]	valid_0's auc: 0.807579
# [52]	valid_0's auc: 0.807919
# [53]	valid_0's auc: 0.808442
# [54]	valid_0's auc: 0.808703
# [55]	valid_0's auc: 0.808959
# [56]	valid_0's auc: 0.809474
# [57]	valid_0's auc: 0.809927
# [58]	valid_0's auc: 0.810089
# [59]	valid_0's auc: 0.810119
# [60]	valid_0's auc: 0.810796
# [61]	valid_0's auc: 0.810944
# [62]	valid_0's auc: 0.811425
# [63]	valid_0's auc: 0.812025
# [64]	valid_0's auc: 0.812512
# [65]	valid_0's auc: 0.812644
# [66]	valid_0's auc: 0.81276
# [67]	valid_0's auc: 0.81309
# [68]	valid_0's auc: 0.813111
# [69]	valid_0's auc: 0.81317
# [70]	valid_0's auc: 0.813038
# [71]	valid_0's auc: 0.813299
# [72]	valid_0's auc: 0.813892
# [73]	valid_0's auc: 0.814088
# [74]	valid_0's auc: 0.814114
# [75]	valid_0's auc: 0.813833
# [76]	valid_0's auc: 0.814127
# [77]	valid_0's auc: 0.814254
# [78]	valid_0's auc: 0.814404
# [79]	valid_0's auc: 0.814721
# [80]	valid_0's auc: 0.814971
# [81]	valid_0's auc: 0.815204
# [82]	valid_0's auc: 0.815256
# [83]	valid_0's auc: 0.815402
# [84]	valid_0's auc: 0.815715
# [85]	valid_0's auc: 0.816002
# [86]	valid_0's auc: 0.816238
# [87]	valid_0's auc: 0.816241
# [88]	valid_0's auc: 0.8164
# [89]	valid_0's auc: 0.816292
# [90]	valid_0's auc: 0.816606
# [91]	valid_0's auc: 0.816673
# [92]	valid_0's auc: 0.816873
# [93]	valid_0's auc: 0.817304
# [94]	valid_0's auc: 0.817565
# [95]	valid_0's auc: 0.817746
# [96]	valid_0's auc: 0.817944
# [97]	valid_0's auc: 0.818071
# [98]	valid_0's auc: 0.818421
# [99]	valid_0's auc: 0.818745
# [100]	valid_0's auc: 0.818814
# [101]	valid_0's auc: 0.819157
# [102]	valid_0's auc: 0.819298
# [103]	valid_0's auc: 0.819511
# [104]	valid_0's auc: 0.819693
# [105]	valid_0's auc: 0.819704
# [106]	valid_0's auc: 0.820056
# [107]	valid_0's auc: 0.82014
# [108]	valid_0's auc: 0.82022
# [109]	valid_0's auc: 0.820143
# [110]	valid_0's auc: 0.819997
# [111]	valid_0's auc: 0.819917
# [112]	valid_0's auc: 0.820126
# [113]	valid_0's auc: 0.820169
# [114]	valid_0's auc: 0.82008
# [115]	valid_0's auc: 0.819998
# [116]	valid_0's auc: 0.819952
# [117]	valid_0's auc: 0.81997
# [118]	valid_0's auc: 0.819971
# [119]	valid_0's auc: 0.820058
# [120]	valid_0's auc: 0.820081
# [121]	valid_0's auc: 0.820112
# [122]	valid_0's auc: 0.819993
# [123]	valid_0's auc: 0.820078
# [124]	valid_0's auc: 0.820172
# [125]	valid_0's auc: 0.820209
# [126]	valid_0's auc: 0.820202
# [127]	valid_0's auc: 0.82016
# [128]	valid_0's auc: 0.82016
# [129]	valid_0's auc: 0.820404
# [130]	valid_0's auc: 0.820316
# [131]	valid_0's auc: 0.820182
# [132]	valid_0's auc: 0.820275
# [133]	valid_0's auc: 0.820369
# [134]	valid_0's auc: 0.82053
# [135]	valid_0's auc: 0.820506
# [136]	valid_0's auc: 0.820434
# [137]	valid_0's auc: 0.820407
# [138]	valid_0's auc: 0.820302
# [139]	valid_0's auc: 0.820166
# [140]	valid_0's auc: 0.820167
# [141]	valid_0's auc: 0.820201
# [142]	valid_0's auc: 0.820109
# [143]	valid_0's auc: 0.820198
# [144]	valid_0's auc: 0.820215
# [145]	valid_0's auc: 0.820172
# [146]	valid_0's auc: 0.820089
# [147]	valid_0's auc: 0.819992
# [148]	valid_0's auc: 0.820025
# [149]	valid_0's auc: 0.820014
# [150]	valid_0's auc: 0.819898
# [151]	valid_0's auc: 0.819926
# [152]	valid_0's auc: 0.819971
# [153]	valid_0's auc: 0.819872
# [154]	valid_0's auc: 0.819759
# [155]	valid_0's auc: 0.819697
# [156]	valid_0's auc: 0.819632
# [157]	valid_0's auc: 0.819766
# [158]	valid_0's auc: 0.819653
# [159]	valid_0's auc: 0.81964
# [160]	valid_0's auc: 0.819737
# [161]	valid_0's auc: 0.819711
# [162]	valid_0's auc: 0.819919
# [163]	valid_0's auc: 0.819955
# [164]	valid_0's auc: 0.81984
# [165]	valid_0's auc: 0.819918
# [166]	valid_0's auc: 0.819974
# [167]	valid_0's auc: 0.820026
# [168]	valid_0's auc: 0.819839
# [169]	valid_0's auc: 0.819913
# [170]	valid_0's auc: 0.819834
# [171]	valid_0's auc: 0.819927
# [172]	valid_0's auc: 0.819771
# [173]	valid_0's auc: 0.819867
# [174]	valid_0's auc: 0.819887
# [175]	valid_0's auc: 0.819821
# [176]	valid_0's auc: 0.819895
# [177]	valid_0's auc: 0.819978
# [178]	valid_0's auc: 0.819877
# [179]	valid_0's auc: 0.819759
# [180]	valid_0's auc: 0.819879
# [181]	valid_0's auc: 0.819869
# [182]	valid_0's auc: 0.819983
# [183]	valid_0's auc: 0.820142
# [184]	valid_0's auc: 0.819973
# Early stopping, best iteration is:
# [134]	valid_0's auc: 0.82053
# |  3        |  0.8205   |  0.7669   |  13.38    |  0.6562   |  0.04042  |  25.02    |  97.46    |  15.67    |  34.62    |
# [1]	valid_0's auc: 0.72348
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's auc: 0.745764
# [3]	valid_0's auc: 0.761432
# [4]	valid_0's auc: 0.760827
# [5]	valid_0's auc: 0.768095
# [6]	valid_0's auc: 0.772227
# [7]	valid_0's auc: 0.774151
# [8]	valid_0's auc: 0.777755
# [9]	valid_0's auc: 0.780481
# [10]	valid_0's auc: 0.781946
# [11]	valid_0's auc: 0.782711
# [12]	valid_0's auc: 0.78387
# [13]	valid_0's auc: 0.783515
# [14]	valid_0's auc: 0.783666
# [15]	valid_0's auc: 0.784659
# [16]	valid_0's auc: 0.785062
# [17]	valid_0's auc: 0.785744
# [18]	valid_0's auc: 0.786606
# [19]	valid_0's auc: 0.787059
# [20]	valid_0's auc: 0.787543
# [21]	valid_0's auc: 0.788446
# [22]	valid_0's auc: 0.788323
# [23]	valid_0's auc: 0.788941
# [24]	valid_0's auc: 0.789476
# [25]	valid_0's auc: 0.789406
# [26]	valid_0's auc: 0.789901
# [27]	valid_0's auc: 0.789665
# [28]	valid_0's auc: 0.790416
# [29]	valid_0's auc: 0.790723
# [30]	valid_0's auc: 0.791317
# [31]	valid_0's auc: 0.791494
# [32]	valid_0's auc: 0.791826
# [33]	valid_0's auc: 0.791982
# [34]	valid_0's auc: 0.79238
# [35]	valid_0's auc: 0.792812
# [36]	valid_0's auc: 0.792976
# [37]	valid_0's auc: 0.793423
# [38]	valid_0's auc: 0.793643
# [39]	valid_0's auc: 0.793753
# [40]	valid_0's auc: 0.794263
# [41]	valid_0's auc: 0.794713
# [42]	valid_0's auc: 0.79496
# [43]	valid_0's auc: 0.795263
# [44]	valid_0's auc: 0.795334
# [45]	valid_0's auc: 0.795829
# [46]	valid_0's auc: 0.796281
# [47]	valid_0's auc: 0.79662
# [48]	valid_0's auc: 0.79718
# [49]	valid_0's auc: 0.797607
# [50]	valid_0's auc: 0.797874
# [51]	valid_0's auc: 0.798124
# [52]	valid_0's auc: 0.79849
# [53]	valid_0's auc: 0.798808
# [54]	valid_0's auc: 0.799182
# [55]	valid_0's auc: 0.799336
# [56]	valid_0's auc: 0.799632
# [57]	valid_0's auc: 0.799916
# [58]	valid_0's auc: 0.800113
# [59]	valid_0's auc: 0.800358
# [60]	valid_0's auc: 0.80061
# [61]	valid_0's auc: 0.800708
# [62]	valid_0's auc: 0.801096
# [63]	valid_0's auc: 0.801138
# [64]	valid_0's auc: 0.801376
# [65]	valid_0's auc: 0.801476
# [66]	valid_0's auc: 0.801521
# [67]	valid_0's auc: 0.801844
# [68]	valid_0's auc: 0.802004
# [69]	valid_0's auc: 0.802016
# [70]	valid_0's auc: 0.802234
# [71]	valid_0's auc: 0.802272
# [72]	valid_0's auc: 0.802471
# [73]	valid_0's auc: 0.802783
# [74]	valid_0's auc: 0.802946
# [75]	valid_0's auc: 0.803126
# [76]	valid_0's auc: 0.803319
# [77]	valid_0's auc: 0.803537
# [78]	valid_0's auc: 0.803675
# [79]	valid_0's auc: 0.80386
# [80]	valid_0's auc: 0.804192
# [81]	valid_0's auc: 0.804484
# [82]	valid_0's auc: 0.804482
# [83]	valid_0's auc: 0.804674
# [84]	valid_0's auc: 0.804884
# [85]	valid_0's auc: 0.805119
# [86]	valid_0's auc: 0.805281
# [87]	valid_0's auc: 0.805416
# [88]	valid_0's auc: 0.805578
# [89]	valid_0's auc: 0.80558
# [90]	valid_0's auc: 0.80568
# [91]	valid_0's auc: 0.805771
# [92]	valid_0's auc: 0.805977
# [93]	valid_0's auc: 0.806082
# [94]	valid_0's auc: 0.806227
# [95]	valid_0's auc: 0.806219
# [96]	valid_0's auc: 0.806515
# [97]	valid_0's auc: 0.8067
# [98]	valid_0's auc: 0.806853
# [99]	valid_0's auc: 0.806957
# [100]	valid_0's auc: 0.807124
# [101]	valid_0's auc: 0.807193
# [102]	valid_0's auc: 0.807335
# [103]	valid_0's auc: 0.807469
# [104]	valid_0's auc: 0.807673
# [105]	valid_0's auc: 0.807864
# [106]	valid_0's auc: 0.808013
# [107]	valid_0's auc: 0.808197
# [108]	valid_0's auc: 0.808189
# [109]	valid_0's auc: 0.808382
# [110]	valid_0's auc: 0.808487
# [111]	valid_0's auc: 0.80852
# [112]	valid_0's auc: 0.80869
# [113]	valid_0's auc: 0.808893
# [114]	valid_0's auc: 0.809137
# [115]	valid_0's auc: 0.809335
# [116]	valid_0's auc: 0.809495
# [117]	valid_0's auc: 0.809634
# [118]	valid_0's auc: 0.809776
# [119]	valid_0's auc: 0.809878
# [120]	valid_0's auc: 0.809948
# [121]	valid_0's auc: 0.810168
# [122]	valid_0's auc: 0.810378
# [123]	valid_0's auc: 0.810582
# [124]	valid_0's auc: 0.810753
# [125]	valid_0's auc: 0.810912
# [126]	valid_0's auc: 0.811048
# [127]	valid_0's auc: 0.811041
# [128]	valid_0's auc: 0.81115
# [129]	valid_0's auc: 0.811249
# [130]	valid_0's auc: 0.811444
# [131]	valid_0's auc: 0.811482
# [132]	valid_0's auc: 0.811573
# [133]	valid_0's auc: 0.811596
# [134]	valid_0's auc: 0.811732
# [135]	valid_0's auc: 0.811787
# [136]	valid_0's auc: 0.811835
# [137]	valid_0's auc: 0.811895
# [138]	valid_0's auc: 0.81192
# [139]	valid_0's auc: 0.811851
# [140]	valid_0's auc: 0.811924
# [141]	valid_0's auc: 0.811985
# [142]	valid_0's auc: 0.81194
# [143]	valid_0's auc: 0.811955
# [144]	valid_0's auc: 0.812058
# [145]	valid_0's auc: 0.812123
# [146]	valid_0's auc: 0.812221
# [147]	valid_0's auc: 0.812295
# [148]	valid_0's auc: 0.812325
# [149]	valid_0's auc: 0.81233
# [150]	valid_0's auc: 0.812478
# [151]	valid_0's auc: 0.812553
# [152]	valid_0's auc: 0.812568
# [153]	valid_0's auc: 0.812706
# [154]	valid_0's auc: 0.812732
# [155]	valid_0's auc: 0.81269
# [156]	valid_0's auc: 0.812805
# [157]	valid_0's auc: 0.812848
# [158]	valid_0's auc: 0.812939
# [159]	valid_0's auc: 0.813059
# [160]	valid_0's auc: 0.813136
# [161]	valid_0's auc: 0.813184
# [162]	valid_0's auc: 0.813243
# [163]	valid_0's auc: 0.81334
# [164]	valid_0's auc: 0.813428
# [165]	valid_0's auc: 0.813559
# [166]	valid_0's auc: 0.813711
# [167]	valid_0's auc: 0.813824
# [168]	valid_0's auc: 0.813847
# [169]	valid_0's auc: 0.814012
# [170]	valid_0's auc: 0.814059
# [171]	valid_0's auc: 0.814153
# [172]	valid_0's auc: 0.8143
# [173]	valid_0's auc: 0.814352
# [174]	valid_0's auc: 0.814494
# [175]	valid_0's auc: 0.814603
# [176]	valid_0's auc: 0.814693
# [177]	valid_0's auc: 0.814718
# [178]	valid_0's auc: 0.814836
# [179]	valid_0's auc: 0.81493
# [180]	valid_0's auc: 0.815001
# [181]	valid_0's auc: 0.815052
# [182]	valid_0's auc: 0.815116
# [183]	valid_0's auc: 0.81519
# [184]	valid_0's auc: 0.815263
# [185]	valid_0's auc: 0.815394
# [186]	valid_0's auc: 0.815452
# [187]	valid_0's auc: 0.815474
# [188]	valid_0's auc: 0.815507
# [189]	valid_0's auc: 0.815476
# [190]	valid_0's auc: 0.81551
# [191]	valid_0's auc: 0.81555
# [192]	valid_0's auc: 0.815622
# [193]	valid_0's auc: 0.815646
# [194]	valid_0's auc: 0.815738
# [195]	valid_0's auc: 0.815857
# [196]	valid_0's auc: 0.815895
# [197]	valid_0's auc: 0.815994
# [198]	valid_0's auc: 0.816043
# [199]	valid_0's auc: 0.816104
# [200]	valid_0's auc: 0.816067
# Did not meet early stopping. Best iteration is:
# [199]	valid_0's auc: 0.816104
# |  4        |  0.8161   |  0.9506   |  18.42    |  0.634    |  0.008772 |  9.246    |  90.25    |  4.917    |  21.06    |
# [1]	valid_0's auc: 0.730855
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's auc: 0.753138
# [3]	valid_0's auc: 0.760606
# [4]	valid_0's auc: 0.767149
# [5]	valid_0's auc: 0.773672
# [6]	valid_0's auc: 0.777416
# [7]	valid_0's auc: 0.779679
# [8]	valid_0's auc: 0.781189
# [9]	valid_0's auc: 0.784274
# [10]	valid_0's auc: 0.785025
# [11]	valid_0's auc: 0.786752
# [12]	valid_0's auc: 0.788729
# [13]	valid_0's auc: 0.79082
# [14]	valid_0's auc: 0.791637
# [15]	valid_0's auc: 0.793449
# [16]	valid_0's auc: 0.793651
# [17]	valid_0's auc: 0.795917
# [18]	valid_0's auc: 0.797717
# [19]	valid_0's auc: 0.798734
# [20]	valid_0's auc: 0.798946
# [21]	valid_0's auc: 0.799446
# [22]	valid_0's auc: 0.800671
# [23]	valid_0's auc: 0.801407
# [24]	valid_0's auc: 0.801695
# [25]	valid_0's auc: 0.802247
# [26]	valid_0's auc: 0.803154
# [27]	valid_0's auc: 0.803545
# [28]	valid_0's auc: 0.804394
# [29]	valid_0's auc: 0.804582
# [30]	valid_0's auc: 0.805461
# [31]	valid_0's auc: 0.805211
# [32]	valid_0's auc: 0.806018
# [33]	valid_0's auc: 0.806442
# [34]	valid_0's auc: 0.806542
# [35]	valid_0's auc: 0.806721
# [36]	valid_0's auc: 0.80728
# [37]	valid_0's auc: 0.80735
# [38]	valid_0's auc: 0.807614
# [39]	valid_0's auc: 0.807976
# [40]	valid_0's auc: 0.808231
# [41]	valid_0's auc: 0.808627
# [42]	valid_0's auc: 0.808778
# [43]	valid_0's auc: 0.80916
# [44]	valid_0's auc: 0.809368
# [45]	valid_0's auc: 0.809508
# [46]	valid_0's auc: 0.809703
# [47]	valid_0's auc: 0.809862
# [48]	valid_0's auc: 0.810249
# [49]	valid_0's auc: 0.810436
# [50]	valid_0's auc: 0.810821
# [51]	valid_0's auc: 0.811326
# [52]	valid_0's auc: 0.811414
# [53]	valid_0's auc: 0.811478
# [54]	valid_0's auc: 0.811542
# [55]	valid_0's auc: 0.811476
# [56]	valid_0's auc: 0.811733
# [57]	valid_0's auc: 0.812
# [58]	valid_0's auc: 0.812052
# [59]	valid_0's auc: 0.812132
# [60]	valid_0's auc: 0.81226
# [61]	valid_0's auc: 0.812473
# [62]	valid_0's auc: 0.812744
# [63]	valid_0's auc: 0.812853
# [64]	valid_0's auc: 0.812989
# [65]	valid_0's auc: 0.812957
# [66]	valid_0's auc: 0.812918
# [67]	valid_0's auc: 0.813177
# [68]	valid_0's auc: 0.813116
# [69]	valid_0's auc: 0.813343
# [70]	valid_0's auc: 0.813379
# [71]	valid_0's auc: 0.813227
# [72]	valid_0's auc: 0.813327
# [73]	valid_0's auc: 0.813442
# [74]	valid_0's auc: 0.813698
# [75]	valid_0's auc: 0.813938
# [76]	valid_0's auc: 0.813938
# [77]	valid_0's auc: 0.813766
# [78]	valid_0's auc: 0.813737
# [79]	valid_0's auc: 0.813855
# [80]	valid_0's auc: 0.813769
# [81]	valid_0's auc: 0.814047
# [82]	valid_0's auc: 0.813925
# [83]	valid_0's auc: 0.813865
# [84]	valid_0's auc: 0.813875
# [85]	valid_0's auc: 0.813865
# [86]	valid_0's auc: 0.813729
# [87]	valid_0's auc: 0.813753
# [88]	valid_0's auc: 0.813582
# [89]	valid_0's auc: 0.813573
# [90]	valid_0's auc: 0.813535
# [91]	valid_0's auc: 0.813562
# [92]	valid_0's auc: 0.813463
# [93]	valid_0's auc: 0.813459
# [94]	valid_0's auc: 0.813624
# [95]	valid_0's auc: 0.8137
# [96]	valid_0's auc: 0.813471
# [97]	valid_0's auc: 0.813506
# [98]	valid_0's auc: 0.813557
# [99]	valid_0's auc: 0.813515
# [100]	valid_0's auc: 0.813586
# [101]	valid_0's auc: 0.813447
# [102]	valid_0's auc: 0.813294
# [103]	valid_0's auc: 0.813202
# [104]	valid_0's auc: 0.813118
# [105]	valid_0's auc: 0.812898
# [106]	valid_0's auc: 0.812867
# [107]	valid_0's auc: 0.812842
# [108]	valid_0's auc: 0.812611
# [109]	valid_0's auc: 0.812643
# [110]	valid_0's auc: 0.812638
# [111]	valid_0's auc: 0.812437
# [112]	valid_0's auc: 0.812248
# [113]	valid_0's auc: 0.812387
# [114]	valid_0's auc: 0.812435
# [115]	valid_0's auc: 0.812166
# [116]	valid_0's auc: 0.81208
# [117]	valid_0's auc: 0.812004
# [118]	valid_0's auc: 0.811893
# [119]	valid_0's auc: 0.811879
# [120]	valid_0's auc: 0.811848
# [121]	valid_0's auc: 0.811851
# [122]	valid_0's auc: 0.811734
# [123]	valid_0's auc: 0.811721
# [124]	valid_0's auc: 0.81171
# [125]	valid_0's auc: 0.811788
# [126]	valid_0's auc: 0.811608
# [127]	valid_0's auc: 0.811651
# [128]	valid_0's auc: 0.811405
# [129]	valid_0's auc: 0.81142
# [130]	valid_0's auc: 0.811436
# [131]	valid_0's auc: 0.81138
# Early stopping, best iteration is:
# [81]	valid_0's auc: 0.814047
# |  5        |  0.814    |  0.9832   |  13.0     |  0.8768   |  0.06379  |  22.16    |  86.77    |  0.9144   |  37.51    |
# [1]	valid_0's auc: 0.728392
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's auc: 0.753109
# [3]	valid_0's auc: 0.763971
# [4]	valid_0's auc: 0.765163
# [5]	valid_0's auc: 0.771282
# [6]	valid_0's auc: 0.775348
# [7]	valid_0's auc: 0.778702
# [8]	valid_0's auc: 0.782101
# [9]	valid_0's auc: 0.784253
# [10]	valid_0's auc: 0.785134
# [11]	valid_0's auc: 0.786928
# [12]	valid_0's auc: 0.787956
# [13]	valid_0's auc: 0.788806
# [14]	valid_0's auc: 0.790408
# [15]	valid_0's auc: 0.79084
# [16]	valid_0's auc: 0.791931
# [17]	valid_0's auc: 0.791612
# [18]	valid_0's auc: 0.792188
# [19]	valid_0's auc: 0.792429
# [20]	valid_0's auc: 0.792423
# [21]	valid_0's auc: 0.792773
# [22]	valid_0's auc: 0.793191
# [23]	valid_0's auc: 0.792927
# [24]	valid_0's auc: 0.793191
# [25]	valid_0's auc: 0.793462
# [26]	valid_0's auc: 0.793935
# [27]	valid_0's auc: 0.794054
# [28]	valid_0's auc: 0.793969
# [29]	valid_0's auc: 0.794063
# [30]	valid_0's auc: 0.794192
# [31]	valid_0's auc: 0.794574
# [32]	valid_0's auc: 0.794696
# [33]	valid_0's auc: 0.795242
# [34]	valid_0's auc: 0.79582
# [35]	valid_0's auc: 0.796055
# [36]	valid_0's auc: 0.796151
# [37]	valid_0's auc: 0.796204
# [38]	valid_0's auc: 0.795875
# [39]	valid_0's auc: 0.796186
# [40]	valid_0's auc: 0.795745
# [41]	valid_0's auc: 0.796021
# [42]	valid_0's auc: 0.796525
# [43]	valid_0's auc: 0.796778
# [44]	valid_0's auc: 0.796784
# [45]	valid_0's auc: 0.796625
# [46]	valid_0's auc: 0.796727
# [47]	valid_0's auc: 0.796351
# [48]	valid_0's auc: 0.79608
# [49]	valid_0's auc: 0.796036
# [50]	valid_0's auc: 0.796517
# [51]	valid_0's auc: 0.796681
# [52]	valid_0's auc: 0.796672
# [53]	valid_0's auc: 0.797094
# [54]	valid_0's auc: 0.79709
# [55]	valid_0's auc: 0.796876
# [56]	valid_0's auc: 0.797009
# [57]	valid_0's auc: 0.797026
# [58]	valid_0's auc: 0.797312
# [59]	valid_0's auc: 0.796853
# [60]	valid_0's auc: 0.796645
# [61]	valid_0's auc: 0.796658
# [62]	valid_0's auc: 0.796768
# [63]	valid_0's auc: 0.796891
# [64]	valid_0's auc: 0.796973
# [65]	valid_0's auc: 0.796792
# [66]	valid_0's auc: 0.797035
# [67]	valid_0's auc: 0.797093
# [68]	valid_0's auc: 0.796918
# [69]	valid_0's auc: 0.796631
# [70]	valid_0's auc: 0.796438
# [71]	valid_0's auc: 0.796614
# [72]	valid_0's auc: 0.796706
# [73]	valid_0's auc: 0.796763
# [74]	valid_0's auc: 0.79674
# [75]	valid_0's auc: 0.79635
# [76]	valid_0's auc: 0.796202
# [77]	valid_0's auc: 0.796184
# [78]	valid_0's auc: 0.796005
# [79]	valid_0's auc: 0.795918
# [80]	valid_0's auc: 0.796021
# [81]	valid_0's auc: 0.796265
# [82]	valid_0's auc: 0.795992
# [83]	valid_0's auc: 0.796148
# [84]	valid_0's auc: 0.796113
# [85]	valid_0's auc: 0.795945
# [86]	valid_0's auc: 0.795929
# [87]	valid_0's auc: 0.796094
# [88]	valid_0's auc: 0.795815
# [89]	valid_0's auc: 0.795618
# [90]	valid_0's auc: 0.795676
# [91]	valid_0's auc: 0.795857
# [92]	valid_0's auc: 0.795933
# [93]	valid_0's auc: 0.796167
# [94]	valid_0's auc: 0.796241
# [95]	valid_0's auc: 0.796074
# [96]	valid_0's auc: 0.796046
# [97]	valid_0's auc: 0.796002
# [98]	valid_0's auc: 0.796304
# [99]	valid_0's auc: 0.79613
# [100]	valid_0's auc: 0.796073
# [101]	valid_0's auc: 0.795902
# [102]	valid_0's auc: 0.795907
# [103]	valid_0's auc: 0.795859
# [104]	valid_0's auc: 0.795592
# [105]	valid_0's auc: 0.795569
# [106]	valid_0's auc: 0.795619
# [107]	valid_0's auc: 0.795287
# [108]	valid_0's auc: 0.795487
# Early stopping, best iteration is:
# [58]	valid_0's auc: 0.797312
# |  6        |  0.7973   |  0.9955   |  16.22    |  0.7122   |  0.1581   |  7.581    |  55.83    |  45.43    |  14.68    |
# [1]	valid_0's auc: 0.740322
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's auc: 0.747856
# [3]	valid_0's auc: 0.749746
# [4]	valid_0's auc: 0.752901
# [5]	valid_0's auc: 0.756315
# [6]	valid_0's auc: 0.760089
# [7]	valid_0's auc: 0.762278
# [8]	valid_0's auc: 0.767058
# [9]	valid_0's auc: 0.767246
# [10]	valid_0's auc: 0.767602
# [11]	valid_0's auc: 0.768488
# [12]	valid_0's auc: 0.769708
# [13]	valid_0's auc: 0.771544
# [14]	valid_0's auc: 0.772509
# [15]	valid_0's auc: 0.773749
# [16]	valid_0's auc: 0.775552
# [17]	valid_0's auc: 0.775321
# [18]	valid_0's auc: 0.776241
# [19]	valid_0's auc: 0.777039
# [20]	valid_0's auc: 0.777448
# [21]	valid_0's auc: 0.778921
# [22]	valid_0's auc: 0.779909
# [23]	valid_0's auc: 0.781278
# [24]	valid_0's auc: 0.781328
# [25]	valid_0's auc: 0.78188
# [26]	valid_0's auc: 0.782241
# [27]	valid_0's auc: 0.782054
# [28]	valid_0's auc: 0.782498
# [29]	valid_0's auc: 0.783617
# [30]	valid_0's auc: 0.783355
# [31]	valid_0's auc: 0.784313
# [32]	valid_0's auc: 0.783957
# [33]	valid_0's auc: 0.78478
# [34]	valid_0's auc: 0.784489
# [35]	valid_0's auc: 0.784638
# [36]	valid_0's auc: 0.78487
# [37]	valid_0's auc: 0.784759
# [38]	valid_0's auc: 0.785629
# [39]	valid_0's auc: 0.785762
# [40]	valid_0's auc: 0.786025
# [41]	valid_0's auc: 0.78644
# [42]	valid_0's auc: 0.786578
# [43]	valid_0's auc: 0.786605
# [44]	valid_0's auc: 0.786706
# [45]	valid_0's auc: 0.785075
# [46]	valid_0's auc: 0.78522
# [47]	valid_0's auc: 0.785236
# [48]	valid_0's auc: 0.785318
# [49]	valid_0's auc: 0.785353
# [50]	valid_0's auc: 0.785392
# [51]	valid_0's auc: 0.785559
# [52]	valid_0's auc: 0.78511
# [53]	valid_0's auc: 0.785019
# [54]	valid_0's auc: 0.784652
# [55]	valid_0's auc: 0.784605
# [56]	valid_0's auc: 0.784761
# [57]	valid_0's auc: 0.7846
# [58]	valid_0's auc: 0.784645
# [59]	valid_0's auc: 0.785297
# [60]	valid_0's auc: 0.784957
# [61]	valid_0's auc: 0.784777
# [62]	valid_0's auc: 0.784807
# [63]	valid_0's auc: 0.784517
# [64]	valid_0's auc: 0.784504
# [65]	valid_0's auc: 0.785271
# [66]	valid_0's auc: 0.785333
# [67]	valid_0's auc: 0.78545
# [68]	valid_0's auc: 0.785012
# [69]	valid_0's auc: 0.7854
# [70]	valid_0's auc: 0.785331
# [71]	valid_0's auc: 0.785936
# [72]	valid_0's auc: 0.786169
# [73]	valid_0's auc: 0.786442
# [74]	valid_0's auc: 0.786285
# [75]	valid_0's auc: 0.786468
# [76]	valid_0's auc: 0.786264
# [77]	valid_0's auc: 0.786246
# [78]	valid_0's auc: 0.786096
# [79]	valid_0's auc: 0.78633
# [80]	valid_0's auc: 0.7864
# [81]	valid_0's auc: 0.786094
# [82]	valid_0's auc: 0.785639
# [83]	valid_0's auc: 0.785604
# [84]	valid_0's auc: 0.785771
# [85]	valid_0's auc: 0.785739
# [86]	valid_0's auc: 0.785633
# [87]	valid_0's auc: 0.785336
# [88]	valid_0's auc: 0.785267
# [89]	valid_0's auc: 0.784952
# [90]	valid_0's auc: 0.785022
# [91]	valid_0's auc: 0.784461
# [92]	valid_0's auc: 0.784463
# [93]	valid_0's auc: 0.78364
# [94]	valid_0's auc: 0.783955
# Early stopping, best iteration is:
# [44]	valid_0's auc: 0.786706
# |  7        |  0.7867   |  0.7151   |  6.95     |  0.6077   |  0.1361   |  10.29    |  41.24    |  24.58    |  2.668    |
# [1]	valid_0's auc: 0.726387
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's auc: 0.754792
# [3]	valid_0's auc: 0.762611
# [4]	valid_0's auc: 0.76653
# [5]	valid_0's auc: 0.770876
# [6]	valid_0's auc: 0.774334
# [7]	valid_0's auc: 0.776951
# [8]	valid_0's auc: 0.778769
# [9]	valid_0's auc: 0.780821
# [10]	valid_0's auc: 0.783178
# [11]	valid_0's auc: 0.784882
# [12]	valid_0's auc: 0.787025
# [13]	valid_0's auc: 0.78851
# [14]	valid_0's auc: 0.789746
# [15]	valid_0's auc: 0.791536
# [16]	valid_0's auc: 0.792675
# [17]	valid_0's auc: 0.793131
# [18]	valid_0's auc: 0.794055
# [19]	valid_0's auc: 0.795165
# [20]	valid_0's auc: 0.795777
# [21]	valid_0's auc: 0.796259
# [22]	valid_0's auc: 0.796796
# [23]	valid_0's auc: 0.797147
# [24]	valid_0's auc: 0.797112
# [25]	valid_0's auc: 0.797434
# [26]	valid_0's auc: 0.797609
# [27]	valid_0's auc: 0.798193
# [28]	valid_0's auc: 0.79861
# [29]	valid_0's auc: 0.799079
# [30]	valid_0's auc: 0.800305
# [31]	valid_0's auc: 0.801943
# [32]	valid_0's auc: 0.802142
# [33]	valid_0's auc: 0.80261
# [34]	valid_0's auc: 0.802577
# [35]	valid_0's auc: 0.802567
# [36]	valid_0's auc: 0.803238
# [37]	valid_0's auc: 0.803329
# [38]	valid_0's auc: 0.803334
# [39]	valid_0's auc: 0.802991
# [40]	valid_0's auc: 0.803356
# [41]	valid_0's auc: 0.803127
# [42]	valid_0's auc: 0.802986
# [43]	valid_0's auc: 0.803477
# [44]	valid_0's auc: 0.802971
# [45]	valid_0's auc: 0.803174
# [46]	valid_0's auc: 0.803174
# [47]	valid_0's auc: 0.803008
# [48]	valid_0's auc: 0.802775
# [49]	valid_0's auc: 0.802248
# [50]	valid_0's auc: 0.802445
# [51]	valid_0's auc: 0.803016
# [52]	valid_0's auc: 0.80365
# [53]	valid_0's auc: 0.803932
# [54]	valid_0's auc: 0.803945
# [55]	valid_0's auc: 0.804317
# [56]	valid_0's auc: 0.804575
# [57]	valid_0's auc: 0.804484
# [58]	valid_0's auc: 0.804035
# [59]	valid_0's auc: 0.803657
# [60]	valid_0's auc: 0.803897
# [61]	valid_0's auc: 0.803781
# [62]	valid_0's auc: 0.803961
# [63]	valid_0's auc: 0.804048
# [64]	valid_0's auc: 0.803801
# [65]	valid_0's auc: 0.803554
# [66]	valid_0's auc: 0.803137
# [67]	valid_0's auc: 0.803125
# [68]	valid_0's auc: 0.802984
# [69]	valid_0's auc: 0.803203
# [70]	valid_0's auc: 0.803425
# [71]	valid_0's auc: 0.803263
# [72]	valid_0's auc: 0.80347
# [73]	valid_0's auc: 0.803411
# [74]	valid_0's auc: 0.803255
# [75]	valid_0's auc: 0.803323
# [76]	valid_0's auc: 0.803551
# [77]	valid_0's auc: 0.803023
# [78]	valid_0's auc: 0.802917
# [79]	valid_0's auc: 0.803042
# [80]	valid_0's auc: 0.802896
# [81]	valid_0's auc: 0.802691
# [82]	valid_0's auc: 0.802702
# [83]	valid_0's auc: 0.802665
# [84]	valid_0's auc: 0.802323
# [85]	valid_0's auc: 0.80208
# [86]	valid_0's auc: 0.801702
# [87]	valid_0's auc: 0.801533
# [88]	valid_0's auc: 0.801586
# [89]	valid_0's auc: 0.801226
# [90]	valid_0's auc: 0.801475
# [91]	valid_0's auc: 0.801363
# [92]	valid_0's auc: 0.80152
# [93]	valid_0's auc: 0.801652
# [94]	valid_0's auc: 0.802154
# [95]	valid_0's auc: 0.80223
# [96]	valid_0's auc: 0.802149
# [97]	valid_0's auc: 0.802168
# [98]	valid_0's auc: 0.802125
# [99]	valid_0's auc: 0.801965
# [100]	valid_0's auc: 0.801747
# [101]	valid_0's auc: 0.801614
# [102]	valid_0's auc: 0.801729
# [103]	valid_0's auc: 0.801524
# [104]	valid_0's auc: 0.80173
# [105]	valid_0's auc: 0.801917
# [106]	valid_0's auc: 0.801717
# Early stopping, best iteration is:
# [56]	valid_0's auc: 0.804575
# |  8        |  0.8046   |  0.8296   |  7.201    |  0.8357   |  0.1403   |  7.558    |  53.12    |  34.72    |  20.71    |
# [1]	valid_0's auc: 0.722945
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's auc: 0.743418
# [3]	valid_0's auc: 0.752516
# [4]	valid_0's auc: 0.753936
# [5]	valid_0's auc: 0.758295
# [6]	valid_0's auc: 0.760734
# [7]	valid_0's auc: 0.763002
# [8]	valid_0's auc: 0.764837
# [9]	valid_0's auc: 0.766669
# [10]	valid_0's auc: 0.767058
# [11]	valid_0's auc: 0.767913
# [12]	valid_0's auc: 0.768556
# [13]	valid_0's auc: 0.769756
# [14]	valid_0's auc: 0.772084
# [15]	valid_0's auc: 0.772873
# [16]	valid_0's auc: 0.773294
# [17]	valid_0's auc: 0.774509
# [18]	valid_0's auc: 0.776364
# [19]	valid_0's auc: 0.776846
# [20]	valid_0's auc: 0.777328
# [21]	valid_0's auc: 0.778332
# [22]	valid_0's auc: 0.778942
# [23]	valid_0's auc: 0.779147
# [24]	valid_0's auc: 0.779298
# [25]	valid_0's auc: 0.780257
# [26]	valid_0's auc: 0.781528
# [27]	valid_0's auc: 0.782107
# [28]	valid_0's auc: 0.782097
# [29]	valid_0's auc: 0.782431
# [30]	valid_0's auc: 0.783106
# [31]	valid_0's auc: 0.783349
# [32]	valid_0's auc: 0.783477
# [33]	valid_0's auc: 0.783657
# [34]	valid_0's auc: 0.783616
# [35]	valid_0's auc: 0.783679
# [36]	valid_0's auc: 0.784174
# [37]	valid_0's auc: 0.783612
# [38]	valid_0's auc: 0.784389
# [39]	valid_0's auc: 0.78423
# [40]	valid_0's auc: 0.7844
# [41]	valid_0's auc: 0.78542
# [42]	valid_0's auc: 0.785952
# [43]	valid_0's auc: 0.786445
# [44]	valid_0's auc: 0.786417
# [45]	valid_0's auc: 0.786796
# [46]	valid_0's auc: 0.787391
# [47]	valid_0's auc: 0.787922
# [48]	valid_0's auc: 0.788413
# [49]	valid_0's auc: 0.789544
# [50]	valid_0's auc: 0.789665
# [51]	valid_0's auc: 0.789444
# [52]	valid_0's auc: 0.789726
# [53]	valid_0's auc: 0.790575
# [54]	valid_0's auc: 0.790777
# [55]	valid_0's auc: 0.790815
# [56]	valid_0's auc: 0.791245
# [57]	valid_0's auc: 0.791865
# [58]	valid_0's auc: 0.792115
# [59]	valid_0's auc: 0.792164
# [60]	valid_0's auc: 0.792237
# [61]	valid_0's auc: 0.792253
# [62]	valid_0's auc: 0.792048
# [63]	valid_0's auc: 0.792277
# [64]	valid_0's auc: 0.791905
# [65]	valid_0's auc: 0.791818
# [66]	valid_0's auc: 0.792155
# [67]	valid_0's auc: 0.792516
# [68]	valid_0's auc: 0.792265
# [69]	valid_0's auc: 0.792417
# [70]	valid_0's auc: 0.792468
# [71]	valid_0's auc: 0.792493
# [72]	valid_0's auc: 0.792236
# [73]	valid_0's auc: 0.792284
# [74]	valid_0's auc: 0.792419
# [75]	valid_0's auc: 0.792553
# [76]	valid_0's auc: 0.792451
# [77]	valid_0's auc: 0.792284
# [78]	valid_0's auc: 0.79236
# [79]	valid_0's auc: 0.792322
# [80]	valid_0's auc: 0.792774
# [81]	valid_0's auc: 0.79303
# [82]	valid_0's auc: 0.793094
# [83]	valid_0's auc: 0.793308
# [84]	valid_0's auc: 0.793407
# [85]	valid_0's auc: 0.793505
# [86]	valid_0's auc: 0.793742
# [87]	valid_0's auc: 0.793905
# [88]	valid_0's auc: 0.793942
# [89]	valid_0's auc: 0.794007
# [90]	valid_0's auc: 0.794603
# [91]	valid_0's auc: 0.794462
# [92]	valid_0's auc: 0.794463
# [93]	valid_0's auc: 0.794733
# [94]	valid_0's auc: 0.794964
# [95]	valid_0's auc: 0.795278
# [96]	valid_0's auc: 0.795481
# [97]	valid_0's auc: 0.794974
# [98]	valid_0's auc: 0.795155
# [99]	valid_0's auc: 0.795402
# [100]	valid_0's auc: 0.795661
# [101]	valid_0's auc: 0.795668
# [102]	valid_0's auc: 0.796312
# [103]	valid_0's auc: 0.796319
# [104]	valid_0's auc: 0.796264
# [105]	valid_0's auc: 0.795629
# [106]	valid_0's auc: 0.795238
# [107]	valid_0's auc: 0.795105
# [108]	valid_0's auc: 0.79483
# [109]	valid_0's auc: 0.794726
# [110]	valid_0's auc: 0.794242
# [111]	valid_0's auc: 0.794179
# [112]	valid_0's auc: 0.794182
# [113]	valid_0's auc: 0.793914
# [114]	valid_0's auc: 0.793691
# [115]	valid_0's auc: 0.793585
# [116]	valid_0's auc: 0.793177
# [117]	valid_0's auc: 0.792913
# [118]	valid_0's auc: 0.792531
# [119]	valid_0's auc: 0.792552
# [120]	valid_0's auc: 0.792645
# [121]	valid_0's auc: 0.792534
# [122]	valid_0's auc: 0.792406
# [123]	valid_0's auc: 0.792303
# [124]	valid_0's auc: 0.792588
# [125]	valid_0's auc: 0.792523
# [126]	valid_0's auc: 0.792546
# [127]	valid_0's auc: 0.792532
# [128]	valid_0's auc: 0.792342
# [129]	valid_0's auc: 0.792545
# [130]	valid_0's auc: 0.792498
# [131]	valid_0's auc: 0.792679
# [132]	valid_0's auc: 0.792852
# [133]	valid_0's auc: 0.792768
# [134]	valid_0's auc: 0.793018
# [135]	valid_0's auc: 0.792903
# [136]	valid_0's auc: 0.793212
# [137]	valid_0's auc: 0.793286
# [138]	valid_0's auc: 0.793141
# [139]	valid_0's auc: 0.79305
# [140]	valid_0's auc: 0.792863
# [141]	valid_0's auc: 0.792639
# [142]	valid_0's auc: 0.792585
# [143]	valid_0's auc: 0.792565
# [144]	valid_0's auc: 0.792633
# [145]	valid_0's auc: 0.792677
# [146]	valid_0's auc: 0.792579
# [147]	valid_0's auc: 0.792488
# [148]	valid_0's auc: 0.792794
# [149]	valid_0's auc: 0.792905
# [150]	valid_0's auc: 0.792922
# [151]	valid_0's auc: 0.792815
# [152]	valid_0's auc: 0.79292
# [153]	valid_0's auc: 0.793051
# Early stopping, best iteration is:
# [103]	valid_0's auc: 0.796319
# |  9        |  0.7963   |  0.62     |  13.04    |  0.8655   |  0.1035   |  28.61    |  66.92    |  45.17    |  6.874    |
# [1]	valid_0's auc: 0.715367
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's auc: 0.745092
# [3]	valid_0's auc: 0.74996
# [4]	valid_0's auc: 0.764118
# [5]	valid_0's auc: 0.767451
# [6]	valid_0's auc: 0.774555
# [7]	valid_0's auc: 0.774723
# [8]	valid_0's auc: 0.776007
# [9]	valid_0's auc: 0.779393
# [10]	valid_0's auc: 0.779825
# [11]	valid_0's auc: 0.78166
# [12]	valid_0's auc: 0.78153
# [13]	valid_0's auc: 0.780877
# [14]	valid_0's auc: 0.782557
# [15]	valid_0's auc: 0.783199
# [16]	valid_0's auc: 0.784134
# [17]	valid_0's auc: 0.783998
# [18]	valid_0's auc: 0.784844
# [19]	valid_0's auc: 0.785691
# [20]	valid_0's auc: 0.786096
# [21]	valid_0's auc: 0.787512
# [22]	valid_0's auc: 0.7881
# [23]	valid_0's auc: 0.789444
# [24]	valid_0's auc: 0.789666
# [25]	valid_0's auc: 0.790745
# [26]	valid_0's auc: 0.791805
# [27]	valid_0's auc: 0.792154
# [28]	valid_0's auc: 0.792983
# [29]	valid_0's auc: 0.793179
# [30]	valid_0's auc: 0.794255
# [31]	valid_0's auc: 0.795183
# [32]	valid_0's auc: 0.795994
# [33]	valid_0's auc: 0.796493
# [34]	valid_0's auc: 0.797252
# [35]	valid_0's auc: 0.797867
# [36]	valid_0's auc: 0.798014
# [37]	valid_0's auc: 0.798433
# [38]	valid_0's auc: 0.798762
# [39]	valid_0's auc: 0.799288
# [40]	valid_0's auc: 0.79966
# [41]	valid_0's auc: 0.799499
# [42]	valid_0's auc: 0.799394
# [43]	valid_0's auc: 0.799582
# [44]	valid_0's auc: 0.800237
# [45]	valid_0's auc: 0.800652
# [46]	valid_0's auc: 0.800953
# [47]	valid_0's auc: 0.80096
# [48]	valid_0's auc: 0.801347
# [49]	valid_0's auc: 0.801547
# [50]	valid_0's auc: 0.8015
# [51]	valid_0's auc: 0.801706
# [52]	valid_0's auc: 0.801832
# [53]	valid_0's auc: 0.802555
# [54]	valid_0's auc: 0.802758
# [55]	valid_0's auc: 0.803212
# [56]	valid_0's auc: 0.80349
# [57]	valid_0's auc: 0.804167
# [58]	valid_0's auc: 0.804631
# [59]	valid_0's auc: 0.804672
# [60]	valid_0's auc: 0.80515
# [61]	valid_0's auc: 0.805106
# [62]	valid_0's auc: 0.805511
# [63]	valid_0's auc: 0.805879
# [64]	valid_0's auc: 0.806162
# [65]	valid_0's auc: 0.806186
# [66]	valid_0's auc: 0.806397
# [67]	valid_0's auc: 0.806597
# [68]	valid_0's auc: 0.806943
# [69]	valid_0's auc: 0.807339
# [70]	valid_0's auc: 0.807525
# [71]	valid_0's auc: 0.807613
# [72]	valid_0's auc: 0.807945
# [73]	valid_0's auc: 0.808075
# [74]	valid_0's auc: 0.808199
# [75]	valid_0's auc: 0.808481
# [76]	valid_0's auc: 0.808463
# [77]	valid_0's auc: 0.808552
# [78]	valid_0's auc: 0.808608
# [79]	valid_0's auc: 0.808814
# [80]	valid_0's auc: 0.809078
# [81]	valid_0's auc: 0.809262
# [82]	valid_0's auc: 0.809225
# [83]	valid_0's auc: 0.809273
# [84]	valid_0's auc: 0.809486
# [85]	valid_0's auc: 0.809557
# [86]	valid_0's auc: 0.809834
# [87]	valid_0's auc: 0.809757
# [88]	valid_0's auc: 0.809665
# [89]	valid_0's auc: 0.809954
# [90]	valid_0's auc: 0.810127
# [91]	valid_0's auc: 0.810403
# [92]	valid_0's auc: 0.8107
# [93]	valid_0's auc: 0.810872
# [94]	valid_0's auc: 0.811129
# [95]	valid_0's auc: 0.811185
# [96]	valid_0's auc: 0.811272
# [97]	valid_0's auc: 0.811303
# [98]	valid_0's auc: 0.81148
# [99]	valid_0's auc: 0.811593
# [100]	valid_0's auc: 0.811829
# [101]	valid_0's auc: 0.812037
# [102]	valid_0's auc: 0.812201
# [103]	valid_0's auc: 0.81243
# [104]	valid_0's auc: 0.812864
# [105]	valid_0's auc: 0.813056
# [106]	valid_0's auc: 0.813242
# [107]	valid_0's auc: 0.813627
# [108]	valid_0's auc: 0.813876
# [109]	valid_0's auc: 0.814238
# [110]	valid_0's auc: 0.814682
# [111]	valid_0's auc: 0.814864
# [112]	valid_0's auc: 0.815073
# [113]	valid_0's auc: 0.815357
# [114]	valid_0's auc: 0.815712
# [115]	valid_0's auc: 0.815887
# [116]	valid_0's auc: 0.815816
# [117]	valid_0's auc: 0.815878
# [118]	valid_0's auc: 0.816027
# [119]	valid_0's auc: 0.816149
# [120]	valid_0's auc: 0.816271
# [121]	valid_0's auc: 0.816625
# [122]	valid_0's auc: 0.816764
# [123]	valid_0's auc: 0.816969
# [124]	valid_0's auc: 0.817228
# [125]	valid_0's auc: 0.817215
# [126]	valid_0's auc: 0.817454
# [127]	valid_0's auc: 0.817622
# [128]	valid_0's auc: 0.817682
# [129]	valid_0's auc: 0.817682
# [130]	valid_0's auc: 0.817737
# [131]	valid_0's auc: 0.817704
# [132]	valid_0's auc: 0.817825
# [133]	valid_0's auc: 0.817761
# [134]	valid_0's auc: 0.817871
# [135]	valid_0's auc: 0.817989
# [136]	valid_0's auc: 0.818064
# [137]	valid_0's auc: 0.818225
# [138]	valid_0's auc: 0.818449
# [139]	valid_0's auc: 0.818665
# [140]	valid_0's auc: 0.81875
# [141]	valid_0's auc: 0.818833
# [142]	valid_0's auc: 0.818878
# [143]	valid_0's auc: 0.818985
# [144]	valid_0's auc: 0.819035
# [145]	valid_0's auc: 0.819053
# [146]	valid_0's auc: 0.819153
# [147]	valid_0's auc: 0.819076
# [148]	valid_0's auc: 0.819147
# [149]	valid_0's auc: 0.819191
# [150]	valid_0's auc: 0.819379
# [151]	valid_0's auc: 0.819409
# [152]	valid_0's auc: 0.819297
# [153]	valid_0's auc: 0.819212
# [154]	valid_0's auc: 0.81917
# [155]	valid_0's auc: 0.819098
# [156]	valid_0's auc: 0.819357
# [157]	valid_0's auc: 0.819355
# [158]	valid_0's auc: 0.819401
# [159]	valid_0's auc: 0.81964
# [160]	valid_0's auc: 0.81961
# [161]	valid_0's auc: 0.819765
# [162]	valid_0's auc: 0.819829
# [163]	valid_0's auc: 0.819931
# [164]	valid_0's auc: 0.819943
# [165]	valid_0's auc: 0.819906
# [166]	valid_0's auc: 0.819901
# [167]	valid_0's auc: 0.819875
# [168]	valid_0's auc: 0.819926
# [169]	valid_0's auc: 0.82002
# [170]	valid_0's auc: 0.820065
# [171]	valid_0's auc: 0.820146
# [172]	valid_0's auc: 0.820303
# [173]	valid_0's auc: 0.820327
# [174]	valid_0's auc: 0.820424
# [175]	valid_0's auc: 0.820595
# [176]	valid_0's auc: 0.8205
# [177]	valid_0's auc: 0.820482
# [178]	valid_0's auc: 0.820691
# [179]	valid_0's auc: 0.820741
# [180]	valid_0's auc: 0.820813
# [181]	valid_0's auc: 0.820906
# [182]	valid_0's auc: 0.821035
# [183]	valid_0's auc: 0.820984
# [184]	valid_0's auc: 0.820881
# [185]	valid_0's auc: 0.82074
# [186]	valid_0's auc: 0.820831
# [187]	valid_0's auc: 0.820963
# [188]	valid_0's auc: 0.820966
# [189]	valid_0's auc: 0.820875
# [190]	valid_0's auc: 0.82085
# [191]	valid_0's auc: 0.820858
# [192]	valid_0's auc: 0.820906
# [193]	valid_0's auc: 0.820915
# [194]	valid_0's auc: 0.820987
# [195]	valid_0's auc: 0.821038
# [196]	valid_0's auc: 0.821059
# [197]	valid_0's auc: 0.820956
# [198]	valid_0's auc: 0.821
# [199]	valid_0's auc: 0.820993
# [200]	valid_0's auc: 0.820906
# Did not meet early stopping. Best iteration is:
# [196]	valid_0's auc: 0.821059
# |  10       |  0.8211   |  0.6557   |  17.11    |  0.7591   |  0.03391  |  28.19    |  47.82    |  37.54    |  36.3     |
# [1]	valid_0's auc: 0.719471
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's auc: 0.750925
# [3]	valid_0's auc: 0.76479
# [4]	valid_0's auc: 0.770325
# [5]	valid_0's auc: 0.77548
# [6]	valid_0's auc: 0.777914
# [7]	valid_0's auc: 0.780028
# [8]	valid_0's auc: 0.783206
# [9]	valid_0's auc: 0.784877
# [10]	valid_0's auc: 0.787129
# [11]	valid_0's auc: 0.789312
# [12]	valid_0's auc: 0.791309
# [13]	valid_0's auc: 0.792658
# [14]	valid_0's auc: 0.794566
# [15]	valid_0's auc: 0.796287
# [16]	valid_0's auc: 0.797315
# [17]	valid_0's auc: 0.798411
# [18]	valid_0's auc: 0.799493
# [19]	valid_0's auc: 0.800375
# [20]	valid_0's auc: 0.800834
# [21]	valid_0's auc: 0.801335
# [22]	valid_0's auc: 0.801847
# [23]	valid_0's auc: 0.802763
# [24]	valid_0's auc: 0.802625
# [25]	valid_0's auc: 0.803719
# [26]	valid_0's auc: 0.804124
# [27]	valid_0's auc: 0.804729
# [28]	valid_0's auc: 0.805048
# [29]	valid_0's auc: 0.805317
# [30]	valid_0's auc: 0.806345
# [31]	valid_0's auc: 0.806421
# [32]	valid_0's auc: 0.80681
# [33]	valid_0's auc: 0.806989
# [34]	valid_0's auc: 0.807152
# [35]	valid_0's auc: 0.807557
# [36]	valid_0's auc: 0.808098
# [37]	valid_0's auc: 0.808447
# [38]	valid_0's auc: 0.808732
# [39]	valid_0's auc: 0.808945
# [40]	valid_0's auc: 0.809241
# [41]	valid_0's auc: 0.809435
# [42]	valid_0's auc: 0.809497
# [43]	valid_0's auc: 0.809518
# [44]	valid_0's auc: 0.809808
# [45]	valid_0's auc: 0.809969
# [46]	valid_0's auc: 0.80989
# [47]	valid_0's auc: 0.810245
# [48]	valid_0's auc: 0.810767
# [49]	valid_0's auc: 0.810895
# [50]	valid_0's auc: 0.810995
# [51]	valid_0's auc: 0.811053
# [52]	valid_0's auc: 0.811217
# [53]	valid_0's auc: 0.811162
# [54]	valid_0's auc: 0.811106
# [55]	valid_0's auc: 0.811331
# [56]	valid_0's auc: 0.811223
# [57]	valid_0's auc: 0.810808
# [58]	valid_0's auc: 0.810959
# [59]	valid_0's auc: 0.811242
# [60]	valid_0's auc: 0.811105
# [61]	valid_0's auc: 0.811232
# [62]	valid_0's auc: 0.811463
# [63]	valid_0's auc: 0.811494
# ...
# [13]	valid_0's auc: 0.777299
# [14]	valid_0's auc: 0.779435
# [15]	valid_0's auc: 0.780614
# [16]	valid_0's auc: 0.781321
# [17]	valid_0's auc: 0.782117
# [18]	valid_0's auc: 0.783572
# [19]	valid_0's auc: 0.784354
# [20]	valid_0's auc: 0.785262
# [21]	valid_0's auc: 0.785784
# [22]	valid_0's auc: 0.786334
# [23]	valid_0's auc: 0.785704
# [24]	valid_0's auc: 0.785909
# [25]	valid_0's auc: 0.786045
# [26]	valid_0's auc: 0.786468
# [27]	valid_0's auc: 0.786706
# [28]	valid_0's auc: 0.786919
# [29]	valid_0's auc: 0.787084
# [30]	valid_0's auc: 0.787286
# [31]	valid_0's auc: 0.787504
# [32]	valid_0's auc: 0.787558
# [33]	valid_0's auc: 0.787453
# [34]	valid_0's auc: 0.787021
# [35]	valid_0's auc: 0.787237
# [36]	valid_0's auc: 0.78733
# [37]	valid_0's auc: 0.787302
# [38]	valid_0's auc: 0.787305
# [39]	valid_0's auc: 0.787629
# [40]	valid_0's auc: 0.787147
# [41]	valid_0's auc: 0.787253
# [42]	valid_0's auc: 0.7878
# [43]	valid_0's auc: 0.788254
# [44]	valid_0's auc: 0.787989
# [45]	valid_0's auc: 0.787645
# [46]	valid_0's auc: 0.788
# [47]	valid_0's auc: 0.787658
# [48]	valid_0's auc: 0.787803
# [49]	valid_0's auc: 0.787426
# [50]	valid_0's auc: 0.787998
# [51]	valid_0's auc: 0.788133
# [52]	valid_0's auc: 0.788569
# [53]	valid_0's auc: 0.788746
# [54]	valid_0's auc: 0.7892
# [55]	valid_0's auc: 0.789643
# [56]	valid_0's auc: 0.789467
# [57]	valid_0's auc: 0.789067
# [58]	valid_0's auc: 0.789797
# [59]	valid_0's auc: 0.789741
# [60]	valid_0's auc: 0.791128
# [61]	valid_0's auc: 0.791271
# [62]	valid_0's auc: 0.791952
# [63]	valid_0's auc: 0.791637
# [64]	valid_0's auc: 0.791712
# [65]	valid_0's auc: 0.79211
# [66]	valid_0's auc: 0.791873
# [67]	valid_0's auc: 0.792013
# [68]	valid_0's auc: 0.792101
# [69]	valid_0's auc: 0.791964
# [70]	valid_0's auc: 0.791783
# [71]	valid_0's auc: 0.791799
# [72]	valid_0's auc: 0.791487
# [73]	valid_0's auc: 0.791895
# [74]	valid_0's auc: 0.791759
# [75]	valid_0's auc: 0.791899
# [76]	valid_0's auc: 0.791749
# [77]	valid_0's auc: 0.791639
# [78]	valid_0's auc: 0.791757
# [79]	valid_0's auc: 0.792482
# [80]	valid_0's auc: 0.791939
# [81]	valid_0's auc: 0.791705
# [82]	valid_0's auc: 0.791358
# [83]	valid_0's auc: 0.791014
# [84]	valid_0's auc: 0.791131
# [85]	valid_0's auc: 0.790768
# [86]	valid_0's auc: 0.790777
# [87]	valid_0's auc: 0.790587
# [88]	valid_0's auc: 0.790217
# [89]	valid_0's auc: 0.789693
# [90]	valid_0's auc: 0.789339
# [91]	valid_0's auc: 0.789639
# [92]	valid_0's auc: 0.789624
# [93]	valid_0's auc: 0.789391
# [94]	valid_0's auc: 0.78929
# [95]	valid_0's auc: 0.789524
# [96]	valid_0's auc: 0.789021
# [97]	valid_0's auc: 0.789061
# [98]	valid_0's auc: 0.788583
# [99]	valid_0's auc: 0.78793
# [100]	valid_0's auc: 0.787854
# [101]	valid_0's auc: 0.787757
# [102]	valid_0's auc: 0.78758
# [103]	valid_0's auc: 0.787789
# [104]	valid_0's auc: 0.787768
# [105]	valid_0's auc: 0.787446
# [106]	valid_0's auc: 0.78772
# [107]	valid_0's auc: 0.787913
# [108]	valid_0's auc: 0.788052
# [109]	valid_0's auc: 0.788082
# [110]	valid_0's auc: 0.787756
# [111]	valid_0's auc: 0.787382
# [112]	valid_0's auc: 0.787266
# [113]	valid_0's auc: 0.787031
# [114]	valid_0's auc: 0.786936
# [115]	valid_0's auc: 0.786536
# [116]	valid_0's auc: 0.786486
# [117]	valid_0's auc: 0.786648
# [118]	valid_0's auc: 0.785991
# [119]	valid_0's auc: 0.786044
# [120]	valid_0's auc: 0.785919
# [121]	valid_0's auc: 0.785845
# [122]	valid_0's auc: 0.786006
# [123]	valid_0's auc: 0.786017
# [124]	valid_0's auc: 0.785939
# [125]	valid_0's auc: 0.786066
# [126]	valid_0's auc: 0.786376
# [127]	valid_0's auc: 0.786696
# [128]	valid_0's auc: 0.786991
# [129]	valid_0's auc: 0.787129
# Early stopping, best iteration is:
# [79]	valid_0's auc: 0.792482
# |  58       |  0.7925   |  0.6437   |  19.99    |  0.7982   |  0.1624   |  21.6     |  98.68    |  0.9612   |  22.47    |
# [1]	valid_0's auc: 0.72752
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's auc: 0.728852
# [3]	valid_0's auc: 0.730625
# [4]	valid_0's auc: 0.737067
# [5]	valid_0's auc: 0.744278
# [6]	valid_0's auc: 0.748931
# [7]	valid_0's auc: 0.750215
# [8]	valid_0's auc: 0.755784
# [9]	valid_0's auc: 0.757281
# [10]	valid_0's auc: 0.758593
# [11]	valid_0's auc: 0.758441
# [12]	valid_0's auc: 0.758774
# [13]	valid_0's auc: 0.766745
# [14]	valid_0's auc: 0.768086
# [15]	valid_0's auc: 0.768087
# [16]	valid_0's auc: 0.76944
# [17]	valid_0's auc: 0.773064
# [18]	valid_0's auc: 0.773788
# [19]	valid_0's auc: 0.773743
# [20]	valid_0's auc: 0.774016
# [21]	valid_0's auc: 0.774163
# [22]	valid_0's auc: 0.774345
# [23]	valid_0's auc: 0.775409
# [24]	valid_0's auc: 0.775838
# [25]	valid_0's auc: 0.775869
# [26]	valid_0's auc: 0.776476
# [27]	valid_0's auc: 0.776404
# [28]	valid_0's auc: 0.776342
# [29]	valid_0's auc: 0.777041
# [30]	valid_0's auc: 0.777571
# [31]	valid_0's auc: 0.777795
# [32]	valid_0's auc: 0.778425
# [33]	valid_0's auc: 0.778606
# [34]	valid_0's auc: 0.778576
# [35]	valid_0's auc: 0.779005
# [36]	valid_0's auc: 0.778873
# [37]	valid_0's auc: 0.779091
# [38]	valid_0's auc: 0.779393
# [39]	valid_0's auc: 0.779822
# [40]	valid_0's auc: 0.779876
# [41]	valid_0's auc: 0.780238
# [42]	valid_0's auc: 0.780563
# [43]	valid_0's auc: 0.780742
# [44]	valid_0's auc: 0.780913
# [45]	valid_0's auc: 0.780868
# [46]	valid_0's auc: 0.780964
# [47]	valid_0's auc: 0.780963
# [48]	valid_0's auc: 0.781201
# [49]	valid_0's auc: 0.781294
# [50]	valid_0's auc: 0.78139
# [51]	valid_0's auc: 0.781482
# [52]	valid_0's auc: 0.781581
# [53]	valid_0's auc: 0.781748
# [54]	valid_0's auc: 0.78196
# [55]	valid_0's auc: 0.78216
# [56]	valid_0's auc: 0.782283
# [57]	valid_0's auc: 0.782434
# [58]	valid_0's auc: 0.782645
# [59]	valid_0's auc: 0.783351
# [60]	valid_0's auc: 0.783941
# [61]	valid_0's auc: 0.783961
# [62]	valid_0's auc: 0.784332
# [63]	valid_0's auc: 0.784349
# [64]	valid_0's auc: 0.784386
# [65]	valid_0's auc: 0.784952
# [66]	valid_0's auc: 0.785073
# [67]	valid_0's auc: 0.785579
# [68]	valid_0's auc: 0.786133
# [69]	valid_0's auc: 0.786042
# [70]	valid_0's auc: 0.786517
# [71]	valid_0's auc: 0.786968
# [72]	valid_0's auc: 0.787412
# [73]	valid_0's auc: 0.787378
# [74]	valid_0's auc: 0.787753
# [75]	valid_0's auc: 0.78801
# [76]	valid_0's auc: 0.788313
# [77]	valid_0's auc: 0.788273
# [78]	valid_0's auc: 0.788199
# [79]	valid_0's auc: 0.788622
# [80]	valid_0's auc: 0.789034
# [81]	valid_0's auc: 0.789392
# [82]	valid_0's auc: 0.789343
# [83]	valid_0's auc: 0.789711
# [84]	valid_0's auc: 0.789625
# [85]	valid_0's auc: 0.789982
# [86]	valid_0's auc: 0.79001
# [87]	valid_0's auc: 0.790019
# [88]	valid_0's auc: 0.790307
# [89]	valid_0's auc: 0.790378
# [90]	valid_0's auc: 0.790588
# [91]	valid_0's auc: 0.790533
# [92]	valid_0's auc: 0.790836
# [93]	valid_0's auc: 0.791093
# [94]	valid_0's auc: 0.791326
# [95]	valid_0's auc: 0.791411
# [96]	valid_0's auc: 0.79165
# [97]	valid_0's auc: 0.791933
# [98]	valid_0's auc: 0.791964
# [99]	valid_0's auc: 0.791988
# [100]	valid_0's auc: 0.792247
# [101]	valid_0's auc: 0.792288
# [102]	valid_0's auc: 0.792533
# [103]	valid_0's auc: 0.792578
# [104]	valid_0's auc: 0.792795
# [105]	valid_0's auc: 0.792823
# [106]	valid_0's auc: 0.793025
# [107]	valid_0's auc: 0.793257
# [108]	valid_0's auc: 0.793213
# [109]	valid_0's auc: 0.793441
# [110]	valid_0's auc: 0.793396
# [111]	valid_0's auc: 0.793603
# [112]	valid_0's auc: 0.793794
# [113]	valid_0's auc: 0.793957
# [114]	valid_0's auc: 0.794171
# [115]	valid_0's auc: 0.794177
# [116]	valid_0's auc: 0.794228
# [117]	valid_0's auc: 0.794395
# [118]	valid_0's auc: 0.794402
# [119]	valid_0's auc: 0.794579
# [120]	valid_0's auc: 0.794611
# [121]	valid_0's auc: 0.794785
# [122]	valid_0's auc: 0.794937
# [123]	valid_0's auc: 0.795087
# [124]	valid_0's auc: 0.795224
# [125]	valid_0's auc: 0.795378
# [126]	valid_0's auc: 0.795438
# [127]	valid_0's auc: 0.795642
# [128]	valid_0's auc: 0.795655
# [129]	valid_0's auc: 0.795676
# [130]	valid_0's auc: 0.795662
# [131]	valid_0's auc: 0.795797
# [132]	valid_0's auc: 0.79595
# [133]	valid_0's auc: 0.795916
# [134]	valid_0's auc: 0.795991
# [135]	valid_0's auc: 0.795986
# [136]	valid_0's auc: 0.796112
# [137]	valid_0's auc: 0.796217
# [138]	valid_0's auc: 0.79636
# [139]	valid_0's auc: 0.796458
# [140]	valid_0's auc: 0.796437
# [141]	valid_0's auc: 0.796554
# [142]	valid_0's auc: 0.796571
# [143]	valid_0's auc: 0.796698
# [144]	valid_0's auc: 0.796811
# [145]	valid_0's auc: 0.796864
# [146]	valid_0's auc: 0.797036
# [147]	valid_0's auc: 0.797098
# [148]	valid_0's auc: 0.797149
# [149]	valid_0's auc: 0.797186
# [150]	valid_0's auc: 0.79725
# [151]	valid_0's auc: 0.79732
# [152]	valid_0's auc: 0.797345
# [153]	valid_0's auc: 0.797303
# [154]	valid_0's auc: 0.797492
# [155]	valid_0's auc: 0.797455
# [156]	valid_0's auc: 0.797642
# [157]	valid_0's auc: 0.797571
# [158]	valid_0's auc: 0.797587
# [159]	valid_0's auc: 0.797606
# [160]	valid_0's auc: 0.79763
# [161]	valid_0's auc: 0.797744
# [162]	valid_0's auc: 0.797858
# [163]	valid_0's auc: 0.797881
# [164]	valid_0's auc: 0.797877
# [165]	valid_0's auc: 0.79788
# [166]	valid_0's auc: 0.797995
# [167]	valid_0's auc: 0.798156
# [168]	valid_0's auc: 0.798144
# [169]	valid_0's auc: 0.798139
# [170]	valid_0's auc: 0.798224
# [171]	valid_0's auc: 0.798345
# [172]	valid_0's auc: 0.798373
# [173]	valid_0's auc: 0.798392
# [174]	valid_0's auc: 0.798389
# [175]	valid_0's auc: 0.79839
# [176]	valid_0's auc: 0.798418
# [177]	valid_0's auc: 0.798429
# [178]	valid_0's auc: 0.798423
# [179]	valid_0's auc: 0.798418
# [180]	valid_0's auc: 0.79847
# [181]	valid_0's auc: 0.798496
# [182]	valid_0's auc: 0.79847
# [183]	valid_0's auc: 0.798525
# [184]	valid_0's auc: 0.798531
# [185]	valid_0's auc: 0.798633
# [186]	valid_0's auc: 0.798715
# [187]	valid_0's auc: 0.79881
# [188]	valid_0's auc: 0.798937
# [189]	valid_0's auc: 0.79893
# [190]	valid_0's auc: 0.799021
# [191]	valid_0's auc: 0.799045
# [192]	valid_0's auc: 0.799165
# [193]	valid_0's auc: 0.799248
# [194]	valid_0's auc: 0.799249
# [195]	valid_0's auc: 0.799333
# [196]	valid_0's auc: 0.799373
# [197]	valid_0's auc: 0.799474
# [198]	valid_0's auc: 0.799454
# [199]	valid_0's auc: 0.799495
# [200]	valid_0's auc: 0.799561
# Did not meet early stopping. Best iteration is:
# [200]	valid_0's auc: 0.799561
# |  59       |  0.7996   |  0.9971   |  17.54    |  0.7743   |  0.003023 |  5.373    |  99.69    |  25.45    |  49.97    |
# [1]	valid_0's auc: 0.777827
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's auc: 0.7894
# [3]	valid_0's auc: 0.789291
# [4]	valid_0's auc: 0.791005
# [5]	valid_0's auc: 0.790899
# [6]	valid_0's auc: 0.792126
# [7]	valid_0's auc: 0.794955
# [8]	valid_0's auc: 0.796608
# [9]	valid_0's auc: 0.796777
# [10]	valid_0's auc: 0.796971
# [11]	valid_0's auc: 0.79798
# [12]	valid_0's auc: 0.797698
# [13]	valid_0's auc: 0.798634
# [14]	valid_0's auc: 0.799403
# [15]	valid_0's auc: 0.799286
# [16]	valid_0's auc: 0.80021
# [17]	valid_0's auc: 0.799863
# [18]	valid_0's auc: 0.799768
# [19]	valid_0's auc: 0.799854
# [20]	valid_0's auc: 0.800168
# [21]	valid_0's auc: 0.800308
# [22]	valid_0's auc: 0.801066
# [23]	valid_0's auc: 0.801146
# [24]	valid_0's auc: 0.801042
# [25]	valid_0's auc: 0.801548
# [26]	valid_0's auc: 0.801994
# [27]	valid_0's auc: 0.801854
# [28]	valid_0's auc: 0.802029
# [29]	valid_0's auc: 0.801854
# [30]	valid_0's auc: 0.80221
# [31]	valid_0's auc: 0.802248
# [32]	valid_0's auc: 0.802263
# [33]	valid_0's auc: 0.802598
# [34]	valid_0's auc: 0.803085
# [35]	valid_0's auc: 0.803528
# [36]	valid_0's auc: 0.803804
# [37]	valid_0's auc: 0.80455
# [38]	valid_0's auc: 0.805216
# [39]	valid_0's auc: 0.80535
# [40]	valid_0's auc: 0.805671
# [41]	valid_0's auc: 0.806216
# [42]	valid_0's auc: 0.806495
# [43]	valid_0's auc: 0.806754
# [44]	valid_0's auc: 0.806885
# [45]	valid_0's auc: 0.806943
# [46]	valid_0's auc: 0.807239
# [47]	valid_0's auc: 0.807389
# [48]	valid_0's auc: 0.807455
# [49]	valid_0's auc: 0.80753
# [50]	valid_0's auc: 0.807544
# [51]	valid_0's auc: 0.807438
# [52]	valid_0's auc: 0.807307
# [53]	valid_0's auc: 0.807779
# [54]	valid_0's auc: 0.808026
# [55]	valid_0's auc: 0.808028
# [56]	valid_0's auc: 0.808263
# [57]	valid_0's auc: 0.808549
# [58]	valid_0's auc: 0.808745
# [59]	valid_0's auc: 0.808901
# [60]	valid_0's auc: 0.809306
# [61]	valid_0's auc: 0.809701
# [62]	valid_0's auc: 0.809969
# [63]	valid_0's auc: 0.810145
# [64]	valid_0's auc: 0.810206
# [65]	valid_0's auc: 0.810293
# [66]	valid_0's auc: 0.810415
# [67]	valid_0's auc: 0.810565
# [68]	valid_0's auc: 0.810698
# [69]	valid_0's auc: 0.810934
# [70]	valid_0's auc: 0.811217
# [71]	valid_0's auc: 0.811491
# [72]	valid_0's auc: 0.811615
# [73]	valid_0's auc: 0.811705
# [74]	valid_0's auc: 0.811893
# [75]	valid_0's auc: 0.811923
# [76]	valid_0's auc: 0.812041
# [77]	valid_0's auc: 0.812127
# [78]	valid_0's auc: 0.812267
# [79]	valid_0's auc: 0.812337
# [80]	valid_0's auc: 0.812557
# [81]	valid_0's auc: 0.812652
# [82]	valid_0's auc: 0.812756
# [83]	valid_0's auc: 0.812878
# [84]	valid_0's auc: 0.813043
# [85]	valid_0's auc: 0.813072
# [86]	valid_0's auc: 0.812959
# [87]	valid_0's auc: 0.812901
# [88]	valid_0's auc: 0.813069
# [89]	valid_0's auc: 0.813156
# [90]	valid_0's auc: 0.813234
# [91]	valid_0's auc: 0.813371
# [92]	valid_0's auc: 0.813408
# [93]	valid_0's auc: 0.813358
# [94]	valid_0's auc: 0.813522
# [95]	valid_0's auc: 0.813498
# [96]	valid_0's auc: 0.813492
# [97]	valid_0's auc: 0.813514
# [98]	valid_0's auc: 0.813508
# [99]	valid_0's auc: 0.813587
# [100]	valid_0's auc: 0.813364
# [101]	valid_0's auc: 0.813396
# [102]	valid_0's auc: 0.813435
# [103]	valid_0's auc: 0.813448
# [104]	valid_0's auc: 0.813369
# [105]	valid_0's auc: 0.813419
# [106]	valid_0's auc: 0.813417
# [107]	valid_0's auc: 0.813418
# [108]	valid_0's auc: 0.813333
# [109]	valid_0's auc: 0.813376
# [110]	valid_0's auc: 0.813389
# [111]	valid_0's auc: 0.813451
# [112]	valid_0's auc: 0.813381
# [113]	valid_0's auc: 0.813423
# [114]	valid_0's auc: 0.813474
# [115]	valid_0's auc: 0.81353
# [116]	valid_0's auc: 0.813602
# [117]	valid_0's auc: 0.813648
# [118]	valid_0's auc: 0.813714
# [119]	valid_0's auc: 0.81378
# [120]	valid_0's auc: 0.813854
# [121]	valid_0's auc: 0.813861
# [122]	valid_0's auc: 0.813743
# [123]	valid_0's auc: 0.813641
# [124]	valid_0's auc: 0.813664
# [125]	valid_0's auc: 0.813733
# [126]	valid_0's auc: 0.813802
# [127]	valid_0's auc: 0.813951
# [128]	valid_0's auc: 0.813984
# [129]	valid_0's auc: 0.813877
# [130]	valid_0's auc: 0.813957
# [131]	valid_0's auc: 0.813969
# [132]	valid_0's auc: 0.814058
# [133]	valid_0's auc: 0.814147
# [134]	valid_0's auc: 0.814004
# [135]	valid_0's auc: 0.813983
# [136]	valid_0's auc: 0.814005
# [137]	valid_0's auc: 0.81416
# [138]	valid_0's auc: 0.81419
# [139]	valid_0's auc: 0.814233
# [140]	valid_0's auc: 0.814242
# [141]	valid_0's auc: 0.81457
# [142]	valid_0's auc: 0.814682
# [143]	valid_0's auc: 0.814888
# [144]	valid_0's auc: 0.814796
# [145]	valid_0's auc: 0.814666
# [146]	valid_0's auc: 0.814779
# [147]	valid_0's auc: 0.81472
# [148]	valid_0's auc: 0.81487
# [149]	valid_0's auc: 0.814846
# [150]	valid_0's auc: 0.814816
# [151]	valid_0's auc: 0.81493
# [152]	valid_0's auc: 0.814844
# [153]	valid_0's auc: 0.814868
# [154]	valid_0's auc: 0.814804
# [155]	valid_0's auc: 0.814806
# [156]	valid_0's auc: 0.81466
# [157]	valid_0's auc: 0.81458
# [158]	valid_0's auc: 0.814408
# [159]	valid_0's auc: 0.814364
# [160]	valid_0's auc: 0.814338
# [161]	valid_0's auc: 0.814192
# [162]	valid_0's auc: 0.814027
# [163]	valid_0's auc: 0.81404
# [164]	valid_0's auc: 0.813939
# [165]	valid_0's auc: 0.813804
# [166]	valid_0's auc: 0.813823
# [167]	valid_0's auc: 0.813816
# [168]	valid_0's auc: 0.813827
# [169]	valid_0's auc: 0.813744
# [170]	valid_0's auc: 0.813747
# [171]	valid_0's auc: 0.813798
# [172]	valid_0's auc: 0.813858
# [173]	valid_0's auc: 0.813921
# [174]	valid_0's auc: 0.813878
# [175]	valid_0's auc: 0.813804
# [176]	valid_0's auc: 0.813768
# [177]	valid_0's auc: 0.813769
# [178]	valid_0's auc: 0.813659
# [179]	valid_0's auc: 0.813731
# [180]	valid_0's auc: 0.813748
# [181]	valid_0's auc: 0.813707
# [182]	valid_0's auc: 0.813796
# [183]	valid_0's auc: 0.813801
# [184]	valid_0's auc: 0.813863
# [185]	valid_0's auc: 0.813892
# [186]	valid_0's auc: 0.813997
# [187]	valid_0's auc: 0.814024
# [188]	valid_0's auc: 0.814077
# [189]	valid_0's auc: 0.814164
# [190]	valid_0's auc: 0.814302
# [191]	valid_0's auc: 0.814348
# [192]	valid_0's auc: 0.814324
# [193]	valid_0's auc: 0.814394
# [194]	valid_0's auc: 0.814445
# [195]	valid_0's auc: 0.81445
# [196]	valid_0's auc: 0.81441
# [197]	valid_0's auc: 0.814472
# [198]	valid_0's auc: 0.814373
# [199]	valid_0's auc: 0.814385
# [200]	valid_0's auc: 0.814443
# Did not meet early stopping. Best iteration is:
# [151]	valid_0's auc: 0.81493
# |  60       |  0.8149   |  0.8224   |  18.99    |  0.841    |  0.03797  |  5.611    |  81.43    |  19.89    |  0.9209   |
# =========================================================================================================================

# %%
LGB_BO.max['target']
# Out:
# 0.8235570039908574

# %%
LGB_BO.max['params']
# Out:
# {'bagging_fraction': 0.8679900331594039,
#  'bagging_freq': 19.461295671833362,
#  'feature_fraction': 0.6521303847699594,
#  'learning_rate': 0.04001280271606868,
#  'max_depth': 27.331557512738563,
#  'num_leaves': 36.11800346099659,
#  'reg_alpha': 0.18342287394159662,
#  'reg_lambda': 6.304147153507928}

# %% [raw]
# for i, res in enumerate(LGB_BO.res):
#     print("Iteration {}: \n\t{}".format(i, res))

# %%
#保存最佳參數
best_parameters = { 'boosting_type': 'gbdt',              
                    'objective': 'binary',               
                    'class_weight': None, 
                    'importance_type': 'split', 
                    #'learning_rate': LGB_BO.max['params']['learning_rate'],
                    'learning_rate':0.1,
                    'max_depth': int(LGB_BO.max['params']['max_depth']),          
                    #'min_split_gain':  LGB_BO.max['params']['min_split_gain'],
                    'n_estimators': 200, 
                    'n_jobs': -1,
                    'num_leaves': int(LGB_BO.max['params']['num_leaves']),
                    #'min_data_in_leaf': int(LGB_BO.max['params']['min_data_in_leaf']),
                    #'min_sum_hessian_in_leaf': LGB_BO.max['params']['min_sum_hessian_in_leaf'],
                    'objective': 'binary', 
                    'random_state': 1, 
                    'reg_alpha':  LGB_BO.max['params']['reg_alpha'], 
                    'reg_lambda': int(LGB_BO.max['params']['reg_lambda']), 
                    'silent': True, 
                    'is_unbalance': True,
                    'metric': 'auc', 
                    'verbose': 0,
                    'feature_fraction': LGB_BO.max['params']['feature_fraction'],
                    'bagging_fraction': LGB_BO.max['params']['bagging_fraction'],  
                    'bagging_freq': int(LGB_BO.max['params']['bagging_freq']), 
                    'cat_smooth': 1}

# %%
best_parameters = { 'boosting_type': 'gbdt',              
                    'objective': 'binary',               
                    'class_weight': None, 
                    'importance_type': 'split', 
                    'learning_rate': 0.04,
                    'learning_rate':0.1,
                    'max_depth': 23,          
                    'min_split_gain':  0.9,
                    'n_estimators': 200, 
                    'n_jobs': -1,
                    'num_leaves': 27,
                    #'min_data_in_leaf': int(LGB_BO.max['params']['min_data_in_leaf']),
                    'min_sum_hessian_in_leaf': 0.02,
                    'objective': 'binary', 
                    'random_state': 1, 
                    'reg_alpha':  0.02, 
                    'reg_lambda': 35, 
                    'silent': True, 
                    'is_unbalance': True,
                    'metric': 'auc', 
                    'verbose': 0,
                    'feature_fraction':0.8,
                    'bagging_fraction': 0.7,  
                    'bagging_freq': 10, 
                    'cat_smooth': 1}

# %%
best_parameters ={'boosting_type': 'gbdt', 'importance_type': 'split', 'learning_rate': 0.1,
                  'max_depth': 20, 'n_estimators': 200, 'n_jobs': -1,'num_leaves': 35, 
                  'objective': 'binary', 'random_state': 1, 'silent': True, 'metric': 'auc', 
                  'verbose': 0, 'feature_fraction': 0.6, 'bagging_fraction': 0.7, 'bagging_freq': 8, 
                  'lambda_l1': 0.1, 'lambda_l2': 35, 'cat_smooth': 1}

# %% [raw]
# best_parameters ={'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'learning_rate': 0.05,
#  'max_depth': 20, 'n_estimators': 200, 'n_jobs': -1,
#  'num_leaves': 35, 'objective': 'binary', 'random_state': 1, 'silent': True,
#  'metric': 'auc', 'verbose': 0, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'bagging_freq': 5,
#  'lambda_l1': 0.1, 'lambda_l2': 35, 'cat_smooth': 1}

# %% [raw]
# best_parameters ={'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'learning_rate': 0.05,
#  'max_depth': 20, 'n_estimators': 200, 'n_jobs': -1,
#  'num_leaves': 35, 'objective': 'binary', 'random_state': None, 'silent': True,
#  'metric': 'auc', 'verbose': 0, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'bagging_freq': 5,
#  'lambda_l1': 0.1, 'lambda_l2': 35, 'cat_smooth': 1}

# %% [markdown]
# ### 訓練LightGBM模型

# %%
train_df_2.shape #train_reprocess_new_columns.csv #0.8403033316326531
# Out:
# (100000, 132)

# %%
train_df_2 = pd.read_csv('train_reprocess_knn_v2.csv',encoding='big5')
test_df_2 = pd.read_csv('test_reprocess_knn_v2.csv',encoding='big5')

#new_col = feat_labels[indices[range(X_selected.shape[1])]]
#train_df_2 = pd.concat([train_df[new_col],train_df['Y1']],axis=1)
#test_df_2 = test_df[new_col]

# %%
train_df_2.shape #train_new_columns_OHE.csv #0.8419634336734694
# Out:
# (100000, 154)

# %%
nfold = 10
skf = StratifiedKFold(n_splits = nfold, shuffle=True, random_state=1)

tStart = time.time()#計時開始

val_predict = np.zeros(len(train_df_2))
predictions = np.zeros((len(test_df_2), nfold))

predictors = train_df_2.drop(['Y1','CUS_ID'],axis=1).columns
target = 'Y1'

i = 0
for train_index, valid_index in skf.split(train_df_2, train_df_2[target]):
    print("\nfold {}".format(i+1))
    lgb_train = lgb.Dataset(train_df_2.iloc[train_index][predictors],
                            train_df_2.iloc[train_index][target])
    
    lgb_valid = lgb.Dataset(train_df_2.iloc[valid_index][predictors],
                            train_df_2.iloc[valid_index][target])
    
    evals_result = {} #紀錄訓練結果
    clf = lgb.train(best_parameters, lgb_train, valid_sets = lgb_valid, early_stopping_rounds = 100, evals_result=evals_result)
    
    val_predict[valid_index] = clf.predict(train_df_2.iloc[valid_index][predictors], num_iteration = clf.best_iteration)
    predictions[:,i] += clf.predict(test_df_2[predictors], num_iteration = clf.best_iteration)
    i += 1

    #print('Training Results...') #訓練過程
    #ax = lgb.plot_metric(evals_result, metric='auc')
    #plt.show()

    #print('Features Importance...') #重要特徵
    #ax = lgb.plot_importance(clf, max_num_features=10)
    #plt.show()

    #print('Plot Tree...')  # 畫出決策樹
    #ax = lgb.plot_tree(clf, figsize=(20, 8), show_info=['split_gain'])
    #plt.show()

    #print('導出最後一輪决策樹的圖到本地') #需安装graphviz
    #graph = lgb.create_tree_digraph(clf, name='Tree_MT_fold' +str(i))
    #graph.render(view=True)

tEnd = time.time()#計時結束
print("\n\n AUC in train data: %.4f" % (metrics.roc_auc_score(train_df_2[target], val_predict)))
print ("It cost %f sec" % (tEnd - tStart))#會自動做進位
# Out:
# fold 1
# C:\Users\doggy\Anaconda3\lib\site-packages\lightgbm\engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# C:\Users\doggy\Anaconda3\lib\site-packages\lightgbm\basic.py:741: UserWarning: silent keyword has been found in `params` and will be ignored.
# Please use silent argument of the Dataset constructor to pass this parameter.
#   .format(key))
# [1]	valid_0's auc: 0.776239
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's auc: 0.794213
# [3]	valid_0's auc: 0.796766
# [4]	valid_0's auc: 0.803663
# [5]	valid_0's auc: 0.80564
# [6]	valid_0's auc: 0.806644
# [7]	valid_0's auc: 0.811501
# [8]	valid_0's auc: 0.813866
# [9]	valid_0's auc: 0.81563
# [10]	valid_0's auc: 0.814623
# [11]	valid_0's auc: 0.8164
# [12]	valid_0's auc: 0.817165
# [13]	valid_0's auc: 0.818406
# [14]	valid_0's auc: 0.819415
# [15]	valid_0's auc: 0.820952
# [16]	valid_0's auc: 0.82134
# [17]	valid_0's auc: 0.822231
# [18]	valid_0's auc: 0.822328
# [19]	valid_0's auc: 0.823854
# [20]	valid_0's auc: 0.823071
# [21]	valid_0's auc: 0.823133
# [22]	valid_0's auc: 0.823618
# [23]	valid_0's auc: 0.824298
# [24]	valid_0's auc: 0.825713
# [25]	valid_0's auc: 0.825978
# [26]	valid_0's auc: 0.826792
# [27]	valid_0's auc: 0.826518
# [28]	valid_0's auc: 0.826907
# [29]	valid_0's auc: 0.827466
# [30]	valid_0's auc: 0.827462
# [31]	valid_0's auc: 0.827728
# [32]	valid_0's auc: 0.82817
# [33]	valid_0's auc: 0.82895
# [34]	valid_0's auc: 0.829445
# [35]	valid_0's auc: 0.829543
# [36]	valid_0's auc: 0.829157
# [37]	valid_0's auc: 0.829123
# [38]	valid_0's auc: 0.828965
# [39]	valid_0's auc: 0.829215
# [40]	valid_0's auc: 0.829797
# [41]	valid_0's auc: 0.829809
# [42]	valid_0's auc: 0.830067
# [43]	valid_0's auc: 0.830316
# [44]	valid_0's auc: 0.830421
# [45]	valid_0's auc: 0.83018
# [46]	valid_0's auc: 0.830641
# [47]	valid_0's auc: 0.830815
# [48]	valid_0's auc: 0.830523
# [49]	valid_0's auc: 0.830527
# [50]	valid_0's auc: 0.830589
# [51]	valid_0's auc: 0.830228
# [52]	valid_0's auc: 0.829895
# [53]	valid_0's auc: 0.829274
# [54]	valid_0's auc: 0.829402
# [55]	valid_0's auc: 0.829239
# [56]	valid_0's auc: 0.828521
# [57]	valid_0's auc: 0.828796
# [58]	valid_0's auc: 0.829016
# [59]	valid_0's auc: 0.828861
# [60]	valid_0's auc: 0.828717
# [61]	valid_0's auc: 0.828953
# [62]	valid_0's auc: 0.829235
# [63]	valid_0's auc: 0.829384
# [64]	valid_0's auc: 0.829624
# [65]	valid_0's auc: 0.829721
# [66]	valid_0's auc: 0.830004
# [67]	valid_0's auc: 0.82998
# [68]	valid_0's auc: 0.829851
# [69]	valid_0's auc: 0.830049
# [70]	valid_0's auc: 0.829812
# [71]	valid_0's auc: 0.829974
# [72]	valid_0's auc: 0.830498
# [73]	valid_0's auc: 0.830199
# [74]	valid_0's auc: 0.829784
# [75]	valid_0's auc: 0.829665
# [76]	valid_0's auc: 0.829711
# [77]	valid_0's auc: 0.829681
# [78]	valid_0's auc: 0.82936
# [79]	valid_0's auc: 0.829207
# [80]	valid_0's auc: 0.829408
# [81]	valid_0's auc: 0.829234
# [82]	valid_0's auc: 0.829553
# [83]	valid_0's auc: 0.829211
# [84]	valid_0's auc: 0.828543
# [85]	valid_0's auc: 0.828275
# [86]	valid_0's auc: 0.828255
# [87]	valid_0's auc: 0.827827
# [88]	valid_0's auc: 0.827791
# [89]	valid_0's auc: 0.827757
# [90]	valid_0's auc: 0.827634
# [91]	valid_0's auc: 0.827535
# [92]	valid_0's auc: 0.827608
# [93]	valid_0's auc: 0.827776
# [94]	valid_0's auc: 0.827186
# [95]	valid_0's auc: 0.827202
# [96]	valid_0's auc: 0.826657
# [97]	valid_0's auc: 0.826442
# [98]	valid_0's auc: 0.826431
# [99]	valid_0's auc: 0.826106
# [100]	valid_0's auc: 0.82595
# [101]	valid_0's auc: 0.826131
# [102]	valid_0's auc: 0.826023
# [103]	valid_0's auc: 0.825646
# [104]	valid_0's auc: 0.825388
# [105]	valid_0's auc: 0.825101
# [106]	valid_0's auc: 0.824974
# [107]	valid_0's auc: 0.824751
# [108]	valid_0's auc: 0.824544
# [109]	valid_0's auc: 0.824321
# [110]	valid_0's auc: 0.823988
# [111]	valid_0's auc: 0.82376
# [112]	valid_0's auc: 0.823998
# [113]	valid_0's auc: 0.823855
# [114]	valid_0's auc: 0.823624
# [115]	valid_0's auc: 0.823304
# [116]	valid_0's auc: 0.8232
# [117]	valid_0's auc: 0.823745
# [118]	valid_0's auc: 0.823997
# [119]	valid_0's auc: 0.823851
# [120]	valid_0's auc: 0.823616
# [121]	valid_0's auc: 0.823706
# [122]	valid_0's auc: 0.823721
# [123]	valid_0's auc: 0.823628
# [124]	valid_0's auc: 0.823305
# [125]	valid_0's auc: 0.823627
# [126]	valid_0's auc: 0.823736
# [127]	valid_0's auc: 0.823801
# [128]	valid_0's auc: 0.823679
# [129]	valid_0's auc: 0.823253
# [130]	valid_0's auc: 0.823062
# [131]	valid_0's auc: 0.823214
# [132]	valid_0's auc: 0.822879
# [133]	valid_0's auc: 0.822452
# [134]	valid_0's auc: 0.822614
# [135]	valid_0's auc: 0.821862
# [136]	valid_0's auc: 0.821939
# [137]	valid_0's auc: 0.821912
# [138]	valid_0's auc: 0.821984
# [139]	valid_0's auc: 0.821808
# [140]	valid_0's auc: 0.821859
# [141]	valid_0's auc: 0.822142
# [142]	valid_0's auc: 0.821822
# [143]	valid_0's auc: 0.822109
# [144]	valid_0's auc: 0.822206
# [145]	valid_0's auc: 0.821863
# [146]	valid_0's auc: 0.821669
# [147]	valid_0's auc: 0.821782
# Early stopping, best iteration is:
# [47]	valid_0's auc: 0.830815
#
# fold 2
# [1]	valid_0's auc: 0.755495
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's auc: 0.787845
# [3]	valid_0's auc: 0.790632
# [4]	valid_0's auc: 0.803214
# [5]	valid_0's auc: 0.807076
# [6]	valid_0's auc: 0.807691
# [7]	valid_0's auc: 0.810312
# [8]	valid_0's auc: 0.816678
# [9]	valid_0's auc: 0.818587
# [10]	valid_0's auc: 0.81823
# [11]	valid_0's auc: 0.819669
# [12]	valid_0's auc: 0.820789
# [13]	valid_0's auc: 0.819516
# [14]	valid_0's auc: 0.821941
# [15]	valid_0's auc: 0.823249
# [16]	valid_0's auc: 0.824784
# [17]	valid_0's auc: 0.826032
# [18]	valid_0's auc: 0.826973
# [19]	valid_0's auc: 0.827172
# [20]	valid_0's auc: 0.828876
# [21]	valid_0's auc: 0.830441
# [22]	valid_0's auc: 0.830198
# [23]	valid_0's auc: 0.830221
# [24]	valid_0's auc: 0.831638
# [25]	valid_0's auc: 0.831091
# [26]	valid_0's auc: 0.831826
# [27]	valid_0's auc: 0.832871
# [28]	valid_0's auc: 0.833556
# [29]	valid_0's auc: 0.834723
# [30]	valid_0's auc: 0.834983
# [31]	valid_0's auc: 0.835571
# [32]	valid_0's auc: 0.837192
# [33]	valid_0's auc: 0.837034
# [34]	valid_0's auc: 0.837876
# [35]	valid_0's auc: 0.838005
# [36]	valid_0's auc: 0.838258
# [37]	valid_0's auc: 0.838838
# [38]	valid_0's auc: 0.83926
# [39]	valid_0's auc: 0.83985
# [40]	valid_0's auc: 0.840094
# [41]	valid_0's auc: 0.840009
# [42]	valid_0's auc: 0.840451
# [43]	valid_0's auc: 0.840566
# [44]	valid_0's auc: 0.840641
# [45]	valid_0's auc: 0.841146
# [46]	valid_0's auc: 0.841377
# [47]	valid_0's auc: 0.842224
# [48]	valid_0's auc: 0.84302
# [49]	valid_0's auc: 0.842922
# [50]	valid_0's auc: 0.843137
# [51]	valid_0's auc: 0.843524
# [52]	valid_0's auc: 0.843657
# [53]	valid_0's auc: 0.84386
# [54]	valid_0's auc: 0.844396
# [55]	valid_0's auc: 0.844424
# [56]	valid_0's auc: 0.844859
# [57]	valid_0's auc: 0.844919
# [58]	valid_0's auc: 0.845198
# [59]	valid_0's auc: 0.845421
# [60]	valid_0's auc: 0.845949
# [61]	valid_0's auc: 0.845954
# [62]	valid_0's auc: 0.84657
# [63]	valid_0's auc: 0.846649
# [64]	valid_0's auc: 0.846571
# [65]	valid_0's auc: 0.847032
# [66]	valid_0's auc: 0.847282
# [67]	valid_0's auc: 0.847349
# [68]	valid_0's auc: 0.847165
# [69]	valid_0's auc: 0.847684
# [70]	valid_0's auc: 0.848043
# [71]	valid_0's auc: 0.84808
# [72]	valid_0's auc: 0.848169
# [73]	valid_0's auc: 0.847714
# [74]	valid_0's auc: 0.847991
# [75]	valid_0's auc: 0.847906
# [76]	valid_0's auc: 0.847891
# [77]	valid_0's auc: 0.848163
# [78]	valid_0's auc: 0.8485
# [79]	valid_0's auc: 0.848247
# [80]	valid_0's auc: 0.848343
# [81]	valid_0's auc: 0.84871
# [82]	valid_0's auc: 0.84918
# [83]	valid_0's auc: 0.849047
# [84]	valid_0's auc: 0.848997
# [85]	valid_0's auc: 0.849178
# [86]	valid_0's auc: 0.849017
# [87]	valid_0's auc: 0.849091
# [88]	valid_0's auc: 0.849335
# [89]	valid_0's auc: 0.84957
# [90]	valid_0's auc: 0.849356
# [91]	valid_0's auc: 0.849288
# [92]	valid_0's auc: 0.848841
# [93]	valid_0's auc: 0.848813
# [94]	valid_0's auc: 0.84852
# [95]	valid_0's auc: 0.848364
# [96]	valid_0's auc: 0.848457
# [97]	valid_0's auc: 0.84818
# [98]	valid_0's auc: 0.848387
# [99]	valid_0's auc: 0.848115
# [100]	valid_0's auc: 0.848098
# [101]	valid_0's auc: 0.847856
# [102]	valid_0's auc: 0.847614
# [103]	valid_0's auc: 0.847867
# [104]	valid_0's auc: 0.848101
# [105]	valid_0's auc: 0.848169
# [106]	valid_0's auc: 0.848123
# [107]	valid_0's auc: 0.84818
# [108]	valid_0's auc: 0.847808
# [109]	valid_0's auc: 0.847912
# [110]	valid_0's auc: 0.84783
# [111]	valid_0's auc: 0.847641
# [112]	valid_0's auc: 0.848091
# [113]	valid_0's auc: 0.847978
# [114]	valid_0's auc: 0.847851
# [115]	valid_0's auc: 0.847521
# [116]	valid_0's auc: 0.847561
# [117]	valid_0's auc: 0.847464
# [118]	valid_0's auc: 0.847254
# [119]	valid_0's auc: 0.847296
# [120]	valid_0's auc: 0.847152
# [121]	valid_0's auc: 0.847088
# [122]	valid_0's auc: 0.846891
# [123]	valid_0's auc: 0.846696
# [124]	valid_0's auc: 0.846682
# [125]	valid_0's auc: 0.847107
# [126]	valid_0's auc: 0.847444
# [127]	valid_0's auc: 0.847683
# [128]	valid_0's auc: 0.847698
# [129]	valid_0's auc: 0.847937
# [130]	valid_0's auc: 0.847876
# [131]	valid_0's auc: 0.848222
# [132]	valid_0's auc: 0.848436
# [133]	valid_0's auc: 0.848539
# [134]	valid_0's auc: 0.848484
# [135]	valid_0's auc: 0.848339
# [136]	valid_0's auc: 0.848532
# [137]	valid_0's auc: 0.848242
# [138]	valid_0's auc: 0.84833
# [139]	valid_0's auc: 0.848473
# [140]	valid_0's auc: 0.848831
# [141]	valid_0's auc: 0.848928
# [142]	valid_0's auc: 0.849231
# [143]	valid_0's auc: 0.849397
# [144]	valid_0's auc: 0.849422
# [145]	valid_0's auc: 0.849642
# [146]	valid_0's auc: 0.849433
# [147]	valid_0's auc: 0.849689
# [148]	valid_0's auc: 0.849577
# [149]	valid_0's auc: 0.849842
# [150]	valid_0's auc: 0.849526
# [151]	valid_0's auc: 0.849684
# [152]	valid_0's auc: 0.84983
# [153]	valid_0's auc: 0.849996
# [154]	valid_0's auc: 0.850299
# [155]	valid_0's auc: 0.850343
# [156]	valid_0's auc: 0.850288
# [157]	valid_0's auc: 0.850303
# [158]	valid_0's auc: 0.850884
# [159]	valid_0's auc: 0.850596
# [160]	valid_0's auc: 0.850853
# [161]	valid_0's auc: 0.850633
# [162]	valid_0's auc: 0.850317
# [163]	valid_0's auc: 0.850348
# [164]	valid_0's auc: 0.850125
# [165]	valid_0's auc: 0.849882
# [166]	valid_0's auc: 0.850294
# [167]	valid_0's auc: 0.850131
# [168]	valid_0's auc: 0.849837
# [169]	valid_0's auc: 0.849806
# [170]	valid_0's auc: 0.850086
# [171]	valid_0's auc: 0.850454
# [172]	valid_0's auc: 0.850448
# [173]	valid_0's auc: 0.85026
# [174]	valid_0's auc: 0.850326
# [175]	valid_0's auc: 0.85032
# [176]	valid_0's auc: 0.850302
# [177]	valid_0's auc: 0.849944
# [178]	valid_0's auc: 0.849802
# [179]	valid_0's auc: 0.849624
# [180]	valid_0's auc: 0.849705
# [181]	valid_0's auc: 0.849991
# [182]	valid_0's auc: 0.850052
# [183]	valid_0's auc: 0.849711
# [184]	valid_0's auc: 0.850183
# [185]	valid_0's auc: 0.850066
# [186]	valid_0's auc: 0.850259
# [187]	valid_0's auc: 0.850352
# [188]	valid_0's auc: 0.850288
# [189]	valid_0's auc: 0.850332
# [190]	valid_0's auc: 0.850195
# [191]	valid_0's auc: 0.850044
# [192]	valid_0's auc: 0.850022
# [193]	valid_0's auc: 0.849939
# [194]	valid_0's auc: 0.849764
# [195]	valid_0's auc: 0.849757
# [196]	valid_0's auc: 0.849617
# [197]	valid_0's auc: 0.849479
# [198]	valid_0's auc: 0.849419
# [199]	valid_0's auc: 0.848908
# [200]	valid_0's auc: 0.848887
# Did not meet early stopping. Best iteration is:
# [158]	valid_0's auc: 0.850884
#
# fold 3
# [1]	valid_0's auc: 0.794114
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's auc: 0.826501
# [3]	valid_0's auc: 0.82751
# [4]	valid_0's auc: 0.832315
# [5]	valid_0's auc: 0.833047
# [6]	valid_0's auc: 0.834651
# [7]	valid_0's auc: 0.83579
# [8]	valid_0's auc: 0.837195
# [9]	valid_0's auc: 0.836716
# [10]	valid_0's auc: 0.836918
# [11]	valid_0's auc: 0.83781
# [12]	valid_0's auc: 0.839139
# [13]	valid_0's auc: 0.838442
# [14]	valid_0's auc: 0.83904
# [15]	valid_0's auc: 0.839392
# [16]	valid_0's auc: 0.839797
# [17]	valid_0's auc: 0.840396
# [18]	valid_0's auc: 0.840118
# [19]	valid_0's auc: 0.841455
# [20]	valid_0's auc: 0.841759
# [21]	valid_0's auc: 0.841939
# [22]	valid_0's auc: 0.84176
# [23]	valid_0's auc: 0.841834
# [24]	valid_0's auc: 0.841843
# [25]	valid_0's auc: 0.841706
# [26]	valid_0's auc: 0.842166
# [27]	valid_0's auc: 0.841944
# [28]	valid_0's auc: 0.842213
# [29]	valid_0's auc: 0.842148
# [30]	valid_0's auc: 0.842567
# [31]	valid_0's auc: 0.842465
# [32]	valid_0's auc: 0.842567
# [33]	valid_0's auc: 0.842989
# [34]	valid_0's auc: 0.843198
# [35]	valid_0's auc: 0.84339
# [36]	valid_0's auc: 0.843538
# [37]	valid_0's auc: 0.844076
# [38]	valid_0's auc: 0.8441
# [39]	valid_0's auc: 0.844173
# [40]	valid_0's auc: 0.844023
# [41]	valid_0's auc: 0.843778
# [42]	valid_0's auc: 0.84382
# [43]	valid_0's auc: 0.843651
# [44]	valid_0's auc: 0.843707
# [45]	valid_0's auc: 0.843679
# [46]	valid_0's auc: 0.843724
# [47]	valid_0's auc: 0.843823
# [48]	valid_0's auc: 0.843964
# [49]	valid_0's auc: 0.844318
# [50]	valid_0's auc: 0.84451
# [51]	valid_0's auc: 0.844499
# [52]	valid_0's auc: 0.84447
# [53]	valid_0's auc: 0.844113
# [54]	valid_0's auc: 0.844264
# [55]	valid_0's auc: 0.844124
# [56]	valid_0's auc: 0.843964
# [57]	valid_0's auc: 0.844735
# [58]	valid_0's auc: 0.844402
# [59]	valid_0's auc: 0.844585
# [60]	valid_0's auc: 0.844437
# [61]	valid_0's auc: 0.844054
# [62]	valid_0's auc: 0.843834
# [63]	valid_0's auc: 0.843764
# [64]	valid_0's auc: 0.843593
# [65]	valid_0's auc: 0.843846
# [66]	valid_0's auc: 0.843718
# [67]	valid_0's auc: 0.843493
# [68]	valid_0's auc: 0.843263
# [69]	valid_0's auc: 0.843569
# [70]	valid_0's auc: 0.843846
# [71]	valid_0's auc: 0.843895
# [72]	valid_0's auc: 0.843764
# [73]	valid_0's auc: 0.844137
# [74]	valid_0's auc: 0.84406
# [75]	valid_0's auc: 0.843666
# [76]	valid_0's auc: 0.843597
# [77]	valid_0's auc: 0.843672
# [78]	valid_0's auc: 0.843898
# [79]	valid_0's auc: 0.844042
# [80]	valid_0's auc: 0.843782
# [81]	valid_0's auc: 0.844096
# [82]	valid_0's auc: 0.844256
# [83]	valid_0's auc: 0.844593
# [84]	valid_0's auc: 0.844626
# [85]	valid_0's auc: 0.844614
# [86]	valid_0's auc: 0.844579
# [87]	valid_0's auc: 0.844747
# [88]	valid_0's auc: 0.8446
# [89]	valid_0's auc: 0.844752
# [90]	valid_0's auc: 0.844826
# [91]	valid_0's auc: 0.844817
# [92]	valid_0's auc: 0.844829
# [93]	valid_0's auc: 0.844976
# [94]	valid_0's auc: 0.845129
# [95]	valid_0's auc: 0.845189
# [96]	valid_0's auc: 0.845005
# [97]	valid_0's auc: 0.844793
# [98]	valid_0's auc: 0.844809
# [99]	valid_0's auc: 0.844861
# [100]	valid_0's auc: 0.84474
# [101]	valid_0's auc: 0.844928
# [102]	valid_0's auc: 0.844927
# [103]	valid_0's auc: 0.844721
# [104]	valid_0's auc: 0.845153
# [105]	valid_0's auc: 0.845029
# [106]	valid_0's auc: 0.844969
# [107]	valid_0's auc: 0.845111
# [108]	valid_0's auc: 0.844743
# [109]	valid_0's auc: 0.844464
# [110]	valid_0's auc: 0.844496
# [111]	valid_0's auc: 0.844605
# [112]	valid_0's auc: 0.844709
# [113]	valid_0's auc: 0.844511
# [114]	valid_0's auc: 0.844399
# [115]	valid_0's auc: 0.844269
# [116]	valid_0's auc: 0.844038
# [117]	valid_0's auc: 0.843987
# [118]	valid_0's auc: 0.844086
# [119]	valid_0's auc: 0.843801
# [120]	valid_0's auc: 0.843653
# [121]	valid_0's auc: 0.843781
# [122]	valid_0's auc: 0.844048
# [123]	valid_0's auc: 0.844003
# [124]	valid_0's auc: 0.843573
# [125]	valid_0's auc: 0.843198
# [126]	valid_0's auc: 0.843561
# [127]	valid_0's auc: 0.843407
# [128]	valid_0's auc: 0.842955
# [129]	valid_0's auc: 0.842845
# [130]	valid_0's auc: 0.842836
# [131]	valid_0's auc: 0.842681
# [132]	valid_0's auc: 0.842805
# [133]	valid_0's auc: 0.842539
# [134]	valid_0's auc: 0.842112
# [135]	valid_0's auc: 0.841508
# [136]	valid_0's auc: 0.841257
# [137]	valid_0's auc: 0.841149
# [138]	valid_0's auc: 0.841564
# [139]	valid_0's auc: 0.841591
# [140]	valid_0's auc: 0.841229
# [141]	valid_0's auc: 0.84149
# [142]	valid_0's auc: 0.841331
# [143]	valid_0's auc: 0.841245
# [144]	valid_0's auc: 0.841277
# [145]	valid_0's auc: 0.841251
# [146]	valid_0's auc: 0.841095
# [147]	valid_0's auc: 0.84129
# [148]	valid_0's auc: 0.841462
# [149]	valid_0's auc: 0.841382
# [150]	valid_0's auc: 0.841017
# [151]	valid_0's auc: 0.840774
# [152]	valid_0's auc: 0.840806
# [153]	valid_0's auc: 0.840979
# [154]	valid_0's auc: 0.840985
# [155]	valid_0's auc: 0.840708
# [156]	valid_0's auc: 0.840812
# [157]	valid_0's auc: 0.840829
# [158]	valid_0's auc: 0.841029
# [159]	valid_0's auc: 0.841273
# [160]	valid_0's auc: 0.841234
# [161]	valid_0's auc: 0.841223
# [162]	valid_0's auc: 0.841242
# [163]	valid_0's auc: 0.840835
# [164]	valid_0's auc: 0.841007
# [165]	valid_0's auc: 0.84123
# [166]	valid_0's auc: 0.841309
# [167]	valid_0's auc: 0.841517
# [168]	valid_0's auc: 0.841559
# [169]	valid_0's auc: 0.84152
# [170]	valid_0's auc: 0.84164
# [171]	valid_0's auc: 0.841553
# [172]	valid_0's auc: 0.841282
# [173]	valid_0's auc: 0.841364
# [174]	valid_0's auc: 0.841535
# [175]	valid_0's auc: 0.841596
# [176]	valid_0's auc: 0.841347
# [177]	valid_0's auc: 0.841012
# [178]	valid_0's auc: 0.841076
# [179]	valid_0's auc: 0.840642
# [180]	valid_0's auc: 0.840689
# [181]	valid_0's auc: 0.84033
# [182]	valid_0's auc: 0.840438
# [183]	valid_0's auc: 0.840423
# [184]	valid_0's auc: 0.840138
# [185]	valid_0's auc: 0.839938
# [186]	valid_0's auc: 0.839945
# [187]	valid_0's auc: 0.839728
# [188]	valid_0's auc: 0.839697
# [189]	valid_0's auc: 0.839521
# [190]	valid_0's auc: 0.839362
# [191]	valid_0's auc: 0.839281
# [192]	valid_0's auc: 0.839028
# [193]	valid_0's auc: 0.838652
# [194]	valid_0's auc: 0.838762
# [195]	valid_0's auc: 0.838709
# Early stopping, best iteration is:
# [95]	valid_0's auc: 0.845189
#
# fold 4
# [1]	valid_0's auc: 0.767763
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's auc: 0.800816
# [3]	valid_0's auc: 0.803126
# [4]	valid_0's auc: 0.807798
# [5]	valid_0's auc: 0.81215
# [6]	valid_0's auc: 0.818005
# [7]	valid_0's auc: 0.820625
# [8]	valid_0's auc: 0.821924
# [9]	valid_0's auc: 0.822873
# [10]	valid_0's auc: 0.822564
# [11]	valid_0's auc: 0.823618
# [12]	valid_0's auc: 0.825996
# [13]	valid_0's auc: 0.826107
# [14]	valid_0's auc: 0.827953
# [15]	valid_0's auc: 0.82887
# [16]	valid_0's auc: 0.828817
# [17]	valid_0's auc: 0.829859
# [18]	valid_0's auc: 0.830428
# [19]	valid_0's auc: 0.831323
# [20]	valid_0's auc: 0.831807
# [21]	valid_0's auc: 0.83236
# [22]	valid_0's auc: 0.83323
# [23]	valid_0's auc: 0.833617
# [24]	valid_0's auc: 0.833466
# [25]	valid_0's auc: 0.833743
# [26]	valid_0's auc: 0.832864
# [27]	valid_0's auc: 0.832715
# [28]	valid_0's auc: 0.833038
# [29]	valid_0's auc: 0.83312
# [30]	valid_0's auc: 0.833585
# [31]	valid_0's auc: 0.833813
# [32]	valid_0's auc: 0.833836
# [33]	valid_0's auc: 0.833701
# [34]	valid_0's auc: 0.833783
# [35]	valid_0's auc: 0.833678
# [36]	valid_0's auc: 0.83395
# [37]	valid_0's auc: 0.834128
# [38]	valid_0's auc: 0.834469
# [39]	valid_0's auc: 0.834503
# [40]	valid_0's auc: 0.83413
# [41]	valid_0's auc: 0.834401
# [42]	valid_0's auc: 0.834476
# [43]	valid_0's auc: 0.8342
# [44]	valid_0's auc: 0.833491
# [45]	valid_0's auc: 0.833814
# [46]	valid_0's auc: 0.834123
# [47]	valid_0's auc: 0.8342
# [48]	valid_0's auc: 0.834206
# [49]	valid_0's auc: 0.834046
# [50]	valid_0's auc: 0.834376
# [51]	valid_0's auc: 0.834985
# [52]	valid_0's auc: 0.834548
# [53]	valid_0's auc: 0.834886
# [54]	valid_0's auc: 0.835518
# [55]	valid_0's auc: 0.835479
# [56]	valid_0's auc: 0.835772
# [57]	valid_0's auc: 0.836223
# [58]	valid_0's auc: 0.836005
# [59]	valid_0's auc: 0.835797
# [60]	valid_0's auc: 0.835667
# [61]	valid_0's auc: 0.835487
# [62]	valid_0's auc: 0.835501
# [63]	valid_0's auc: 0.835688
# [64]	valid_0's auc: 0.835472
# [65]	valid_0's auc: 0.835812
# [66]	valid_0's auc: 0.835655
# [67]	valid_0's auc: 0.835788
# [68]	valid_0's auc: 0.835832
# [69]	valid_0's auc: 0.835773
# [70]	valid_0's auc: 0.835702
# [71]	valid_0's auc: 0.835879
# [72]	valid_0's auc: 0.835853
# [73]	valid_0's auc: 0.835251
# [74]	valid_0's auc: 0.835343
# [75]	valid_0's auc: 0.835017
# [76]	valid_0's auc: 0.834937
# [77]	valid_0's auc: 0.83525
# [78]	valid_0's auc: 0.835644
# [79]	valid_0's auc: 0.835408
# [80]	valid_0's auc: 0.83584
# [81]	valid_0's auc: 0.835432
# [82]	valid_0's auc: 0.835095
# [83]	valid_0's auc: 0.83494
# [84]	valid_0's auc: 0.834991
# [85]	valid_0's auc: 0.835267
# [86]	valid_0's auc: 0.835361
# [87]	valid_0's auc: 0.835119
# [88]	valid_0's auc: 0.834887
# [89]	valid_0's auc: 0.835125
# [90]	valid_0's auc: 0.835214
# [91]	valid_0's auc: 0.835271
# [92]	valid_0's auc: 0.834892
# [93]	valid_0's auc: 0.835495
# [94]	valid_0's auc: 0.835258
# [95]	valid_0's auc: 0.835326
# [96]	valid_0's auc: 0.835259
# [97]	valid_0's auc: 0.834877
# [98]	valid_0's auc: 0.834734
# [99]	valid_0's auc: 0.834755
# [100]	valid_0's auc: 0.834549
# [101]	valid_0's auc: 0.834512
# [102]	valid_0's auc: 0.834528
# [103]	valid_0's auc: 0.834609
# [104]	valid_0's auc: 0.834683
# [105]	valid_0's auc: 0.834488
# [106]	valid_0's auc: 0.834196
# [107]	valid_0's auc: 0.834691
# [108]	valid_0's auc: 0.834496
# [109]	valid_0's auc: 0.834053
# [110]	valid_0's auc: 0.834241
# [111]	valid_0's auc: 0.834113
# [112]	valid_0's auc: 0.834156
# [113]	valid_0's auc: 0.834218
# [114]	valid_0's auc: 0.834332
# [115]	valid_0's auc: 0.834758
# [116]	valid_0's auc: 0.834991
# [117]	valid_0's auc: 0.834861
# [118]	valid_0's auc: 0.83491
# [119]	valid_0's auc: 0.834534
# [120]	valid_0's auc: 0.834578
# [121]	valid_0's auc: 0.834793
# [122]	valid_0's auc: 0.834524
# [123]	valid_0's auc: 0.83438
# [124]	valid_0's auc: 0.834504
# [125]	valid_0's auc: 0.834542
# [126]	valid_0's auc: 0.834835
# [127]	valid_0's auc: 0.834958
# [128]	valid_0's auc: 0.834831
# [129]	valid_0's auc: 0.83469
# [130]	valid_0's auc: 0.834661
# [131]	valid_0's auc: 0.834898
# [132]	valid_0's auc: 0.834847
# [133]	valid_0's auc: 0.834461
# [134]	valid_0's auc: 0.834019
# [135]	valid_0's auc: 0.833559
# [136]	valid_0's auc: 0.833413
# [137]	valid_0's auc: 0.833825
# [138]	valid_0's auc: 0.833484
# [139]	valid_0's auc: 0.833685
# [140]	valid_0's auc: 0.833675
# [141]	valid_0's auc: 0.833506
# [142]	valid_0's auc: 0.833496
# [143]	valid_0's auc: 0.833426
# [144]	valid_0's auc: 0.833218
# [145]	valid_0's auc: 0.832996
# [146]	valid_0's auc: 0.832855
# [147]	valid_0's auc: 0.83275
# [148]	valid_0's auc: 0.8329
# [149]	valid_0's auc: 0.832722
# [150]	valid_0's auc: 0.832524
# [151]	valid_0's auc: 0.832737
# [152]	valid_0's auc: 0.832846
# [153]	valid_0's auc: 0.832614
# [154]	valid_0's auc: 0.832619
# [155]	valid_0's auc: 0.832476
# [156]	valid_0's auc: 0.832308
# [157]	valid_0's auc: 0.832225
# Early stopping, best iteration is:
# [57]	valid_0's auc: 0.836223
#
# fold 5
# [1]	valid_0's auc: 0.753799
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's auc: 0.788685
# [3]	valid_0's auc: 0.784382
# [4]	valid_0's auc: 0.794068
# [5]	valid_0's auc: 0.79594
# [6]	valid_0's auc: 0.798105
# [7]	valid_0's auc: 0.801004
# [8]	valid_0's auc: 0.804302
# [9]	valid_0's auc: 0.810143
# [10]	valid_0's auc: 0.80915
# [11]	valid_0's auc: 0.809964
# [12]	valid_0's auc: 0.812337
# [13]	valid_0's auc: 0.812123
# [14]	valid_0's auc: 0.814787
# [15]	valid_0's auc: 0.815805
# [16]	valid_0's auc: 0.816909
# [17]	valid_0's auc: 0.817527
# [18]	valid_0's auc: 0.818808
# [19]	valid_0's auc: 0.820158
# [20]	valid_0's auc: 0.821329
# [21]	valid_0's auc: 0.822646
# [22]	valid_0's auc: 0.824051
# [23]	valid_0's auc: 0.824301
# [24]	valid_0's auc: 0.824433
# [25]	valid_0's auc: 0.824619
# [26]	valid_0's auc: 0.825198
# [27]	valid_0's auc: 0.82546
# [28]	valid_0's auc: 0.826482
# [29]	valid_0's auc: 0.826288
# [30]	valid_0's auc: 0.826762
# [31]	valid_0's auc: 0.826908
# [32]	valid_0's auc: 0.827252
# [33]	valid_0's auc: 0.827151
# [34]	valid_0's auc: 0.826665
# [35]	valid_0's auc: 0.826821
# [36]	valid_0's auc: 0.82667
# [37]	valid_0's auc: 0.826426
# [38]	valid_0's auc: 0.825992
# [39]	valid_0's auc: 0.825447
# [40]	valid_0's auc: 0.82578
# [41]	valid_0's auc: 0.825568
# [42]	valid_0's auc: 0.825489
# [43]	valid_0's auc: 0.825731
# [44]	valid_0's auc: 0.826072
# [45]	valid_0's auc: 0.826217
# [46]	valid_0's auc: 0.826324
# [47]	valid_0's auc: 0.825901
# [48]	valid_0's auc: 0.825775
# [49]	valid_0's auc: 0.825838
# [50]	valid_0's auc: 0.825987
# [51]	valid_0's auc: 0.825898
# [52]	valid_0's auc: 0.825968
# [53]	valid_0's auc: 0.826321
# [54]	valid_0's auc: 0.826601
# [55]	valid_0's auc: 0.826101
# [56]	valid_0's auc: 0.82588
# [57]	valid_0's auc: 0.826433
# [58]	valid_0's auc: 0.826711
# [59]	valid_0's auc: 0.827214
# [60]	valid_0's auc: 0.827267
# [61]	valid_0's auc: 0.827618
# [62]	valid_0's auc: 0.827854
# [63]	valid_0's auc: 0.828283
# [64]	valid_0's auc: 0.828726
# [65]	valid_0's auc: 0.82892
# [66]	valid_0's auc: 0.828869
# [67]	valid_0's auc: 0.828951
# [68]	valid_0's auc: 0.828929
# [69]	valid_0's auc: 0.828877
# [70]	valid_0's auc: 0.829017
# [71]	valid_0's auc: 0.828449
# [72]	valid_0's auc: 0.828222
# [73]	valid_0's auc: 0.828285
# [74]	valid_0's auc: 0.828136
# [75]	valid_0's auc: 0.828317
# [76]	valid_0's auc: 0.828441
# [77]	valid_0's auc: 0.828658
# [78]	valid_0's auc: 0.82849
# [79]	valid_0's auc: 0.828583
# [80]	valid_0's auc: 0.828344
# [81]	valid_0's auc: 0.828191
# [82]	valid_0's auc: 0.828244
# [83]	valid_0's auc: 0.8284
# [84]	valid_0's auc: 0.828402
# [85]	valid_0's auc: 0.828175
# [86]	valid_0's auc: 0.82806
# [87]	valid_0's auc: 0.82802
# [88]	valid_0's auc: 0.827865
# [89]	valid_0's auc: 0.827461
# [90]	valid_0's auc: 0.827642
# [91]	valid_0's auc: 0.827771
# [92]	valid_0's auc: 0.827683
# [93]	valid_0's auc: 0.827258
# [94]	valid_0's auc: 0.827037
# [95]	valid_0's auc: 0.827192
# [96]	valid_0's auc: 0.82715
# [97]	valid_0's auc: 0.826996
# [98]	valid_0's auc: 0.827204
# [99]	valid_0's auc: 0.826774
# [100]	valid_0's auc: 0.826672
# [101]	valid_0's auc: 0.826719
# [102]	valid_0's auc: 0.826755
# [103]	valid_0's auc: 0.827086
# [104]	valid_0's auc: 0.826977
# [105]	valid_0's auc: 0.826731
# [106]	valid_0's auc: 0.826704
# [107]	valid_0's auc: 0.826472
# [108]	valid_0's auc: 0.826452
# [109]	valid_0's auc: 0.826375
# [110]	valid_0's auc: 0.826483
# [111]	valid_0's auc: 0.826617
# [112]	valid_0's auc: 0.826161
# [113]	valid_0's auc: 0.825972
# [114]	valid_0's auc: 0.825518
# [115]	valid_0's auc: 0.825609
# [116]	valid_0's auc: 0.825835
# [117]	valid_0's auc: 0.825975
# [118]	valid_0's auc: 0.825697
# [119]	valid_0's auc: 0.825669
# [120]	valid_0's auc: 0.825987
# [121]	valid_0's auc: 0.826313
# [122]	valid_0's auc: 0.826513
# [123]	valid_0's auc: 0.826512
# [124]	valid_0's auc: 0.826702
# [125]	valid_0's auc: 0.826936
# [126]	valid_0's auc: 0.827186
# [127]	valid_0's auc: 0.827684
# [128]	valid_0's auc: 0.827871
# [129]	valid_0's auc: 0.82805
# [130]	valid_0's auc: 0.827709
# [131]	valid_0's auc: 0.827961
# [132]	valid_0's auc: 0.827918
# [133]	valid_0's auc: 0.827878
# [134]	valid_0's auc: 0.828154
# [135]	valid_0's auc: 0.828263
# [136]	valid_0's auc: 0.828446
# [137]	valid_0's auc: 0.82853
# [138]	valid_0's auc: 0.82845
# [139]	valid_0's auc: 0.828337
# [140]	valid_0's auc: 0.828132
# [141]	valid_0's auc: 0.827884
# [142]	valid_0's auc: 0.827923
# [143]	valid_0's auc: 0.827874
# [144]	valid_0's auc: 0.827669
# [145]	valid_0's auc: 0.827306
# [146]	valid_0's auc: 0.827012
# [147]	valid_0's auc: 0.827048
# [148]	valid_0's auc: 0.826965
# [149]	valid_0's auc: 0.82672
# [150]	valid_0's auc: 0.826589
# [151]	valid_0's auc: 0.826377
# [152]	valid_0's auc: 0.826072
# [153]	valid_0's auc: 0.826121
# [154]	valid_0's auc: 0.826057
# [155]	valid_0's auc: 0.826453
# [156]	valid_0's auc: 0.826406
# [157]	valid_0's auc: 0.826541
# [158]	valid_0's auc: 0.826895
# [159]	valid_0's auc: 0.826658
# [160]	valid_0's auc: 0.826754
# [161]	valid_0's auc: 0.826973
# [162]	valid_0's auc: 0.827212
# [163]	valid_0's auc: 0.82771
# [164]	valid_0's auc: 0.828116
# [165]	valid_0's auc: 0.827839
# [166]	valid_0's auc: 0.827858
# [167]	valid_0's auc: 0.827804
# [168]	valid_0's auc: 0.827807
# [169]	valid_0's auc: 0.827666
# [170]	valid_0's auc: 0.827707
# Early stopping, best iteration is:
# [70]	valid_0's auc: 0.829017
#
# fold 6
# [1]	valid_0's auc: 0.770774
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's auc: 0.790765
# [3]	valid_0's auc: 0.792478
# [4]	valid_0's auc: 0.799611
# [5]	valid_0's auc: 0.805786
# [6]	valid_0's auc: 0.809352
# [7]	valid_0's auc: 0.814035
# [8]	valid_0's auc: 0.814933
# [9]	valid_0's auc: 0.8191
# [10]	valid_0's auc: 0.821744
# [11]	valid_0's auc: 0.823516
# [12]	valid_0's auc: 0.824687
# [13]	valid_0's auc: 0.825742
# [14]	valid_0's auc: 0.826948
# [15]	valid_0's auc: 0.827543
# [16]	valid_0's auc: 0.827963
# [17]	valid_0's auc: 0.827851
# [18]	valid_0's auc: 0.828305
# [19]	valid_0's auc: 0.828044
# [20]	valid_0's auc: 0.829479
# [21]	valid_0's auc: 0.829619
# [22]	valid_0's auc: 0.829544
# [23]	valid_0's auc: 0.830444
# [24]	valid_0's auc: 0.831116
# [25]	valid_0's auc: 0.831876
# [26]	valid_0's auc: 0.832365
# [27]	valid_0's auc: 0.833216
# [28]	valid_0's auc: 0.833602
# [29]	valid_0's auc: 0.834198
# [30]	valid_0's auc: 0.835105
# [31]	valid_0's auc: 0.835683
# [32]	valid_0's auc: 0.836029
# [33]	valid_0's auc: 0.835907
# [34]	valid_0's auc: 0.83615
# [35]	valid_0's auc: 0.836181
# [36]	valid_0's auc: 0.836512
# [37]	valid_0's auc: 0.836048
# [38]	valid_0's auc: 0.83571
# [39]	valid_0's auc: 0.836518
# [40]	valid_0's auc: 0.837125
# [41]	valid_0's auc: 0.837181
# [42]	valid_0's auc: 0.837424
# [43]	valid_0's auc: 0.837923
# [44]	valid_0's auc: 0.83812
# [45]	valid_0's auc: 0.838132
# [46]	valid_0's auc: 0.837976
# [47]	valid_0's auc: 0.838728
# [48]	valid_0's auc: 0.839081
# [49]	valid_0's auc: 0.839002
# [50]	valid_0's auc: 0.839544
# [51]	valid_0's auc: 0.839754
# [52]	valid_0's auc: 0.839286
# [53]	valid_0's auc: 0.83942
# [54]	valid_0's auc: 0.838772
# [55]	valid_0's auc: 0.838924
# [56]	valid_0's auc: 0.838965
# [57]	valid_0's auc: 0.838695
# [58]	valid_0's auc: 0.838342
# [59]	valid_0's auc: 0.838224
# [60]	valid_0's auc: 0.838682
# [61]	valid_0's auc: 0.83838
# [62]	valid_0's auc: 0.838466
# [63]	valid_0's auc: 0.838861
# [64]	valid_0's auc: 0.839217
# [65]	valid_0's auc: 0.839001
# [66]	valid_0's auc: 0.839375
# [67]	valid_0's auc: 0.839871
# [68]	valid_0's auc: 0.840118
# [69]	valid_0's auc: 0.840288
# [70]	valid_0's auc: 0.840613
# [71]	valid_0's auc: 0.840998
# [72]	valid_0's auc: 0.841243
# [73]	valid_0's auc: 0.840732
# [74]	valid_0's auc: 0.840915
# [75]	valid_0's auc: 0.84059
# [76]	valid_0's auc: 0.840607
# [77]	valid_0's auc: 0.8405
# [78]	valid_0's auc: 0.840619
# [79]	valid_0's auc: 0.840659
# [80]	valid_0's auc: 0.8406
# [81]	valid_0's auc: 0.840844
# [82]	valid_0's auc: 0.840561
# [83]	valid_0's auc: 0.840867
# [84]	valid_0's auc: 0.840568
# [85]	valid_0's auc: 0.84105
# [86]	valid_0's auc: 0.840844
# [87]	valid_0's auc: 0.841243
# [88]	valid_0's auc: 0.841418
# [89]	valid_0's auc: 0.841398
# [90]	valid_0's auc: 0.841309
# [91]	valid_0's auc: 0.841307
# [92]	valid_0's auc: 0.841478
# [93]	valid_0's auc: 0.841526
# [94]	valid_0's auc: 0.841565
# [95]	valid_0's auc: 0.841485
# [96]	valid_0's auc: 0.841398
# [97]	valid_0's auc: 0.841618
# [98]	valid_0's auc: 0.841707
# [99]	valid_0's auc: 0.842047
# [100]	valid_0's auc: 0.842519
# [101]	valid_0's auc: 0.842884
# [102]	valid_0's auc: 0.842778
# [103]	valid_0's auc: 0.843019
# [104]	valid_0's auc: 0.84315
# [105]	valid_0's auc: 0.84346
# [106]	valid_0's auc: 0.843116
# [107]	valid_0's auc: 0.843116
# [108]	valid_0's auc: 0.843234
# [109]	valid_0's auc: 0.842884
# [110]	valid_0's auc: 0.842459
# [111]	valid_0's auc: 0.842291
# [112]	valid_0's auc: 0.842123
# [113]	valid_0's auc: 0.841971
# [114]	valid_0's auc: 0.841919
# [115]	valid_0's auc: 0.841604
# [116]	valid_0's auc: 0.841574
# [117]	valid_0's auc: 0.841536
# [118]	valid_0's auc: 0.841431
# [119]	valid_0's auc: 0.841204
# [120]	valid_0's auc: 0.840913
# [121]	valid_0's auc: 0.841456
# [122]	valid_0's auc: 0.841906
# [123]	valid_0's auc: 0.841842
# [124]	valid_0's auc: 0.842116
# [125]	valid_0's auc: 0.842222
# [126]	valid_0's auc: 0.842325
# [127]	valid_0's auc: 0.842437
# [128]	valid_0's auc: 0.842667
# [129]	valid_0's auc: 0.842897
# [130]	valid_0's auc: 0.843182
# [131]	valid_0's auc: 0.843314
# [132]	valid_0's auc: 0.843401
# [133]	valid_0's auc: 0.843371
# [134]	valid_0's auc: 0.843036
# [135]	valid_0's auc: 0.842961
# [136]	valid_0's auc: 0.843027
# [137]	valid_0's auc: 0.843241
# [138]	valid_0's auc: 0.84355
# [139]	valid_0's auc: 0.843852
# [140]	valid_0's auc: 0.844216
# [141]	valid_0's auc: 0.844197
# [142]	valid_0's auc: 0.844279
# [143]	valid_0's auc: 0.844302
# [144]	valid_0's auc: 0.844203
# [145]	valid_0's auc: 0.844478
# [146]	valid_0's auc: 0.844287
# [147]	valid_0's auc: 0.844121
# [148]	valid_0's auc: 0.844225
# [149]	valid_0's auc: 0.844102
# [150]	valid_0's auc: 0.843978
# [151]	valid_0's auc: 0.843869
# [152]	valid_0's auc: 0.84388
# [153]	valid_0's auc: 0.843993
# [154]	valid_0's auc: 0.844116
# [155]	valid_0's auc: 0.844176
# [156]	valid_0's auc: 0.844229
# [157]	valid_0's auc: 0.844365
# [158]	valid_0's auc: 0.844259
# [159]	valid_0's auc: 0.844257
# [160]	valid_0's auc: 0.843974
# [161]	valid_0's auc: 0.844408
# [162]	valid_0's auc: 0.844381
# [163]	valid_0's auc: 0.844559
# [164]	valid_0's auc: 0.844602
# [165]	valid_0's auc: 0.844494
# [166]	valid_0's auc: 0.844968
# [167]	valid_0's auc: 0.844861
# [168]	valid_0's auc: 0.844509
# [169]	valid_0's auc: 0.844423
# [170]	valid_0's auc: 0.84437
# [171]	valid_0's auc: 0.844387
# [172]	valid_0's auc: 0.844505
# [173]	valid_0's auc: 0.844428
# [174]	valid_0's auc: 0.844245
# [175]	valid_0's auc: 0.843902
# [176]	valid_0's auc: 0.843763
# [177]	valid_0's auc: 0.843425
# [178]	valid_0's auc: 0.84332
# [179]	valid_0's auc: 0.843345
# [180]	valid_0's auc: 0.84354
# [181]	valid_0's auc: 0.843433
# [182]	valid_0's auc: 0.843615
# [183]	valid_0's auc: 0.843147
# [184]	valid_0's auc: 0.843141
# [185]	valid_0's auc: 0.843031
# [186]	valid_0's auc: 0.843107
# [187]	valid_0's auc: 0.842976
# [188]	valid_0's auc: 0.842882
# [189]	valid_0's auc: 0.843
# [190]	valid_0's auc: 0.842903
# [191]	valid_0's auc: 0.842724
# [192]	valid_0's auc: 0.842513
# [193]	valid_0's auc: 0.842383
# [194]	valid_0's auc: 0.842413
# [195]	valid_0's auc: 0.842333
# [196]	valid_0's auc: 0.842002
# [197]	valid_0's auc: 0.841822
# [198]	valid_0's auc: 0.841704
# [199]	valid_0's auc: 0.841571
# [200]	valid_0's auc: 0.841532
# Did not meet early stopping. Best iteration is:
# [166]	valid_0's auc: 0.844968
#
# fold 7
# [1]	valid_0's auc: 0.770233
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's auc: 0.816964
# [3]	valid_0's auc: 0.820686
# [4]	valid_0's auc: 0.82455
# [5]	valid_0's auc: 0.83032
# [6]	valid_0's auc: 0.831603
# [7]	valid_0's auc: 0.833555
# [8]	valid_0's auc: 0.835044
# [9]	valid_0's auc: 0.834832
# [10]	valid_0's auc: 0.833056
# [11]	valid_0's auc: 0.83325
# [12]	valid_0's auc: 0.834166
# [13]	valid_0's auc: 0.834892
# [14]	valid_0's auc: 0.836052
# [15]	valid_0's auc: 0.837432
# [16]	valid_0's auc: 0.83835
# [17]	valid_0's auc: 0.839034
# [18]	valid_0's auc: 0.838951
# [19]	valid_0's auc: 0.838978
# [20]	valid_0's auc: 0.839161
# [21]	valid_0's auc: 0.839358
# [22]	valid_0's auc: 0.839427
# [23]	valid_0's auc: 0.839661
# [24]	valid_0's auc: 0.840055
# [25]	valid_0's auc: 0.839981
# [26]	valid_0's auc: 0.840226
# [27]	valid_0's auc: 0.840624
# [28]	valid_0's auc: 0.840196
# [29]	valid_0's auc: 0.840447
# [30]	valid_0's auc: 0.840698
# [31]	valid_0's auc: 0.841182
# [32]	valid_0's auc: 0.841436
# [33]	valid_0's auc: 0.841896
# [34]	valid_0's auc: 0.842395
# [35]	valid_0's auc: 0.842999
# [36]	valid_0's auc: 0.843454
# [37]	valid_0's auc: 0.843687
# [38]	valid_0's auc: 0.843673
# [39]	valid_0's auc: 0.844152
# [40]	valid_0's auc: 0.844178
# [41]	valid_0's auc: 0.844232
# [42]	valid_0's auc: 0.844597
# [43]	valid_0's auc: 0.845194
# [44]	valid_0's auc: 0.844843
# [45]	valid_0's auc: 0.844219
# [46]	valid_0's auc: 0.844594
# [47]	valid_0's auc: 0.844244
# [48]	valid_0's auc: 0.844296
# [49]	valid_0's auc: 0.845055
# [50]	valid_0's auc: 0.845809
# [51]	valid_0's auc: 0.845364
# [52]	valid_0's auc: 0.845646
# [53]	valid_0's auc: 0.845723
# [54]	valid_0's auc: 0.846289
# [55]	valid_0's auc: 0.84647
# [56]	valid_0's auc: 0.84662
# [57]	valid_0's auc: 0.846475
# [58]	valid_0's auc: 0.846968
# [59]	valid_0's auc: 0.846944
# [60]	valid_0's auc: 0.847563
# [61]	valid_0's auc: 0.848118
# [62]	valid_0's auc: 0.84783
# [63]	valid_0's auc: 0.848359
# [64]	valid_0's auc: 0.848263
# [65]	valid_0's auc: 0.848368
# [66]	valid_0's auc: 0.848878
# [67]	valid_0's auc: 0.848582
# [68]	valid_0's auc: 0.848419
# [69]	valid_0's auc: 0.848532
# [70]	valid_0's auc: 0.848459
# [71]	valid_0's auc: 0.848527
# [72]	valid_0's auc: 0.848616
# [73]	valid_0's auc: 0.848596
# [74]	valid_0's auc: 0.848506
# [75]	valid_0's auc: 0.848372
# [76]	valid_0's auc: 0.848704
# [77]	valid_0's auc: 0.848344
# [78]	valid_0's auc: 0.848431
# [79]	valid_0's auc: 0.848305
# [80]	valid_0's auc: 0.848439
# [81]	valid_0's auc: 0.848578
# [82]	valid_0's auc: 0.849123
# [83]	valid_0's auc: 0.850021
# [84]	valid_0's auc: 0.850106
# [85]	valid_0's auc: 0.849887
# [86]	valid_0's auc: 0.850028
# [87]	valid_0's auc: 0.850031
# [88]	valid_0's auc: 0.850225
# [89]	valid_0's auc: 0.850081
# [90]	valid_0's auc: 0.850356
# [91]	valid_0's auc: 0.850436
# [92]	valid_0's auc: 0.850386
# [93]	valid_0's auc: 0.850749
# [94]	valid_0's auc: 0.850685
# [95]	valid_0's auc: 0.850523
# [96]	valid_0's auc: 0.850597
# [97]	valid_0's auc: 0.850876
# [98]	valid_0's auc: 0.850838
# [99]	valid_0's auc: 0.85083
# [100]	valid_0's auc: 0.850697
# [101]	valid_0's auc: 0.850758
# [102]	valid_0's auc: 0.850536
# [103]	valid_0's auc: 0.850482
# [104]	valid_0's auc: 0.850383
# [105]	valid_0's auc: 0.850155
# [106]	valid_0's auc: 0.850401
# [107]	valid_0's auc: 0.850377
# [108]	valid_0's auc: 0.850543
# [109]	valid_0's auc: 0.850719
# [110]	valid_0's auc: 0.850646
# [111]	valid_0's auc: 0.851085
# [112]	valid_0's auc: 0.851041
# [113]	valid_0's auc: 0.850867
# [114]	valid_0's auc: 0.850839
# [115]	valid_0's auc: 0.851081
# [116]	valid_0's auc: 0.851077
# [117]	valid_0's auc: 0.851006
# [118]	valid_0's auc: 0.851157
# [119]	valid_0's auc: 0.850768
# [120]	valid_0's auc: 0.850627
# [121]	valid_0's auc: 0.850439
# [122]	valid_0's auc: 0.85047
# [123]	valid_0's auc: 0.85035
# [124]	valid_0's auc: 0.850153
# [125]	valid_0's auc: 0.850076
# [126]	valid_0's auc: 0.850185
# [127]	valid_0's auc: 0.850097
# [128]	valid_0's auc: 0.850129
# [129]	valid_0's auc: 0.84998
# [130]	valid_0's auc: 0.850229
# [131]	valid_0's auc: 0.850001
# [132]	valid_0's auc: 0.85026
# [133]	valid_0's auc: 0.850307
# [134]	valid_0's auc: 0.850398
# [135]	valid_0's auc: 0.850148
# [136]	valid_0's auc: 0.850191
# [137]	valid_0's auc: 0.850523
# [138]	valid_0's auc: 0.85029
# [139]	valid_0's auc: 0.849904
# [140]	valid_0's auc: 0.850104
# [141]	valid_0's auc: 0.849651
# [142]	valid_0's auc: 0.849477
# [143]	valid_0's auc: 0.849629
# [144]	valid_0's auc: 0.849532
# [145]	valid_0's auc: 0.849282
# [146]	valid_0's auc: 0.84914
# [147]	valid_0's auc: 0.849302
# [148]	valid_0's auc: 0.849853
# [149]	valid_0's auc: 0.850168
# [150]	valid_0's auc: 0.849997
# [151]	valid_0's auc: 0.850009
# [152]	valid_0's auc: 0.849773
# [153]	valid_0's auc: 0.850146
# [154]	valid_0's auc: 0.850492
# [155]	valid_0's auc: 0.850635
# [156]	valid_0's auc: 0.850486
# [157]	valid_0's auc: 0.850374
# [158]	valid_0's auc: 0.850484
# [159]	valid_0's auc: 0.850507
# [160]	valid_0's auc: 0.850578
# [161]	valid_0's auc: 0.850968
# [162]	valid_0's auc: 0.850737
# [163]	valid_0's auc: 0.850852
# [164]	valid_0's auc: 0.850971
# [165]	valid_0's auc: 0.850694
# [166]	valid_0's auc: 0.850241
# [167]	valid_0's auc: 0.850234
# [168]	valid_0's auc: 0.850291
# [169]	valid_0's auc: 0.850255
# [170]	valid_0's auc: 0.849789
# [171]	valid_0's auc: 0.849405
# [172]	valid_0's auc: 0.849353
# [173]	valid_0's auc: 0.84942
# [174]	valid_0's auc: 0.849109
# [175]	valid_0's auc: 0.849072
# [176]	valid_0's auc: 0.848858
# [177]	valid_0's auc: 0.849114
# [178]	valid_0's auc: 0.848899
# [179]	valid_0's auc: 0.849159
# [180]	valid_0's auc: 0.849105
# [181]	valid_0's auc: 0.849296
# [182]	valid_0's auc: 0.849336
# [183]	valid_0's auc: 0.84918
# [184]	valid_0's auc: 0.848904
# [185]	valid_0's auc: 0.849119
# [186]	valid_0's auc: 0.848888
# [187]	valid_0's auc: 0.848602
# [188]	valid_0's auc: 0.848278
# [189]	valid_0's auc: 0.84776
# [190]	valid_0's auc: 0.847815
# [191]	valid_0's auc: 0.847883
# [192]	valid_0's auc: 0.847911
# [193]	valid_0's auc: 0.847756
# [194]	valid_0's auc: 0.847543
# [195]	valid_0's auc: 0.847484
# [196]	valid_0's auc: 0.847171
# [197]	valid_0's auc: 0.847068
# [198]	valid_0's auc: 0.846785
# [199]	valid_0's auc: 0.846821
# [200]	valid_0's auc: 0.846995
# Did not meet early stopping. Best iteration is:
# [118]	valid_0's auc: 0.851157
#
# fold 8
# [1]	valid_0's auc: 0.770547
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's auc: 0.802023
# [3]	valid_0's auc: 0.805268
# [4]	valid_0's auc: 0.812102
# [5]	valid_0's auc: 0.815091
# [6]	valid_0's auc: 0.813559
# [7]	valid_0's auc: 0.813989
# [8]	valid_0's auc: 0.817285
# [9]	valid_0's auc: 0.821457
# [10]	valid_0's auc: 0.823598
# [11]	valid_0's auc: 0.823611
# [12]	valid_0's auc: 0.826966
# [13]	valid_0's auc: 0.828132
# [14]	valid_0's auc: 0.829351
# [15]	valid_0's auc: 0.830176
# [16]	valid_0's auc: 0.831685
# [17]	valid_0's auc: 0.834049
# [18]	valid_0's auc: 0.834827
# [19]	valid_0's auc: 0.834826
# [20]	valid_0's auc: 0.836009
# [21]	valid_0's auc: 0.835253
# [22]	valid_0's auc: 0.835561
# [23]	valid_0's auc: 0.836079
# [24]	valid_0's auc: 0.836924
# [25]	valid_0's auc: 0.838299
# [26]	valid_0's auc: 0.839176
# [27]	valid_0's auc: 0.8399
# [28]	valid_0's auc: 0.840596
# [29]	valid_0's auc: 0.841271
# [30]	valid_0's auc: 0.842163
# [31]	valid_0's auc: 0.842764
# [32]	valid_0's auc: 0.842884
# [33]	valid_0's auc: 0.843392
# [34]	valid_0's auc: 0.844489
# [35]	valid_0's auc: 0.845378
# [36]	valid_0's auc: 0.845492
# [37]	valid_0's auc: 0.845314
# [38]	valid_0's auc: 0.84564
# [39]	valid_0's auc: 0.845928
# [40]	valid_0's auc: 0.846244
# [41]	valid_0's auc: 0.846873
# [42]	valid_0's auc: 0.847281
# [43]	valid_0's auc: 0.847617
# [44]	valid_0's auc: 0.847719
# [45]	valid_0's auc: 0.847909
# [46]	valid_0's auc: 0.848197
# [47]	valid_0's auc: 0.847981
# [48]	valid_0's auc: 0.848361
# [49]	valid_0's auc: 0.84828
# [50]	valid_0's auc: 0.848666
# [51]	valid_0's auc: 0.848694
# [52]	valid_0's auc: 0.849216
# [53]	valid_0's auc: 0.849345
# [54]	valid_0's auc: 0.849034
# [55]	valid_0's auc: 0.849222
# [56]	valid_0's auc: 0.849502
# [57]	valid_0's auc: 0.849619
# [58]	valid_0's auc: 0.849933
# [59]	valid_0's auc: 0.849919
# [60]	valid_0's auc: 0.84971
# [61]	valid_0's auc: 0.849617
# [62]	valid_0's auc: 0.849544
# [63]	valid_0's auc: 0.849913
# [64]	valid_0's auc: 0.849912
# [65]	valid_0's auc: 0.850019
# [66]	valid_0's auc: 0.850119
# [67]	valid_0's auc: 0.850354
# [68]	valid_0's auc: 0.850436
# [69]	valid_0's auc: 0.851137
# [70]	valid_0's auc: 0.851468
# [71]	valid_0's auc: 0.851345
# [72]	valid_0's auc: 0.851198
# [73]	valid_0's auc: 0.850799
# [74]	valid_0's auc: 0.850586
# [75]	valid_0's auc: 0.850898
# [76]	valid_0's auc: 0.850987
# [77]	valid_0's auc: 0.850723
# [78]	valid_0's auc: 0.851104
# [79]	valid_0's auc: 0.851107
# [80]	valid_0's auc: 0.850905
# [81]	valid_0's auc: 0.850825
# [82]	valid_0's auc: 0.85086
# [83]	valid_0's auc: 0.850929
# [84]	valid_0's auc: 0.851005
# [85]	valid_0's auc: 0.851216
# [86]	valid_0's auc: 0.851073
# [87]	valid_0's auc: 0.851109
# [88]	valid_0's auc: 0.851135
# [89]	valid_0's auc: 0.851064
# [90]	valid_0's auc: 0.850849
# [91]	valid_0's auc: 0.850911
# [92]	valid_0's auc: 0.850687
# [93]	valid_0's auc: 0.850656
# [94]	valid_0's auc: 0.850755
# [95]	valid_0's auc: 0.851313
# [96]	valid_0's auc: 0.851229
# [97]	valid_0's auc: 0.851251
# [98]	valid_0's auc: 0.851093
# [99]	valid_0's auc: 0.851091
# [100]	valid_0's auc: 0.851494
# [101]	valid_0's auc: 0.851087
# [102]	valid_0's auc: 0.850789
# [103]	valid_0's auc: 0.851301
# [104]	valid_0's auc: 0.851167
# [105]	valid_0's auc: 0.851608
# [106]	valid_0's auc: 0.851424
# [107]	valid_0's auc: 0.851411
# [108]	valid_0's auc: 0.851633
# [109]	valid_0's auc: 0.851902
# [110]	valid_0's auc: 0.851864
# [111]	valid_0's auc: 0.851826
# [112]	valid_0's auc: 0.851682
# [113]	valid_0's auc: 0.851754
# [114]	valid_0's auc: 0.852151
# [115]	valid_0's auc: 0.852474
# [116]	valid_0's auc: 0.852714
# [117]	valid_0's auc: 0.852709
# [118]	valid_0's auc: 0.852718
# [119]	valid_0's auc: 0.85274
# [120]	valid_0's auc: 0.853042
# [121]	valid_0's auc: 0.853334
# [122]	valid_0's auc: 0.853103
# [123]	valid_0's auc: 0.85343
# [124]	valid_0's auc: 0.853573
# [125]	valid_0's auc: 0.853127
# [126]	valid_0's auc: 0.852981
# [127]	valid_0's auc: 0.85304
# [128]	valid_0's auc: 0.85298
# [129]	valid_0's auc: 0.85308
# [130]	valid_0's auc: 0.853013
# [131]	valid_0's auc: 0.853008
# [132]	valid_0's auc: 0.85259
# [133]	valid_0's auc: 0.852534
# [134]	valid_0's auc: 0.852477
# [135]	valid_0's auc: 0.852092
# [136]	valid_0's auc: 0.851882
# [137]	valid_0's auc: 0.85189
# [138]	valid_0's auc: 0.851982
# [139]	valid_0's auc: 0.851953
# [140]	valid_0's auc: 0.851898
# [141]	valid_0's auc: 0.851796
# [142]	valid_0's auc: 0.851643
# [143]	valid_0's auc: 0.851758
# [144]	valid_0's auc: 0.852136
# [145]	valid_0's auc: 0.852093
# [146]	valid_0's auc: 0.852179
# [147]	valid_0's auc: 0.85212
# [148]	valid_0's auc: 0.852338
# [149]	valid_0's auc: 0.852563
# [150]	valid_0's auc: 0.852863
# [151]	valid_0's auc: 0.853135
# [152]	valid_0's auc: 0.853091
# [153]	valid_0's auc: 0.853083
# [154]	valid_0's auc: 0.853023
# [155]	valid_0's auc: 0.852966
# [156]	valid_0's auc: 0.852943
# [157]	valid_0's auc: 0.852662
# [158]	valid_0's auc: 0.852451
# [159]	valid_0's auc: 0.852276
# [160]	valid_0's auc: 0.852141
# [161]	valid_0's auc: 0.852292
# [162]	valid_0's auc: 0.852671
# [163]	valid_0's auc: 0.852703
# [164]	valid_0's auc: 0.852651
# [165]	valid_0's auc: 0.852755
# [166]	valid_0's auc: 0.852882
# [167]	valid_0's auc: 0.852844
# [168]	valid_0's auc: 0.852752
# [169]	valid_0's auc: 0.852715
# [170]	valid_0's auc: 0.852723
# [171]	valid_0's auc: 0.852616
# [172]	valid_0's auc: 0.852694
# [173]	valid_0's auc: 0.852429
# [174]	valid_0's auc: 0.852219
# [175]	valid_0's auc: 0.852566
# [176]	valid_0's auc: 0.852648
# [177]	valid_0's auc: 0.852881
# [178]	valid_0's auc: 0.852505
# [179]	valid_0's auc: 0.852398
# [180]	valid_0's auc: 0.852279
# [181]	valid_0's auc: 0.852348
# [182]	valid_0's auc: 0.852365
# [183]	valid_0's auc: 0.85241
# [184]	valid_0's auc: 0.852404
# [185]	valid_0's auc: 0.85244
# [186]	valid_0's auc: 0.852361
# [187]	valid_0's auc: 0.852304
# [188]	valid_0's auc: 0.852412
# [189]	valid_0's auc: 0.852588
# [190]	valid_0's auc: 0.852611
# [191]	valid_0's auc: 0.85293
# [192]	valid_0's auc: 0.852927
# [193]	valid_0's auc: 0.852855
# [194]	valid_0's auc: 0.852765
# [195]	valid_0's auc: 0.852797
# [196]	valid_0's auc: 0.85269
# [197]	valid_0's auc: 0.852437
# [198]	valid_0's auc: 0.85237
# [199]	valid_0's auc: 0.852248
# [200]	valid_0's auc: 0.852344
# Did not meet early stopping. Best iteration is:
# [124]	valid_0's auc: 0.853573
#
# fold 9
# [1]	valid_0's auc: 0.756613
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's auc: 0.787848
# [3]	valid_0's auc: 0.788851
# [4]	valid_0's auc: 0.800834
# [5]	valid_0's auc: 0.809406
# [6]	valid_0's auc: 0.810727
# [7]	valid_0's auc: 0.812357
# [8]	valid_0's auc: 0.814589
# [9]	valid_0's auc: 0.816423
# [10]	valid_0's auc: 0.817327
# [11]	valid_0's auc: 0.815966
# [12]	valid_0's auc: 0.817067
# [13]	valid_0's auc: 0.816685
# [14]	valid_0's auc: 0.817513
# [15]	valid_0's auc: 0.818005
# [16]	valid_0's auc: 0.817665
# [17]	valid_0's auc: 0.817451
# [18]	valid_0's auc: 0.817124
# [19]	valid_0's auc: 0.818498
# [20]	valid_0's auc: 0.818921
# [21]	valid_0's auc: 0.81953
# [22]	valid_0's auc: 0.81971
# [23]	valid_0's auc: 0.820588
# [24]	valid_0's auc: 0.820128
# [25]	valid_0's auc: 0.819851
# [26]	valid_0's auc: 0.820154
# [27]	valid_0's auc: 0.820624
# [28]	valid_0's auc: 0.820918
# [29]	valid_0's auc: 0.821208
# [30]	valid_0's auc: 0.821626
# [31]	valid_0's auc: 0.821977
# [32]	valid_0's auc: 0.822132
# [33]	valid_0's auc: 0.822345
# [34]	valid_0's auc: 0.823318
# [35]	valid_0's auc: 0.823466
# [36]	valid_0's auc: 0.823889
# [37]	valid_0's auc: 0.824114
# [38]	valid_0's auc: 0.82437
# [39]	valid_0's auc: 0.824684
# [40]	valid_0's auc: 0.824853
# [41]	valid_0's auc: 0.824907
# [42]	valid_0's auc: 0.825189
# [43]	valid_0's auc: 0.825679
# [44]	valid_0's auc: 0.825586
# [45]	valid_0's auc: 0.825832
# [46]	valid_0's auc: 0.825976
# [47]	valid_0's auc: 0.826532
# [48]	valid_0's auc: 0.827099
# [49]	valid_0's auc: 0.826523
# [50]	valid_0's auc: 0.82684
# [51]	valid_0's auc: 0.826869
# [52]	valid_0's auc: 0.826347
# [53]	valid_0's auc: 0.826657
# [54]	valid_0's auc: 0.826695
# [55]	valid_0's auc: 0.826697
# [56]	valid_0's auc: 0.826902
# [57]	valid_0's auc: 0.827286
# [58]	valid_0's auc: 0.827135
# [59]	valid_0's auc: 0.827181
# [60]	valid_0's auc: 0.827288
# [61]	valid_0's auc: 0.827074
# [62]	valid_0's auc: 0.82768
# [63]	valid_0's auc: 0.827521
# [64]	valid_0's auc: 0.827522
# [65]	valid_0's auc: 0.827709
# [66]	valid_0's auc: 0.827823
# [67]	valid_0's auc: 0.828317
# [68]	valid_0's auc: 0.828253
# [69]	valid_0's auc: 0.828583
# [70]	valid_0's auc: 0.828851
# [71]	valid_0's auc: 0.828196
# [72]	valid_0's auc: 0.827873
# [73]	valid_0's auc: 0.827901
# [74]	valid_0's auc: 0.828739
# [75]	valid_0's auc: 0.828275
# [76]	valid_0's auc: 0.827992
# [77]	valid_0's auc: 0.828142
# [78]	valid_0's auc: 0.828205
# [79]	valid_0's auc: 0.827927
# [80]	valid_0's auc: 0.827768
# [81]	valid_0's auc: 0.827891
# [82]	valid_0's auc: 0.82754
# [83]	valid_0's auc: 0.827771
# [84]	valid_0's auc: 0.827487
# [85]	valid_0's auc: 0.82745
# [86]	valid_0's auc: 0.827465
# [87]	valid_0's auc: 0.828012
# [88]	valid_0's auc: 0.828303
# [89]	valid_0's auc: 0.828849
# [90]	valid_0's auc: 0.828621
# [91]	valid_0's auc: 0.828797
# [92]	valid_0's auc: 0.828695
# [93]	valid_0's auc: 0.828836
# [94]	valid_0's auc: 0.829203
# [95]	valid_0's auc: 0.829037
# [96]	valid_0's auc: 0.828798
# [97]	valid_0's auc: 0.828902
# [98]	valid_0's auc: 0.828826
# [99]	valid_0's auc: 0.828485
# [100]	valid_0's auc: 0.828863
# [101]	valid_0's auc: 0.828832
# [102]	valid_0's auc: 0.828866
# [103]	valid_0's auc: 0.828969
# [104]	valid_0's auc: 0.828753
# [105]	valid_0's auc: 0.82868
# [106]	valid_0's auc: 0.828302
# [107]	valid_0's auc: 0.827774
# [108]	valid_0's auc: 0.827319
# [109]	valid_0's auc: 0.827131
# [110]	valid_0's auc: 0.827183
# [111]	valid_0's auc: 0.827519
# [112]	valid_0's auc: 0.827549
# [113]	valid_0's auc: 0.8269
# [114]	valid_0's auc: 0.8269
# [115]	valid_0's auc: 0.826979
# [116]	valid_0's auc: 0.827262
# [117]	valid_0's auc: 0.82747
# [118]	valid_0's auc: 0.827937
# [119]	valid_0's auc: 0.828128
# [120]	valid_0's auc: 0.828304
# [121]	valid_0's auc: 0.827989
# [122]	valid_0's auc: 0.827685
# [123]	valid_0's auc: 0.827381
# [124]	valid_0's auc: 0.827135
# [125]	valid_0's auc: 0.827321
# [126]	valid_0's auc: 0.827178
# [127]	valid_0's auc: 0.827311
# [128]	valid_0's auc: 0.827717
# [129]	valid_0's auc: 0.828133
# [130]	valid_0's auc: 0.828
# [131]	valid_0's auc: 0.827804
# [132]	valid_0's auc: 0.827604
# [133]	valid_0's auc: 0.827985
# [134]	valid_0's auc: 0.8278
# [135]	valid_0's auc: 0.827844
# [136]	valid_0's auc: 0.827824
# [137]	valid_0's auc: 0.828021
# [138]	valid_0's auc: 0.828294
# [139]	valid_0's auc: 0.828187
# [140]	valid_0's auc: 0.827975
# [141]	valid_0's auc: 0.827847
# [142]	valid_0's auc: 0.827805
# [143]	valid_0's auc: 0.827759
# [144]	valid_0's auc: 0.827774
# [145]	valid_0's auc: 0.827849
# [146]	valid_0's auc: 0.827742
# [147]	valid_0's auc: 0.827798
# [148]	valid_0's auc: 0.827747
# [149]	valid_0's auc: 0.827806
# [150]	valid_0's auc: 0.827948
# [151]	valid_0's auc: 0.828057
# [152]	valid_0's auc: 0.828139
# [153]	valid_0's auc: 0.828345
# [154]	valid_0's auc: 0.828402
# [155]	valid_0's auc: 0.828161
# [156]	valid_0's auc: 0.827789
# [157]	valid_0's auc: 0.827635
# [158]	valid_0's auc: 0.827582
# [159]	valid_0's auc: 0.827762
# [160]	valid_0's auc: 0.827849
# [161]	valid_0's auc: 0.827855
# [162]	valid_0's auc: 0.828528
# [163]	valid_0's auc: 0.829021
# [164]	valid_0's auc: 0.829252
# [165]	valid_0's auc: 0.829391
# [166]	valid_0's auc: 0.829156
# [167]	valid_0's auc: 0.829115
# [168]	valid_0's auc: 0.82922
# [169]	valid_0's auc: 0.829226
# [170]	valid_0's auc: 0.829204
# [171]	valid_0's auc: 0.829298
# [172]	valid_0's auc: 0.829448
# [173]	valid_0's auc: 0.829371
# [174]	valid_0's auc: 0.829405
# [175]	valid_0's auc: 0.829355
# [176]	valid_0's auc: 0.8294
# [177]	valid_0's auc: 0.829519
# [178]	valid_0's auc: 0.830008
# [179]	valid_0's auc: 0.829796
# [180]	valid_0's auc: 0.829731
# [181]	valid_0's auc: 0.829907
# [182]	valid_0's auc: 0.829835
# [183]	valid_0's auc: 0.829599
# [184]	valid_0's auc: 0.82999
# [185]	valid_0's auc: 0.830125
# [186]	valid_0's auc: 0.830173
# [187]	valid_0's auc: 0.830004
# [188]	valid_0's auc: 0.82991
# [189]	valid_0's auc: 0.830346
# [190]	valid_0's auc: 0.830603
# [191]	valid_0's auc: 0.830792
# [192]	valid_0's auc: 0.830679
# [193]	valid_0's auc: 0.830387
# [194]	valid_0's auc: 0.830506
# [195]	valid_0's auc: 0.8302
# [196]	valid_0's auc: 0.830076
# [197]	valid_0's auc: 0.829941
# [198]	valid_0's auc: 0.830066
# [199]	valid_0's auc: 0.829963
# [200]	valid_0's auc: 0.830207
# Did not meet early stopping. Best iteration is:
# [191]	valid_0's auc: 0.830792
# fold 10
# [1]	valid_0's auc: 0.766277
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's auc: 0.80796
# [3]	valid_0's auc: 0.80452
# [4]	valid_0's auc: 0.809259
# [5]	valid_0's auc: 0.815189
# [6]	valid_0's auc: 0.82113
# [7]	valid_0's auc: 0.823174
# [8]	valid_0's auc: 0.823445
# [9]	valid_0's auc: 0.825395
# [10]	valid_0's auc: 0.826179
# [11]	valid_0's auc: 0.826677
# [12]	valid_0's auc: 0.828966
# [13]	valid_0's auc: 0.829331
# [14]	valid_0's auc: 0.830505
# [15]	valid_0's auc: 0.832155
# [16]	valid_0's auc: 0.832341
# [17]	valid_0's auc: 0.832986
# [18]	valid_0's auc: 0.83284
# [19]	valid_0's auc: 0.833351
# [20]	valid_0's auc: 0.833833
# [21]	valid_0's auc: 0.83443
# [22]	valid_0's auc: 0.835003
# [23]	valid_0's auc: 0.835881
# [24]	valid_0's auc: 0.836106
# [25]	valid_0's auc: 0.836272
# [26]	valid_0's auc: 0.837095
# [27]	valid_0's auc: 0.838818
# [28]	valid_0's auc: 0.839362
# [29]	valid_0's auc: 0.839459
# [30]	valid_0's auc: 0.840864
# [31]	valid_0's auc: 0.841544
# [32]	valid_0's auc: 0.841771
# [33]	valid_0's auc: 0.841416
# [34]	valid_0's auc: 0.841052
# [35]	valid_0's auc: 0.84121
# [36]	valid_0's auc: 0.840799
# [37]	valid_0's auc: 0.840605
# [38]	valid_0's auc: 0.84039
# [39]	valid_0's auc: 0.840874
# [40]	valid_0's auc: 0.841155
# [41]	valid_0's auc: 0.841889
# [42]	valid_0's auc: 0.842303
# [43]	valid_0's auc: 0.842549
# [44]	valid_0's auc: 0.842152
# [45]	valid_0's auc: 0.841674
# [46]	valid_0's auc: 0.842127
# [47]	valid_0's auc: 0.841617
# [48]	valid_0's auc: 0.841428
# [49]	valid_0's auc: 0.841284
# [50]	valid_0's auc: 0.841275
# [51]	valid_0's auc: 0.841557
# [52]	valid_0's auc: 0.841284
# [53]	valid_0's auc: 0.84141
# [54]	valid_0's auc: 0.841055
# [55]	valid_0's auc: 0.840979
# [56]	valid_0's auc: 0.841211
# [57]	valid_0's auc: 0.841105
# [58]	valid_0's auc: 0.841134
# [59]	valid_0's auc: 0.841243
# [60]	valid_0's auc: 0.841421
# [61]	valid_0's auc: 0.84122
# [62]	valid_0's auc: 0.841443
# [63]	valid_0's auc: 0.84114
# [64]	valid_0's auc: 0.841236
# [65]	valid_0's auc: 0.841097
# [66]	valid_0's auc: 0.841227
# [67]	valid_0's auc: 0.841112
# [68]	valid_0's auc: 0.840681
# [69]	valid_0's auc: 0.840993
# [70]	valid_0's auc: 0.841099
# [71]	valid_0's auc: 0.841063
# [72]	valid_0's auc: 0.840876
# [73]	valid_0's auc: 0.841066
# [74]	valid_0's auc: 0.840728
# [75]	valid_0's auc: 0.840575
# [76]	valid_0's auc: 0.840542
# [77]	valid_0's auc: 0.8408
# [78]	valid_0's auc: 0.840641
# [79]	valid_0's auc: 0.840442
# [80]	valid_0's auc: 0.840728
# [81]	valid_0's auc: 0.840777
# [82]	valid_0's auc: 0.840982
# [83]	valid_0's auc: 0.840691
# [84]	valid_0's auc: 0.840789
# [85]	valid_0's auc: 0.840386
# [86]	valid_0's auc: 0.83977
# [87]	valid_0's auc: 0.839835
# [88]	valid_0's auc: 0.839712
# [89]	valid_0's auc: 0.839532
# [90]	valid_0's auc: 0.839451
# [91]	valid_0's auc: 0.839155
# [92]	valid_0's auc: 0.83897
# [93]	valid_0's auc: 0.838827
# [94]	valid_0's auc: 0.838574
# [95]	valid_0's auc: 0.838777
# [96]	valid_0's auc: 0.838653
# [97]	valid_0's auc: 0.838073
# [98]	valid_0's auc: 0.838332
# [99]	valid_0's auc: 0.838749
# [100]	valid_0's auc: 0.838809
# [101]	valid_0's auc: 0.83888
# [102]	valid_0's auc: 0.838573
# [103]	valid_0's auc: 0.838213
# [104]	valid_0's auc: 0.838132
# [105]	valid_0's auc: 0.837599
# [106]	valid_0's auc: 0.837805
# [107]	valid_0's auc: 0.837616
# [108]	valid_0's auc: 0.837895
# [109]	valid_0's auc: 0.837658
# [110]	valid_0's auc: 0.837763
# [111]	valid_0's auc: 0.837676
# [112]	valid_0's auc: 0.837173
# [113]	valid_0's auc: 0.836876
# [114]	valid_0's auc: 0.836464
# [115]	valid_0's auc: 0.83639
# [116]	valid_0's auc: 0.836286
# [117]	valid_0's auc: 0.835888
# [118]	valid_0's auc: 0.835758
# [119]	valid_0's auc: 0.835556
# [120]	valid_0's auc: 0.83561
# [121]	valid_0's auc: 0.835392
# [122]	valid_0's auc: 0.835169
# [123]	valid_0's auc: 0.834782
# [124]	valid_0's auc: 0.834472
# [125]	valid_0's auc: 0.834404
# [126]	valid_0's auc: 0.834079
# [127]	valid_0's auc: 0.833782
# [128]	valid_0's auc: 0.83385
# [129]	valid_0's auc: 0.834128
# [130]	valid_0's auc: 0.83389
# [131]	valid_0's auc: 0.833807
# [132]	valid_0's auc: 0.833748
# [133]	valid_0's auc: 0.833612
# [134]	valid_0's auc: 0.833865
# [135]	valid_0's auc: 0.833758
# [136]	valid_0's auc: 0.833977
# [137]	valid_0's auc: 0.834113
# [138]	valid_0's auc: 0.83391
# [139]	valid_0's auc: 0.833898
# [140]	valid_0's auc: 0.833618
# [141]	valid_0's auc: 0.833788
# [142]	valid_0's auc: 0.833492
# [143]	valid_0's auc: 0.833575
# Early stopping, best iteration is:
# [43]	valid_0's auc: 0.842549
#
#
#  AUC in train data: 0.8411
# It cost 51.524124 sec

# %%
print("\n\n AUC in train data: %.4f | It costs %f sec" % (metrics.roc_auc_score(train_df_2[target], val_predict), (tEnd - tStart)))
# Out:
#  AUC in train data: 0.8411 | It costs 51.524124 sec

# %% [raw]
# metrics.roc_auc_score(train_df_2[target], val_predict) #train_reprocess_knn_v2 #0.8408522346938776

# %%
metrics.roc_auc_score(train_df_2[target], val_predict) #train_reprocess #0.8422430076530614
# Out:
# 0.8422430076530614

# %% [markdown]
# ### 平均folds預測結果

# %%
predictions
# Out:
# array([[0.04297558, 0.0225673 , 0.03223007, ..., 0.03526879, 0.02907358,
#         0.04309781],
#        [0.00218763, 0.0017327 , 0.00192614, ..., 0.00164087, 0.00139406,
#         0.00239386],
#        [0.00485049, 0.00253477, 0.00458762, ..., 0.00381704, 0.0033667 ,
#         0.00414319],
#        ...,
#        [0.12882683, 0.12850523, 0.20422815, ..., 0.15807645, 0.1992501 ,
#         0.05835648],
#        [0.06187036, 0.10217092, 0.09807307, ..., 0.10286012, 0.12936324,
#         0.02151471],
#        [0.03975468, 0.08504033, 0.062961  , ..., 0.12260089, 0.07900538,
#         0.01733423]])

# %%
prediction2 = predictions

# %%
predictions[:,[1,5,6,7]].shape
# Out:
# (150000, 4)

# %%
predictions_transform = sum(predictions[:,[1,6,7]].T) /3

# %% [raw]
# predictions_transform = sum(predictions.T) / nfold

# %%
predictions_transform
# Out:
# array([0.03297947, 0.00174498, 0.00348902, ..., 0.13432976, 0.09708225,
#        0.09433066])

# %%
submit = pd.DataFrame({'CUS_ID': test_df_2['CUS_ID'].astype(np.int64),'Ypred': predictions_transform})#rank_predictions.reshape(-1,)})
submit.to_csv('Lightgbm_reprocess_prob_26_knn.csv',index=False)

# %%
#清除函数占用的内存
'''
for x in list(locals().keys()):
    del locals()[x]
'''
gc.collect()

# %% [raw]
# stats.describe(predictions_transform)

# %% [raw]
# predictions_transform

# %% [raw]
# # 取K折排名平均值
# print("Rank averaging on", nfold, "fold predictions")
# rank_predictions = np.zeros((predictions.shape[0],1))
# for i in range(nfold):
#     rank_predictions[:, 0] = np.add(rank_predictions[:, 0], rankdata(predictions[:, i].reshape(-1,1)) / rank_predictions.shape[0])
#
# rank_predictions = rank_predictions / nfold

# %% [raw]
# stats.describe(rank_predictions)

# %% [raw]
# predictions_transform

# %% [raw]
# rank_predictions

# %% [raw]
# submit = pd.DataFrame({'CUS_ID': test_df['CUS_ID'].astype(np.int64),'Ypred': rank_predictions.reshape(-1,)})
# submit.to_csv('Lightgbm_reprocess_prob_9(new_columns_OHE).csv',index=False)

# %% [raw]
# # testing the calculation of AUC
# y= np.array([1,1,0,0,1,1])
# z=np.array([0.04703397, 0.00191934, 0.00528361, 0.1298776, 0.06876139, 0.04674724])
# h=np.array([0.89245333, 0.10615967, 0.362232, 0.97793067, 0.927712, 0.874634 ])
# print(metrics.roc_auc_score(y, z))
# print(metrics.roc_auc_score(y, h))

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------------------------------------

# %%
def roc_curve_plot(df_true, df_predict):
    fpr,tpr,th = metrics.roc_curve(df_true, df_predict)

    plt.figure(figsize=(14,6))
    plt.plot(fpr,tpr,color='r')
    plt.plot([0,1],[0,1],color='b')
    plt.title('Reciever operating Charactaristics')
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.show()
    
def roc_thresholds(df_true, df_predict, min_tpr, max_fpr):
    fpr,tpr,th = metrics.roc_curve(df_true, df_predict)
    thresholds_df = pd.DataFrame({'fpr':fpr,'tpr':tpr,'threshold':th}).sort_values(by="tpr" , ascending=False)
    a = thresholds['tpr'] > min_tpr
    b = thresholds['fpr'] < max_fpr
    return thresholds_df[(a & b)]


def conf_matrix(df_true, df_predict, threshold):
    y_pred_turn = pd.Series(df_predict).apply(lambda x: 1 if x > threshold else 0)
    matrix = metrics.confusion_matrix(y_true = df_true, 
                                      y_pred = y_pred_turn)
    score = metrics.roc_auc_score(df_true, y_pred_turn)

    fig, ax = plt.subplots(figsize= (5,5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i,j], va='center', ha='center')  
    plt.xlabel('Predict')
    plt.ylabel('True')
    plt.show()

    print('\n\nAUC after transformation：',score)

# %%
roc_curve_plot(train_df[target], val_predict)

# %% [raw]
# roc_thresholds(train_df[target].values, val_predict, min_tpr = 0.6, max_fpr = 0.4)

# %% [raw]
# stats.describe(val_predict)

# %% [raw]
# conf_matrix(train_df[target], val_predict, val_predict.std() + val_predict.mean())

# %% [markdown]
# ### test records

# %%
'''
Lightgbm_reprocess_1.csv  sum_of_1 = 44796
threshold：0.02
AUC after transformation：0.7581462585034013, TBrain_AUC：0.762815

{'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 1.0, 'importance_type': 'split', 'learning_rate': 0.01,
 'max_depth': 15, 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'n_estimators': 100, 'n_jobs': -1,
 'num_leaves': 35, 'objective': 'binary', 'random_state': None, silent': True,
 'subsample_for_bin': 200000, 'metric': 'auc', 'verbose': 0, 'feature_fraction': 0.6,
 'bagging_fraction': 0.8, 'bagging_freq': 2, 'lambda_l1': 0.1, 'lambda_l2': 10, 'cat_smooth': 1}
'''

# %%
''' 
Lightgbm_reprocess_2.csv[Lightgbm_reprocess_prob_3.csv]  sum_of_1 = 37818  
threshold：0.021 
AUC in training: 0.8401, AUC after transformation：0.7616156462585034, TBrain_AUC：0.7746192893,  TBrain_AUC[new]：0.8485426599

{'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 1.0, 'importance_type': 'split', 'learning_rate': 0.1,
 'max_depth': 20, 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'n_estimators': 100, 'n_jobs': -1,
 'num_leaves': 35, 'objective': 'binary', 'random_state': None, 'silent': True,
 'subsample_for_bin': 200000, 'metric': 'auc', 'verbose': 0, 'feature_fraction': 0.6,
 'bagging_fraction': 0.7, 'bagging_freq': 8, 'lambda_l1': 0.1, 'lambda_l2': 35, 'cat_smooth': 1}
'''

# %%
''' BEST
Lightgbm_reprocess_prob_11.csv 
AUC in training:0.840415714285, TBrain_AUC：0.8492443858

{'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 1.0, 'importance_type': 'split', 'learning_rate': 0.1,
 'max_depth': 20, 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'n_estimators': 100, 'n_jobs': -1,
 'num_leaves': 37, 'objective': 'binary', 'random_state': None, 'silent': True,'subsample_for_bin': 200000, 
 'metric': 'auc', 'verbose': 0, 'feature_fraction': 0.6, 'bagging_fraction': 0.7, 'bagging_freq': 8, 
 'lambda_l1': 0.1, 'lambda_l2': 35, 'cat_smooth': 1}
 
Lightgbm_reprocess_prob_13.csv 
AUC in training:0.8405826556122449, TBrain_AUC：XXX
early_stopping_rounds = 10 -> 15

Lightgbm_reprocess_prob_14.csv 
AUC in training:0.8409510178571429, TBrain_AUC：XXX
early_stopping_rounds = 10 -> 15 -> 20

Lightgbm_reprocess_prob_15.csv 
AUC in training:0.841293762755102, TBrain_AUC：0.8494192487
early_stopping_rounds = 10 -> 15 -> 20 -> 30

Lightgbm_reprocess_prob_16.csv 
AUC in training:0.8422430076530614, TBrain_AUC：0.8498711743
early_stopping_rounds = 10 -> 15 -> 20 -> 30
n_estimators = 100 -> 200

Lightgbm_reprocess_prob_24.csv
取Lightgbm_reprocess_prob_16中的 predictions[:,[1,2,3,5,6,7,9]]做平均  TBrain_AUC：0.8503344027

Lightgbm_reprocess_prob_21_knn.csv
AUC in training:0.8412987576530613, TBrain_AUC：0.8498704027

Lightgbm_reprocess_prob_22_knn.csv
AUC in training:0.842063642857143, TBrain_AUC： 0.8484891777
best_parameters ={'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'learning_rate': 0.05,
 'max_depth': 20, 'n_estimators': 200, 'n_jobs': -1,
 'num_leaves': 35, 'objective': 'binary', 'random_state': None, 'silent': True, 
 'metric': 'auc', 'verbose': 0, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'bagging_freq': 5, 
 'lambda_l1': 0.1, 'lambda_l2': 35, 'cat_smooth': 1}

Lightgbm_reprocess_prob_20.csv 
AUC in training:0.8429781198979592, TBrain_AUC：XXX
early_stopping_rounds = 10 -> 15 -> 20 -> 30
n_estimators = 100 -> 200
lambda_l2 = 35 -> 40
 

Lightgbm_reprocess_prob_17.csv 
AUC in training:0.8422174158163266, TBrain_AUC：0.8474860643
early_stopping_rounds = 10 -> 15 -> 20 -> 30 -> 50
n_estimators = 100 -> 200 -> 300
boosting_type = 'goss'

Lightgbm_reprocess_prob_19.csv 
AUC in training:0.8423614770408163, TBrain_AUC：0.8484761421
early_stopping_rounds = 10 -> 15 -> 20 -> 30 -> 35
n_estimators = 100 -> 200
bagging_freq = 8 -> 9
'''

# %%
'''
Lightgbm_reprocess_prob_18.csv (using [train_new_columns_OHE.csv] data)
AUC in training:0.8431564438775511, TBrain_AUC：0.8480138071

{'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 1.0, 'importance_type': 'split', 'learning_rate': 0.1,
 'max_depth': 20, 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'n_estimators': 300, 'n_jobs': -1,
 'num_leaves': 37, 'objective': 'binary', 'random_state': None, 'silent': True,'subsample_for_bin': 200000, 
 'metric': 'auc', 'verbose': 0, 'feature_fraction': 0.6, 'bagging_fraction': 0.7, 'bagging_freq': 8, 
 'lambda_l1': 0.1, 'lambda_l2': 35, 'cat_smooth': 1}
 
 '''

# %%
'''
Lightgbm_reprocess_prob_12.csv
AUC in training: 0.8410963954 , TBrain_AUC：0.8487294078

{best_parameters ={'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 1.0, 'importance_type': 'split', 'learning_rate': 0.1,
 'max_depth': 20, 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'n_estimators': 100, 'n_jobs': -1,
 'num_leaves': 38, 'objective': 'binary', 'random_state': 1, 'silent': True, 'subsample': 1.0,
 'subsample_for_bin': 200000, 'subsample_freq': 0, 'metric': 'auc', 'verbose': 0, 'feature_fraction': 0.6,
 'bagging_fraction': 0.7, 'bagging_freq': 8, 'lambda_l1': 0.1, 'lambda_l2': 35, 'cat_smooth': 1}
'''

# %%
'''
Lightgbm_reprocess_3.csv(without doing OHE)[Lightgbm_reprocess_prob_4.csv]  sum_of_1 = 28523
threshold：0.02111, 
AUC in training: 0.8424, AUC after transformation：0.7648979591836734, TBrain_AUC：0.6717529611, TBrain_AUC[new]：0.8470215228

{'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 1.0, 'importance_type': 'split', 'learning_rate': 0.1,
 'max_depth': 20, 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'n_estimators': 100, 'n_jobs': -1,
 'num_leaves': 35, 'objective': 'binary', 'random_state': None, 'silent': True,
 'subsample_for_bin': 200000, 'metric': 'auc', 'verbose': 0, 'feature_fraction': 0.6,
 'bagging_fraction': 0.7, 'bagging_freq': 5, 'lambda_l1': 0.1, 'lambda_l2': 35, 'cat_smooth': 1}
'''

# %%
'''
Lightgbm_reprocess_4.csv  sum_of_1 = 76059
threshold = 0.5
AUC in training: 0.8319, AUC after transformation：0.7504285714285714, Tbrain：0.7183654822 

{'boosting_type': 'gbdt', 'objective': 'binary', 'class_weight': 'balanced', 'importance_type': 'split',
 'learning_rate': 0.048845927448988316, 'max_depth': 47, 'min_child_samples': 15, 'min_split_gain': 0.6704675101784022,
 'n_estimators': 100, 'n_jobs': -1, 'num_leaves': 16, 'min_data_in_leaf': 5, 'min_sum_hessian_in_leaf': 0.020923509638119637,
 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'is_unbalance': True, 'subsample_for_bin': 200000,
 'subsample_freq': 0, 'metric': 'auc', 'verbose': 0, 'feature_fraction': 0.6616450202010071, 'bagging_fraction': 0.6,
 'bagging_freq': 8, 'lambda_l1': 11.28791771604942, 'lambda_l2': 37.40878001587038, 'cat_smooth': 1}
'''

# %%
'''
Lightgbm_reprocess_5.csv[Lightgbm_reprocess_prob_2.csv]  sum_of_1 = 38022
threshold = {'fold1': 0.4800000000000001, 'fold2': 0.4800000000000001, 'fold3': 0.44000000000000006, 'fold4': 0.4800000000000001,
             'fold5': 0.4600000000000001, 'fold6': 0.5600000000000002, 'fold7': 0.5200000000000001,  'fold8': 0.5400000000000001,
             'fold9': 0.4800000000000001, 'fold10': 0.42000000000000004}
             
AUC in training: 0.8355, AUC after transformation：XXX , Tbrain：0.8443494958

{'boosting_type': 'gbdt', 'objective': 'binary', 'class_weight': None, 'importance_type': 'split',
 'learning_rate': 0.054526359848345994, 'max_depth': 22, 'min_child_samples': 20, 'min_split_gain': 0.9620310653179346,
 'n_estimators': 100, 'n_jobs': -1, 'num_leaves': 24, 'min_data_in_leaf': 19, 'min_sum_hessian_in_leaf': 0.04858829899583882,
 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'is_unbalance': True, 'subsample_for_bin': 2000,
 'subsample_freq': 4, 'metric': 'auc', 'verbose': 0, 'feature_fraction': 0.7829084970031792, 'bagging_fraction': 0.7,
 'bagging_freq': 8, 'lambda_l1': 49.83708262075042, 'lambda_l2': 49.59441610333089, 'cat_smooth': 1}
'''

# %%
'''
Lightgbm_reprocess_prob.csv  
AUC in training: 0.8349, AUC after transformation：XXX , Tbrain：0.842534

{'boosting_type': 'gbdt', 'objective': 'binary', 'class_weight': None, 'importance_type': 'split', 
 'learning_rate': 0.047364271859971274, 'max_depth': 10, 'min_split_gain': 0.293237287812807, 
 'n_estimators': 200, 'n_jobs': -1, 'num_leaves': 401, 'min_data_in_leaf': 46, 'min_sum_hessian_in_leaf': 0.03313119848815982,
 'random_state': 1, 'reg_alpha': 48.77369736176732, 'reg_lambda': 41.514456471954624, 'silent': True, 'is_unbalance': True,
 'metric': 'auc', 'verbose': 0, 'feature_fraction': 0.7381674547563201, 'bagging_fraction': 0.5018758497121245, 'bagging_freq': 10,
 'cat_smooth': 1}
'''

# %%
'''
Lightgbm_reprocess_prob_5.csv
LGB_BO.max['target']: 0.8339245026344717, AUC in training: 0.8362, , Tbrain：XXX

{'boosting_type': 'gbdt', 'objective': 'binary', 'class_weight': None, 'importance_type': 'split',
 'learning_rate': 0.036462505977644125, 'max_depth': 34, 'min_split_gain': 0.16535419711693278,
 'n_estimators': 200, 'n_jobs': -1, 'num_leaves': 508, 'min_data_in_leaf': 31, 'min_sum_hessian_in_leaf': 0.0927581071815638,
 'random_state': 1, 'reg_alpha': 37.54060515680778, 'reg_lambda': 36.29989926752258, 'silent': True, 'is_unbalance': True,
 'metric': 'auc', 'verbose': 0, 'feature_fraction': 0.7412424112438712, 'bagging_fraction': 0.7710205745863651, 'bagging_freq': 10,
 'cat_smooth': 1}
'''

# %%
'''
Lightgbm_reprocess_prob_6.csv
LGB_BO.max['target']: 0.838803567546262, AUC in training: 0.8403, , Tbrain：0.8473665651

{'boosting_type': 'dart', 'objective': 'binary', 'class_weight': None, 'importance_type': 'split', 'learning_rate': 0.06611771474105235,
 'max_depth': 40, 'min_split_gain': 0.8946066635038473, 'n_estimators': 200, 'n_jobs': -1, 'num_leaves': 36, 'min_data_in_leaf': 55,
 'min_sum_hessian_in_leaf': 0.008595916715840812, 'random_state': 1, 'reg_alpha': 8.491520978228445, 'reg_lambda': 43.90712517147065,
 'silent': True, 'is_unbalance': True, 'metric': 'auc', 'verbose': 0, 'feature_fraction': 0.9841307878596988,
 'bagging_fraction': 0.9003722843377684, 'bagging_freq': 10, 'cat_smooth': 1}
'''

# %%
'''
Lightgbm_reprocess_prob_7.csv  #using [train_reprocess_2.csv] data
LGB_BO.max['target']: 0.8409108462598369, AUC in training: 0.8403, , Tbrain：0.8467020914

{'boosting_type': 'dart', 'objective': 'binary', 'class_weight': None, 'importance_type': 'split', 'learning_rate': 0.06611771474105235,
 'max_depth': 40, 'min_split_gain': 0.8946066635038473, 'n_estimators': 200, 'n_jobs': -1, 'num_leaves': 36,
 'min_data_in_leaf': 55, 'min_sum_hessian_in_leaf': 0.008595916715840812, 'random_state': 1,
 'reg_alpha': 8.491520978228445, 'reg_lambda': 43.90712517147065, 'silent': True, 'is_unbalance': True, 'metric': 'auc',
 'verbose': 0, 'feature_fraction': 0.9841307878596988, 'bagging_fraction': 0.9003722843377684, 'bagging_freq': 10, 'cat_smooth': 1}
'''

# %%
'''
Lightgbm_reprocess_prob_8.csv  #using [train_reprocess_2.csv] data
LGB_BO.max['target']: 0.8400115824555283, AUC in training: 0.8416, , Tbrain：0.8451220575

{'boosting_type': 'gbdt', 'objective': 'binary', 'class_weight': None, 'importance_type': 'split','learning_rate': 0.03215888771389792,
 'max_depth': 41, 'min_split_gain': 0.16535419711693278, 'n_estimators': 200, 'n_jobs': -1,'num_leaves': 76,
 'min_data_in_leaf': 29, 'min_sum_hessian_in_leaf': 0.0927581071815638, 'random_state': 1,
 'reg_alpha': 37.54060515680778, 'reg_lambda': 36.29989926752258, 'silent': True, 'is_unbalance': True, 'metric': 'auc',
 'verbose': 0, 'feature_fraction': 0.5687373520731187, 'bagging_fraction': 0.9517009576439417, 'bagging_freq': 10, 'cat_smooth': 1}
'''

# %%
'''
Lightgbm_reprocess_prob_9.csv  #using [train_new_columns_OHE.csv] data
AUC in training: 0.8411265739795919, , Tbrain：0.8471926768

{'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 1.0, 'importance_type': 'split', 'learning_rate': 0.1,
 'max_depth': 20, 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'n_estimators': 100, 'n_jobs': -1,
 'num_leaves': 35, 'objective': 'binary', 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample': 1.0,
 'subsample_for_bin': 200000, 'subsample_freq': 0, 'metric': 'auc', 'verbose': 0, 'feature_fraction': 0.6,
 'bagging_fraction': 0.7, 'bagging_freq': 8, 'lambda_l1': 0.1, 'lambda_l2': 35, 'cat_smooth': 1, 'learn_rate': 0.02}
'''

# %%
'''
Lightgbm_reprocess_prob_10.csv  #using [train_reprocess_nan.csv] data
AUC in training: 0.9505286122448979, , Tbrain：0.7894146058

{'boosting_type': 'gbdt', 'objective': 'binary', 'class_weight': None, 'importance_type': 'split',
 'learning_rate': 0.09746013255697664, 'max_depth': 22, 'min_split_gain': 0.9051459971534626, 'n_estimators': 100,
 'n_jobs': -1, 'num_leaves': 30, 'min_data_in_leaf': 91, 'min_sum_hessian_in_leaf': 0.008595916715840812, 'random_state': 1,
 'reg_alpha': 3.396608391291378, 'reg_lambda': 17.56285006858826, 'silent': True, 'is_unbalance': True,
 'metric': 'auc', 'verbose': 0, 'bagging_fraction': 0.940223370602661, 'bagging_freq': 9, 'cat_smooth': 1}
'''

# %%
best_parameters

# %% [markdown]
# ### 參考網站(貝葉斯全局優化)：https://blog.csdn.net/qq_42283960/article/details/88317003

# %% [markdown]
# ### 參考網站(特徵工程)：https://www.zhihu.com/question/28641663
